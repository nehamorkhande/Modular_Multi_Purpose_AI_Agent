# %%
import os
import pandas as pd
import re

def clean_text(text):
    text = str(text).lower()
    text = re.sub(r"[^a-zA-Z0-9\s]", "", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text

input_folder = "../raw"
output_folder = "../pre_processed"

for filename in os.listdir(input_folder):
    if filename.endswith(".csv"):
        file_path = os.path.join(input_folder, filename)
        
        df = pd.read_csv(file_path)

        if 'text' in df.columns:
            df['text'] = df['text'].apply(clean_text)

            output_file = os.path.join(output_folder, f"{os.path.splitext(filename)[0]}_cleaned.csv")
            df.to_csv(output_file, index=False)
            print(f"Processed: {filename}")
        else:
            print(f"'text' column not found in {filename}")
# Out:
# Processed: convert_to_audio_data.csv
# Processed: gmail_intent_data.csv
# Processed: make_notes_data.csv
# Processed: product_sentiment_data.csv
# Processed: stock_sentiment_data.csv
# Processed: voice_summary_data.csv
# Processed: weather_data.csv
