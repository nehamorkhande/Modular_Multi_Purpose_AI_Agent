# %% [markdown]
# # Convert to audio intent data

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd

# %% [markdown]
# ## Generated data

# %%
data1 = [
    {"text": "I'd love to hear this read out loud", "intent": "convert_to_audio"},
    {"text": "Could you turn this script into an audio file?", "intent": "convert_to_audio"},
    {"text": "Please make this sentence audible", "intent": "convert_to_audio"},
    {"text": "Transform these lines into voice format", "intent": "convert_to_audio"},
    {"text": "Produce an MP3 from this message", "intent": "convert_to_audio"},
    {"text": "Is it possible to vocalize this content?", "intent": "convert_to_audio"},
    {"text": "Say these words out loud", "intent": "convert_to_audio"},
    {"text": "Turn the following into an audio clip", "intent": "convert_to_audio"},
    {"text": "I’d appreciate a voice version of this", "intent": "convert_to_audio"},
    {"text": "Generate a sound file of this", "intent": "convert_to_audio"},
    {"text": "Convert the note below into speech", "intent": "convert_to_audio"},
    {"text": "Speak this for me, please", "intent": "convert_to_audio"},
    {"text": "Give me a narrated version of this content", "intent": "convert_to_audio"},
    {"text": "Please render this paragraph into voice", "intent": "convert_to_audio"},
    {"text": "Make a recording of this content", "intent": "convert_to_audio"},
    {"text": "How does this sound when spoken?", "intent": "convert_to_audio"},
    {"text": "Can you output this as an MP3?", "intent": "convert_to_audio"},
    {"text": "Speak this document out loud", "intent": "convert_to_audio"},
    {"text": "Create a podcast version of this text", "intent": "convert_to_audio"},
    {"text": "I'd like to listen to this in spoken form", "intent": "convert_to_audio"},
    {"text": "Convert my notes into a voice memo", "intent": "convert_to_audio"},
    {"text": "Can this text be transformed into audio?", "intent": "convert_to_audio"},
    {"text": "Give me a voice-over version of this note", "intent": "convert_to_audio"},
    {"text": "I need to hear this out loud", "intent": "convert_to_audio"},
    {"text": "Audioify this content", "intent": "convert_to_audio"},
    {"text": "Please give me a voice representation of this", "intent": "convert_to_audio"},
    {"text": "Create a verbal output for this", "intent": "convert_to_audio"},
    {"text": "Play the spoken version of these lines", "intent": "convert_to_audio"},
    {"text": "I'd like a read-aloud of this", "intent": "convert_to_audio"},
    {"text": "Vocalize these sentences for me", "intent": "convert_to_audio"},
    {"text": "Turn this paragraph into speech format", "intent": "convert_to_audio"},
    {"text": "Make a podcast reading of this note", "intent": "convert_to_audio"},
    {"text": "Give this note a voice", "intent": "convert_to_audio"},
    {"text": "Turn the content into an audible clip", "intent": "convert_to_audio"},
    {"text": "Read this script in a podcast style", "intent": "convert_to_audio"},
    {"text": "I'd like an audio narration of this paragraph", "intent": "convert_to_audio"},
    {"text": "Please convert this article to sound", "intent": "convert_to_audio"},
    {"text": "Convert the following sentence into audio output", "intent": "convert_to_audio"},
    {"text": "Let me hear what this text sounds like", "intent": "convert_to_audio"},
    {"text": "Read this in your voice", "intent": "convert_to_audio"},
    {"text": "Speak out the paragraph below", "intent": "convert_to_audio"},
    {"text": "Please convert my document into a voice file", "intent": "convert_to_audio"},
    {"text": "I want to listen to these sentences", "intent": "convert_to_audio"},
    {"text": "Please provide an audio narration", "intent": "convert_to_audio"},
    {"text": "Turn this into speech audio format", "intent": "convert_to_audio"},
    {"text": "Read out my writing in voice", "intent": "convert_to_audio"},
    {"text": "Audio playback required for this content", "intent": "convert_to_audio"},
    {"text": "Give an oral version of this file", "intent": "convert_to_audio"},
    {"text": "Speak this section like a narrator would", "intent": "convert_to_audio"},
    {"text": "Let me hear how this reads", "intent": "convert_to_audio"},
    {"text": "I want an audible playback of these notes", "intent": "convert_to_audio"},
    {"text": "Can you sound this paragraph?", "intent": "convert_to_audio"},
    {"text": "Convert and vocalize this script", "intent": "convert_to_audio"},
    {"text": "Voice message required for the following", "intent": "convert_to_audio"},
    {"text": "Turn these lines into a speech clip", "intent": "convert_to_audio"},
    {"text": "Could you say these notes aloud?", "intent": "convert_to_audio"},
    {"text": "I'd like to get an audio transformation of this", "intent": "convert_to_audio"},
    {"text": "Play this paragraph using voice", "intent": "convert_to_audio"},
    {"text": "Can you return this note as audio?", "intent": "convert_to_audio"},
    {"text": "Voice representation needed for this script", "intent": "convert_to_audio"},
    {"text": "Generate an audio file from these points", "intent": "convert_to_audio"},
    {"text": "I’d like this content spoken", "intent": "convert_to_audio"},
    {"text": "Produce a sound version of this paragraph", "intent": "convert_to_audio"},
    {"text": "Let me hear this content in MP3 form", "intent": "convert_to_audio"},
    {"text": "Turn this sentence into voice-based output", "intent": "convert_to_audio"},
    {"text": "Can you read these lines for me?", "intent": "convert_to_audio"},
    {"text": "Please voice out the following message", "intent": "convert_to_audio"},
    {"text": "Speak this out as if it's a podcast", "intent": "convert_to_audio"},
    {"text": "Narrate this paragraph, please", "intent": "convert_to_audio"},
    {"text": "Generate a voice-over for this note", "intent": "convert_to_audio"},
    {"text": "Make an audio track from this sentence", "intent": "convert_to_audio"},
    {"text": "I'd love to hear this read in English", "intent": "convert_to_audio"},
    {"text": "Please say these lines using audio", "intent": "convert_to_audio"},
    {"text": "Provide an auditory version of this", "intent": "convert_to_audio"},
    {"text": "Can you return an MP3 of this note?", "intent": "convert_to_audio"},
    {"text": "Voice this script out loud", "intent": "convert_to_audio"},
    {"text": "Let me listen to these notes", "intent": "convert_to_audio"},
    {"text": "Say this section in your voice", "intent": "convert_to_audio"},
    {"text": "I need this transformed into voice", "intent": "convert_to_audio"},
    {"text": "Say this sentence with voice", "intent": "convert_to_audio"},
    {"text": "Create a speech version of these points", "intent": "convert_to_audio"},
    {"text": "Speak the following out like an audiobook", "intent": "convert_to_audio"},
    {"text": "Give me an audible file of this message", "intent": "convert_to_audio"},
    {"text": "Produce speech for the content below", "intent": "convert_to_audio"},
    {"text": "Please let me hear this script", "intent": "convert_to_audio"},
    {"text": "Say this back to me in audio", "intent": "convert_to_audio"},
    {"text": "I’d like an MP3 version of this writing", "intent": "convert_to_audio"},
    {"text": "Speak the paragraph in clear audio", "intent": "convert_to_audio"},
    {"text": "Can you return a vocal version of this file?", "intent": "convert_to_audio"},
    {"text": "Say the following in spoken English", "intent": "convert_to_audio"},
    {"text": "Play this in audio speech format", "intent": "convert_to_audio"},
    {"text": "Produce a sound clip from this paragraph", "intent": "convert_to_audio"},
    {"text": "Please create a spoken version", "intent": "convert_to_audio"},
    {"text": "Make the following paragraph verbal", "intent": "convert_to_audio"},
    {"text": "Can you give me an MP3 reading of this?", "intent": "convert_to_audio"},
    {"text": "Say these contents out loud like a narrator", "intent": "convert_to_audio"},
    {"text": "Speak this message into an audio file", "intent": "convert_to_audio"},
    {"text": "Make this segment listenable", "intent": "convert_to_audio"},
    {"text": "Play this note as a voice output", "intent": "convert_to_audio"},
    {"text": "Say my paragraph as sound", "intent": "convert_to_audio"},
    {"text": "Turn this piece into vocal form", "intent": "convert_to_audio"},
    {"text": "Please pronounce this note aloud", "intent": "convert_to_audio"},
    {"text": "Produce audio using the following words", "intent": "convert_to_audio"},
    {"text": "Turn this into spoken narration", "intent": "convert_to_audio"}
]

# %%
data2 = [
    {"text": "I'd like this text to be read out loud", "intent": "convert_to_audio"},
    {"text": "Convert this sentence into an audio message", "intent": "convert_to_audio"},
    {"text": "Can you play back this text as speech?", "intent": "convert_to_audio"},
    {"text": "I want this written content in audio format", "intent": "convert_to_audio"},
    {"text": "Please turn this message into spoken audio", "intent": "convert_to_audio"},
    {"text": "I need this content vocalized", "intent": "convert_to_audio"},
    {"text": "Say this sentence in a natural voice", "intent": "convert_to_audio"},
    {"text": "Turn this content into something I can listen to", "intent": "convert_to_audio"},
    {"text": "Could you generate a voiceover of this message?", "intent": "convert_to_audio"},
    {"text": "I’d like to listen to this instead of reading", "intent": "convert_to_audio"},
    {"text": "Please speak the following aloud", "intent": "convert_to_audio"},
    {"text": "Turn these points into a speech file", "intent": "convert_to_audio"},
    {"text": "Give me an audible form of this input", "intent": "convert_to_audio"},
    {"text": "Play this content back as audio", "intent": "convert_to_audio"},
    {"text": "I want this information as an MP3", "intent": "convert_to_audio"},
    {"text": "Can you convert these lines into sound?", "intent": "convert_to_audio"},
    {"text": "Make this sentence speakable", "intent": "convert_to_audio"},
    {"text": "Transform my paragraph into an audible recording", "intent": "convert_to_audio"},
    {"text": "I prefer hearing this — generate voice", "intent": "convert_to_audio"},
    {"text": "Please produce a speech output of this note", "intent": "convert_to_audio"},
    {"text": "Let me hear this message in audio form", "intent": "convert_to_audio"},
    {"text": "Convert the following into voice-based audio", "intent": "convert_to_audio"},
    {"text": "I'd like this typed content spoken back to me", "intent": "convert_to_audio"},
    {"text": "Speak this text for audio playback", "intent": "convert_to_audio"},
    {"text": "I want a narrator-style version of this content", "intent": "convert_to_audio"},
    {"text": "Please output this as a speech stream", "intent": "convert_to_audio"},
    {"text": "Say these words in human-like voice", "intent": "convert_to_audio"},
    {"text": "I'd appreciate this as spoken language", "intent": "convert_to_audio"},
    {"text": "Say this input in voice form", "intent": "convert_to_audio"},
    {"text": "Voice this paragraph and send it as audio", "intent": "convert_to_audio"},
    {"text": "Turn this message into a voice format", "intent": "convert_to_audio"},
    {"text": "Produce speech from this input", "intent": "convert_to_audio"},
    {"text": "Can you narrate this line?", "intent": "convert_to_audio"},
    {"text": "Please play this out loud using AI voice", "intent": "convert_to_audio"},
    {"text": "Say the next message as an audio clip", "intent": "convert_to_audio"},
    {"text": "Speak this using natural-sounding speech", "intent": "convert_to_audio"},
    {"text": "Play audio of these statements", "intent": "convert_to_audio"},
    {"text": "Create a vocal file of this paragraph", "intent": "convert_to_audio"},
    {"text": "Generate voice narration for this entry", "intent": "convert_to_audio"},
    {"text": "Provide this content as a spoken file", "intent": "convert_to_audio"},
    {"text": "Read this aloud like a narrator", "intent": "convert_to_audio"},
    {"text": "I want to hear this paragraph", "intent": "convert_to_audio"},
    {"text": "Give me a listenable version of the input", "intent": "convert_to_audio"},
    {"text": "Play this content as a human voice", "intent": "convert_to_audio"},
    {"text": "Make this paragraph sound like a podcast", "intent": "convert_to_audio"},
    {"text": "Turn this sentence into something I can hear", "intent": "convert_to_audio"},
    {"text": "Could you voice this out for me?", "intent": "convert_to_audio"},
    {"text": "I'd like to hear this sentence played back", "intent": "convert_to_audio"},
    {"text": "Transform this message into voice output", "intent": "convert_to_audio"},
    {"text": "Please speak this out in English", "intent": "convert_to_audio"},
    {"text": "Return an audio narration of this input", "intent": "convert_to_audio"}
]

# %%
data3 = [
    {"text": "Please give a voice version of this input", "intent": "convert_to_audio"},
    {"text": "Can this line be read out in voice?", "intent": "convert_to_audio"},
    {"text": "Produce a sound output for this message", "intent": "convert_to_audio"},
    {"text": "Change this text into a spoken phrase", "intent": "convert_to_audio"},
    {"text": "Say this as though reading it to an audience", "intent": "convert_to_audio"},
    {"text": "Turn this into a recording I can listen to", "intent": "convert_to_audio"},
    {"text": "I want this narrated like a podcast", "intent": "convert_to_audio"},
    {"text": "Speak these words like an audiobook", "intent": "convert_to_audio"},
    {"text": "Play this content as voice narration", "intent": "convert_to_audio"},
    {"text": "Please turn this block of text into sound", "intent": "convert_to_audio"},
    {"text": "Use speech to say this", "intent": "convert_to_audio"},
    {"text": "Let me hear this in an audio clip", "intent": "convert_to_audio"},
    {"text": "Say this like a voice assistant", "intent": "convert_to_audio"},
    {"text": "I want a speech version of this sentence", "intent": "convert_to_audio"},
    {"text": "Please generate audio playback for this", "intent": "convert_to_audio"},
    {"text": "Make this content vocal", "intent": "convert_to_audio"},
    {"text": "Give a voice-based format of this note", "intent": "convert_to_audio"},
    {"text": "Narrate this line using a voice engine", "intent": "convert_to_audio"},
    {"text": "Turn the content into something audible", "intent": "convert_to_audio"},
    {"text": "Can you turn these sentences into a spoken clip?", "intent": "convert_to_audio"},
    {"text": "Convert to voice mode", "intent": "convert_to_audio"},
    {"text": "Let me listen to the input", "intent": "convert_to_audio"},
    {"text": "Create a sound version of this paragraph", "intent": "convert_to_audio"},
    {"text": "Change this into vocal output", "intent": "convert_to_audio"},
    {"text": "Speak this in plain English", "intent": "convert_to_audio"},
    {"text": "Generate audible feedback for this text", "intent": "convert_to_audio"},
    {"text": "Give this back as a voice file", "intent": "convert_to_audio"},
    {"text": "Say this script aloud", "intent": "convert_to_audio"},
    {"text": "Can you read these notes out loud?", "intent": "convert_to_audio"},
    {"text": "Make this listenable content", "intent": "convert_to_audio"},
    {"text": "I'd like an audio snippet of this", "intent": "convert_to_audio"},
    {"text": "Please return this as a speech sample", "intent": "convert_to_audio"},
    {"text": "Play this text like a voice note", "intent": "convert_to_audio"},
    {"text": "Give me a sound file for this statement", "intent": "convert_to_audio"},
    {"text": "Verbal version of this, please", "intent": "convert_to_audio"},
    {"text": "Convert this paragraph to a voice clip", "intent": "convert_to_audio"},
    {"text": "Speak this so I can hear it", "intent": "convert_to_audio"},
    {"text": "Make this paragraph talk", "intent": "convert_to_audio"},
    {"text": "Produce audio for this written passage", "intent": "convert_to_audio"},
    {"text": "Give this sentence back as an MP3", "intent": "convert_to_audio"},
    {"text": "I want to hear these lines", "intent": "convert_to_audio"},
    {"text": "Turn this phrase into audible speech", "intent": "convert_to_audio"},
    {"text": "Read this message out using synthetic voice", "intent": "convert_to_audio"},
    {"text": "Please generate a vocalized clip of this", "intent": "convert_to_audio"},
    {"text": "Voice out this section of text", "intent": "convert_to_audio"},
    {"text": "Render this message into audio", "intent": "convert_to_audio"},
    {"text": "Provide a sound clip of this sentence", "intent": "convert_to_audio"},
    {"text": "Say this as if reading to a friend", "intent": "convert_to_audio"},
    {"text": "Play this aloud as a narration", "intent": "convert_to_audio"},
    {"text": "Make an MP3 narration of this note", "intent": "convert_to_audio"}
]

# %%
data4 = [
    {"text": "Convert this text to audio", "intent": "convert_to_audio"},
    {"text": "Can you read this out loud?", "intent": "convert_to_audio"},
    {"text": "Make an audio file from this", "intent": "convert_to_audio"},
    {"text": "Speak this text", "intent": "convert_to_audio"},
    {"text": "Turn these notes into an MP3", "intent": "convert_to_audio"},
    {"text": "I want to hear this content", "intent": "convert_to_audio"},
    {"text": "Play this as audio", "intent": "convert_to_audio"},
    {"text": "Read this in audio format", "intent": "convert_to_audio"},
    {"text": "Generate audio from this note", "intent": "convert_to_audio"},
    {"text": "Can you say this out loud?", "intent": "convert_to_audio"},
    {"text": "Turn this note into spoken words", "intent": "convert_to_audio"},
    {"text": "Please give me an audio version of this", "intent": "convert_to_audio"},
    {"text": "I want this in audio format", "intent": "convert_to_audio"},
    {"text": "Speak these words", "intent": "convert_to_audio"},
    {"text": "Can you speak this content?", "intent": "convert_to_audio"},
    {"text": "Say this text", "intent": "convert_to_audio"},
    {"text": "I want an audio clip of this", "intent": "convert_to_audio"},
    {"text": "Make this listenable", "intent": "convert_to_audio"},
    {"text": "Give me audio output for this", "intent": "convert_to_audio"},
    {"text": "Voice this content", "intent": "convert_to_audio"},
    {"text": "Can I hear this text?", "intent": "convert_to_audio"},
    {"text": "Please play this note as audio", "intent": "convert_to_audio"},
    {"text": "Turn this into a voice message", "intent": "convert_to_audio"},
    {"text": "I’d like to hear this", "intent": "convert_to_audio"},
    {"text": "Convert the following to voice", "intent": "convert_to_audio"},
    {"text": "Give this back as sound", "intent": "convert_to_audio"},
    {"text": "I want to listen to this", "intent": "convert_to_audio"},
    {"text": "Can this be converted to speech?", "intent": "convert_to_audio"},
    {"text": "Read this content using voice", "intent": "convert_to_audio"},
    {"text": "Say it aloud", "intent": "convert_to_audio"},
    {"text": "Please give audio for this", "intent": "convert_to_audio"},
    {"text": "Make this audible", "intent": "convert_to_audio"},
    {"text": "Can you give me a sound version of this?", "intent": "convert_to_audio"},
    {"text": "Let me hear this document", "intent": "convert_to_audio"},
    {"text": "Voice over this content", "intent": "convert_to_audio"},
    {"text": "Generate speech from this", "intent": "convert_to_audio"},
    {"text": "Can you vocalize this?", "intent": "convert_to_audio"},
    {"text": "Play this paragraph as audio", "intent": "convert_to_audio"},
    {"text": "Say this out", "intent": "convert_to_audio"},
    {"text": "Audio version needed", "intent": "convert_to_audio"},
    {"text": "Can you pronounce this content?", "intent": "convert_to_audio"},
    {"text": "Make this text audible", "intent": "convert_to_audio"},
    {"text": "Read this aloud like a podcast", "intent": "convert_to_audio"},
    {"text": "Convert it into spoken audio", "intent": "convert_to_audio"},
    {"text": "Give a voice recording of this", "intent": "convert_to_audio"},
    {"text": "Provide an MP3 for this note", "intent": "convert_to_audio"},
    {"text": "Transform this text into audio", "intent": "convert_to_audio"},
    {"text": "Speak out the content", "intent": "convert_to_audio"},
    {"text": "Please read my notes", "intent": "convert_to_audio"},
    {"text": "Read it like an audiobook", "intent": "convert_to_audio"},
    {"text": "Turn this into spoken English", "intent": "convert_to_audio"},
    {"text": "Make a voice file from this", "intent": "convert_to_audio"},
    {"text": "I need this in audio", "intent": "convert_to_audio"},
    {"text": "Play these notes as sound", "intent": "convert_to_audio"},
    {"text": "Read this paragraph aloud", "intent": "convert_to_audio"},
    {"text": "Produce a voice message of this", "intent": "convert_to_audio"},
    {"text": "I’d like an audio file for this", "intent": "convert_to_audio"},
    {"text": "Can you narrate this?", "intent": "convert_to_audio"},
    {"text": "Speak the following sentence", "intent": "convert_to_audio"},
    {"text": "Say the content in this file", "intent": "convert_to_audio"},
    {"text": "Please make this content audible", "intent": "convert_to_audio"},
    {"text": "Render this into a voice", "intent": "convert_to_audio"},
    {"text": "Voice over this file", "intent": "convert_to_audio"},
    {"text": "Narrate these notes", "intent": "convert_to_audio"},
    {"text": "Audio narration needed", "intent": "convert_to_audio"},
    {"text": "Make this readable by voice", "intent": "convert_to_audio"},
    {"text": "Create audio narration", "intent": "convert_to_audio"},
    {"text": "I'd like a voice output", "intent": "convert_to_audio"},
    {"text": "Please speak the following", "intent": "convert_to_audio"},
    {"text": "I need an audible version of this", "intent": "convert_to_audio"},
    {"text": "Voice convert this", "intent": "convert_to_audio"},
    {"text": "Please generate audio", "intent": "convert_to_audio"},
    {"text": "Play back the notes", "intent": "convert_to_audio"},
    {"text": "Make a podcast-style clip", "intent": "convert_to_audio"},
    {"text": "Turn my notes into speech", "intent": "convert_to_audio"},
    {"text": "Can I get this as a spoken clip?", "intent": "convert_to_audio"},
    {"text": "I want this in voice form", "intent": "convert_to_audio"},
    {"text": "Convert it into verbal audio", "intent": "convert_to_audio"},
    {"text": "Spoken form needed", "intent": "convert_to_audio"},
    {"text": "Make the sentence soundable", "intent": "convert_to_audio"},
    {"text": "Speak this like a narrator", "intent": "convert_to_audio"},
    {"text": "Play this as a voice recording", "intent": "convert_to_audio"},
    {"text": "Turn these notes into a speech", "intent": "convert_to_audio"},
    {"text": "Read this out as if I’m listening", "intent": "convert_to_audio"},
    {"text": "Verbalize this", "intent": "convert_to_audio"},
    {"text": "Generate audio feedback", "intent": "convert_to_audio"},
    {"text": "Let me hear the notes", "intent": "convert_to_audio"},
    {"text": "Record a voice reading this", "intent": "convert_to_audio"},
    {"text": "Spoken version needed", "intent": "convert_to_audio"},
    {"text": "I want to hear this paragraph", "intent": "convert_to_audio"},
    {"text": "Turn this into an MP3 narration", "intent": "convert_to_audio"},
    {"text": "Please play the text in audio", "intent": "convert_to_audio"},
    {"text": "Speak out these sentences", "intent": "convert_to_audio"},
    {"text": "Say my notes aloud", "intent": "convert_to_audio"},
    {"text": "Convert these words to sound", "intent": "convert_to_audio"},
    {"text": "Generate a vocal output", "intent": "convert_to_audio"},
    {"text": "Make a reading of this", "intent": "convert_to_audio"},
    {"text": "Let me hear this note", "intent": "convert_to_audio"},
    {"text": "Sound this paragraph", "intent": "convert_to_audio"},
]

# %%
data5 = [
    {"text": "I'd like this spoken back to me", "intent": "convert_to_audio"},
    {"text": "Please narrate this passage", "intent": "convert_to_audio"},
    {"text": "Convert these lines into a voice clip", "intent": "convert_to_audio"},
    {"text": "Can you vocalize this script?", "intent": "convert_to_audio"},
    {"text": "Make an audio track out of this", "intent": "convert_to_audio"},
    {"text": "Say this content like a news reader", "intent": "convert_to_audio"},
    {"text": "Give a spoken delivery of this", "intent": "convert_to_audio"},
    {"text": "Voice-over these words", "intent": "convert_to_audio"},
    {"text": "I’d love to hear this instead of reading", "intent": "convert_to_audio"},
    {"text": "Turn the text into speech", "intent": "convert_to_audio"},
    {"text": "Can I get a sound clip of this?", "intent": "convert_to_audio"},
    {"text": "Say this as an announcement", "intent": "convert_to_audio"},
    {"text": "Let me hear a voice read this out", "intent": "convert_to_audio"},
    {"text": "Read these out using text-to-speech", "intent": "convert_to_audio"},
    {"text": "I'd like a voice note of this", "intent": "convert_to_audio"},
    {"text": "Turn this message into a podcast segment", "intent": "convert_to_audio"},
    {"text": "Give this in MP3 voice format", "intent": "convert_to_audio"},
    {"text": "Speak the sentence to me", "intent": "convert_to_audio"},
    {"text": "Make this a readable file using voice", "intent": "convert_to_audio"},
    {"text": "I'd like to hear the spoken version", "intent": "convert_to_audio"},
    {"text": "Can this paragraph be made audible?", "intent": "convert_to_audio"},
    {"text": "Convert the text to a soundwave", "intent": "convert_to_audio"},
    {"text": "Sound this text as voice", "intent": "convert_to_audio"},
    {"text": "Turn my sentence into a sound file", "intent": "convert_to_audio"},
    {"text": "I'd appreciate an audible format", "intent": "convert_to_audio"},
    {"text": "Generate a podcast-like voiceover", "intent": "convert_to_audio"},
    {"text": "Render this note vocally", "intent": "convert_to_audio"},
    {"text": "I want an MP3 voice clip of this", "intent": "convert_to_audio"},
    {"text": "Create a voiceover output for this", "intent": "convert_to_audio"},
    {"text": "Generate voice message format", "intent": "convert_to_audio"},
    {"text": "Let me listen instead of reading", "intent": "convert_to_audio"},
    {"text": "Say this line with a clear voice", "intent": "convert_to_audio"},
    {"text": "Play this aloud using a voice bot", "intent": "convert_to_audio"},
    {"text": "Please give a sound interpretation", "intent": "convert_to_audio"},
    {"text": "I need voice narration of this part", "intent": "convert_to_audio"},
    {"text": "Please vocalize the sentence", "intent": "convert_to_audio"},
    {"text": "Transform this paragraph into sound", "intent": "convert_to_audio"},
    {"text": "Can you turn this into verbal format?", "intent": "convert_to_audio"},
    {"text": "Let me hear this as if from a narrator", "intent": "convert_to_audio"},
    {"text": "Play this text as audio content", "intent": "convert_to_audio"},
    {"text": "I'd like this read to me", "intent": "convert_to_audio"},
    {"text": "Turn this into something I can hear", "intent": "convert_to_audio"},
    {"text": "Give me the audible outcome of this", "intent": "convert_to_audio"},
    {"text": "Speak this paragraph using voice AI", "intent": "convert_to_audio"},
    {"text": "Can you pronounce this out loud?", "intent": "convert_to_audio"},
    {"text": "Turn this note into a narration", "intent": "convert_to_audio"},
    {"text": "Say this for me in voice", "intent": "convert_to_audio"},
    {"text": "Let me hear this in a speech form", "intent": "convert_to_audio"},
    {"text": "I need a voice file of this text", "intent": "convert_to_audio"},
    {"text": "Please provide a speech-based clip", "intent": "convert_to_audio"},
    {"text": "Read this like a storyteller", "intent": "convert_to_audio"},
    {"text": "Speak it in a smooth voice", "intent": "convert_to_audio"},
    {"text": "I’d like this played in voice format", "intent": "convert_to_audio"},
    {"text": "Convert to synthetic voice", "intent": "convert_to_audio"},
    {"text": "I want to hear this read aloud", "intent": "convert_to_audio"},
    {"text": "Voice generate this input", "intent": "convert_to_audio"},
    {"text": "Make this section spoken", "intent": "convert_to_audio"},
    {"text": "Give me a reading in voice", "intent": "convert_to_audio"},
    {"text": "Generate a sound version of this message", "intent": "convert_to_audio"},
    {"text": "Create a listening version of this", "intent": "convert_to_audio"},
    {"text": "Say these lines using voice AI", "intent": "convert_to_audio"},
    {"text": "Play back this note with sound", "intent": "convert_to_audio"},
    {"text": "Let this be heard", "intent": "convert_to_audio"},
    {"text": "Please use audio to deliver this", "intent": "convert_to_audio"},
    {"text": "Turn it into an MP3 voice track", "intent": "convert_to_audio"},
    {"text": "I’d like this rendered in voice", "intent": "convert_to_audio"},
    {"text": "Speak this section of the document", "intent": "convert_to_audio"},
    {"text": "Audio render this message", "intent": "convert_to_audio"},
    {"text": "Transform into a voice playable", "intent": "convert_to_audio"},
    {"text": "Make this into something I can listen to", "intent": "convert_to_audio"},
    {"text": "Say these words to me", "intent": "convert_to_audio"},
    {"text": "Use your voice to read this", "intent": "convert_to_audio"},
    {"text": "Provide me with a sound file of this", "intent": "convert_to_audio"},
    {"text": "Play this using voice synthesis", "intent": "convert_to_audio"},
    {"text": "Please make an audio recording of this", "intent": "convert_to_audio"},
    {"text": "Speak this clearly", "intent": "convert_to_audio"},
    {"text": "Read this part like a narrator", "intent": "convert_to_audio"},
    {"text": "Convert the script into audible format", "intent": "convert_to_audio"},
    {"text": "I'd like this played like an audiobook", "intent": "convert_to_audio"},
    {"text": "Turn this chunk of text into an audio stream", "intent": "convert_to_audio"},
    {"text": "Make this vocal content", "intent": "convert_to_audio"},
    {"text": "Audio playback of this required", "intent": "convert_to_audio"},
    {"text": "Speak this paragraph with voice modulation", "intent": "convert_to_audio"},
    {"text": "Turn this into a spoken paragraph", "intent": "convert_to_audio"},
    {"text": "I need this in a voice assistant format", "intent": "convert_to_audio"},
    {"text": "Please convert to audible MP3", "intent": "convert_to_audio"},
    {"text": "Let me hear this like it's on a podcast", "intent": "convert_to_audio"},
    {"text": "Sound out these details", "intent": "convert_to_audio"},
    {"text": "Provide an audio message for this", "intent": "convert_to_audio"},
    {"text": "Narrate this like a story", "intent": "convert_to_audio"},
    {"text": "Generate a narration file for this", "intent": "convert_to_audio"},
    {"text": "Make the voice version of this", "intent": "convert_to_audio"},
    {"text": "Can I hear an audible version of these words?", "intent": "convert_to_audio"},
    {"text": "Use AI voice to read this", "intent": "convert_to_audio"},
    {"text": "Give me this sentence as a voice output", "intent": "convert_to_audio"},
    {"text": "Speak this whole content", "intent": "convert_to_audio"},
    {"text": "Make this content play as a voice", "intent": "convert_to_audio"},
    {"text": "Read this as an audio file", "intent": "convert_to_audio"},
    {"text": "Let me hear the script", "intent": "convert_to_audio"}
]

# %%
data6 = [
    {"text": "Could you turn this text into audio?", "intent": "convert_to_audio"},
    {"text": "Make this sentence audible", "intent": "convert_to_audio"},
    {"text": "I need this part read out loud", "intent": "convert_to_audio"},
    {"text": "Convert this into a spoken format", "intent": "convert_to_audio"},
    {"text": "Can this content be played aloud?", "intent": "convert_to_audio"},
    {"text": "Read this aloud like a podcast", "intent": "convert_to_audio"},
    {"text": "Use TTS to speak this", "intent": "convert_to_audio"},
    {"text": "I'd rather listen to this", "intent": "convert_to_audio"},
    {"text": "Play this as spoken words", "intent": "convert_to_audio"},
    {"text": "Turn this into a voice message", "intent": "convert_to_audio"},
    {"text": "I want this spoken via AI", "intent": "convert_to_audio"},
    {"text": "Say this using speech synthesis", "intent": "convert_to_audio"},
    {"text": "Play this sentence as audio", "intent": "convert_to_audio"},
    {"text": "Read this like a narrator would", "intent": "convert_to_audio"},
    {"text": "I want to hear this part", "intent": "convert_to_audio"},
    {"text": "Can you read this section out?", "intent": "convert_to_audio"},
    {"text": "Speak this as a voiceover artist", "intent": "convert_to_audio"},
    {"text": "Please turn this script into voice", "intent": "convert_to_audio"},
    {"text": "Render this in speech", "intent": "convert_to_audio"},
    {"text": "Let me hear a reading of this", "intent": "convert_to_audio"},
    {"text": "Use voice to express this", "intent": "convert_to_audio"},
    {"text": "Give me the spoken output", "intent": "convert_to_audio"},
    {"text": "Speak this passage clearly", "intent": "convert_to_audio"},
    {"text": "I want a voice playback of this", "intent": "convert_to_audio"},
    {"text": "Play this as a voice message", "intent": "convert_to_audio"},
    {"text": "Give me a reading voice of this text", "intent": "convert_to_audio"},
    {"text": "Turn the written part into audio", "intent": "convert_to_audio"},
    {"text": "Let me hear this instead", "intent": "convert_to_audio"},
    {"text": "Produce an audio result for this", "intent": "convert_to_audio"},
    {"text": "I’d like this presented in a vocal form", "intent": "convert_to_audio"},
    {"text": "Use your speech engine to say this", "intent": "convert_to_audio"},
    {"text": "Make a verbal version of this", "intent": "convert_to_audio"},
    {"text": "Convert this text to something I can hear", "intent": "convert_to_audio"},
    {"text": "Please make a sound version of this sentence", "intent": "convert_to_audio"},
    {"text": "Speak this with emotion", "intent": "convert_to_audio"},
    {"text": "Can you say these words out loud?", "intent": "convert_to_audio"},
    {"text": "Turn this into a speech form output", "intent": "convert_to_audio"},
    {"text": "Generate a vocal rendition of this", "intent": "convert_to_audio"},
    {"text": "Speak these lines out", "intent": "convert_to_audio"},
    {"text": "Please say this out loud for me", "intent": "convert_to_audio"},
    {"text": "Let me hear the spoken format", "intent": "convert_to_audio"},
    {"text": "Transform the content to an audio clip", "intent": "convert_to_audio"},
    {"text": "I want a synthetic voice to say this", "intent": "convert_to_audio"},
    {"text": "Produce this as audible speech", "intent": "convert_to_audio"},
    {"text": "I'd like a voice readout of this", "intent": "convert_to_audio"},
    {"text": "Can you turn these words into a podcast voice?", "intent": "convert_to_audio"},
    {"text": "Please read this line for me", "intent": "convert_to_audio"},
    {"text": "Read this into an audio file", "intent": "convert_to_audio"},
    {"text": "I want this section narrated", "intent": "convert_to_audio"},
    {"text": "Say these things for me out loud", "intent": "convert_to_audio"},
    {"text": "Deliver this as speech", "intent": "convert_to_audio"}
]

# %%
# data7 = [
#     ("Turn this into a spoken file", "convert_to_audio"),
#     ("I'd like this text in a voiced format", "convert_to_audio"),
#     ("Please convert my paragraph into speech", "convert_to_audio"),
#     ("Create a vocal version of this text", "convert_to_audio"),
#     ("Audio form of this note, please", "convert_to_audio"),
#     ("Let me listen to this content", "convert_to_audio"),
#     ("Read these lines using voice", "convert_to_audio"),
#     ("Convert the passage to audio format", "convert_to_audio"),
#     ("Transform the message into sound", "convert_to_audio"),
#     ("Please synthesize this into audio", "convert_to_audio"),
#     ("Use voice to read this", "convert_to_audio"),
#     ("Say the content as if in a podcast", "convert_to_audio"),
#     ("I want an MP3 version of these words", "convert_to_audio"),
#     ("Make this text play like a message", "convert_to_audio"),
#     ("Convert this file into audio output", "convert_to_audio"),
#     ("Can you create speech from this file?", "convert_to_audio"),
#     ("Let me hear your voice reading this", "convert_to_audio"),
#     ("Change this into an audible format", "convert_to_audio"),
#     ("Say this out like a newsreader", "convert_to_audio"),
#     ("Please use voice synthesis for this", "convert_to_audio"),
#     ("Transform these lines to speech", "convert_to_audio"),
#     ("I want to hear the following sentence", "convert_to_audio"),
#     ("Play this content using voice", "convert_to_audio"),
#     ("Make this into a speech segment", "convert_to_audio"),
#     ("Generate voice playback for this text", "convert_to_audio"),
#     ("I need to hear this as sound", "convert_to_audio"),
#     ("Say these notes with voice", "convert_to_audio"),
#     ("Read this content like a narrator", "convert_to_audio"),
#     ("Make it sound like a lecture", "convert_to_audio"),
#     ("I'd prefer a voiceover of this", "convert_to_audio"),
#     ("Give this text a voice", "convert_to_audio"),
#     ("I’d appreciate this in audio", "convert_to_audio"),
#     ("Can you play this text aloud?", "convert_to_audio"),
#     ("Make this document soundable", "convert_to_audio"),
#     ("Turn the text into a podcast clip", "convert_to_audio"),
#     ("Convert this sentence to a sound file", "convert_to_audio"),
#     ("Record a podcast-like version of this", "convert_to_audio"),
#     ("Please say these lines for me", "convert_to_audio"),
#     ("Provide voice playback of this", "convert_to_audio"),
#     ("Audible form of the following, please", "convert_to_audio"),
#     ("I would like to hear this in sound", "convert_to_audio"),
#     ("Use a voice to deliver this message", "convert_to_audio"),
#     ("Say these words out loud", "convert_to_audio"),
#     ("Play this sentence back using sound", "convert_to_audio"),
#     ("Can this content be spoken?", "convert_to_audio"),
#     ("Turn the notes into audio narration", "convert_to_audio"),
#     ("Play back this using speech", "convert_to_audio"),
#     ("Please make this file listenable", "convert_to_audio"),
#     ("Give an MP3 output of this content", "convert_to_audio"),
#     ("Read this in a voiceover style", "convert_to_audio"),
#     ("Turn these sentences into speech", "convert_to_audio"),
#     ("Please convert this passage to voice", "convert_to_audio"),
#     ("Convert this writing into verbal format", "convert_to_audio"),
#     ("Narrate this section", "convert_to_audio"),
#     ("Voice these written lines", "convert_to_audio"),
#     ("Can you say this in a natural voice?", "convert_to_audio"),
#     ("Audio playback required for this", "convert_to_audio"),
#     ("Make this text available in audio", "convert_to_audio"),
#     ("Say the words from this paragraph", "convert_to_audio"),
#     ("I want a sound version of this text", "convert_to_audio"),
#     ("Give me a podcast output of this", "convert_to_audio"),
#     ("Speak these notes using AI voice", "convert_to_audio"),
#     ("Generate synthetic voice for this", "convert_to_audio"),
#     ("Please convert this document to spoken English", "convert_to_audio"),
#     ("Voice narration of this sentence needed", "convert_to_audio"),
#     ("Read this aloud like a presentation", "convert_to_audio"),
#     ("Create a readable voice clip", "convert_to_audio"),
#     ("I need this document read out", "convert_to_audio"),
#     ("Play this voice clip", "convert_to_audio"),
#     ("Generate narration for this page", "convert_to_audio"),
#     ("Make this script audible", "convert_to_audio"),
#     ("Please read this message in voice", "convert_to_audio"),
#     ("Make an MP3 narration", "convert_to_audio"),
#     ("Generate a speech recording", "convert_to_audio"),
#     ("Read this using text-to-speech", "convert_to_audio"),
#     ("I want an audio representation of this", "convert_to_audio"),
#     ("Voice playback requested", "convert_to_audio"),
#     ("Make a verbal file of this note", "convert_to_audio"),
#     ("Spoken output needed", "convert_to_audio"),
#     ("Convert my message to sound", "convert_to_audio"),
#     ("Create a reading voice version", "convert_to_audio"),
#     ("Say it like a narrator would", "convert_to_audio"),
#     ("Produce a reading of this text", "convert_to_audio"),
#     ("Speak my paragraph out loud", "convert_to_audio"),
#     ("Let me hear the following message", "convert_to_audio"),
#     ("Sound clip required for this", "convert_to_audio"),
#     ("Use TTS for this content", "convert_to_audio"),
#     ("Play this statement in voice", "convert_to_audio"),
#     ("Generate a reading voice output", "convert_to_audio"),
#     ("I'd like this in podcast voice", "convert_to_audio"),
#     ("Please provide this in MP3 sound", "convert_to_audio"),
#     ("Say it with a friendly voice", "convert_to_audio"),
#     ("Can this be said aloud?", "convert_to_audio"),
#     ("Convert these notes to audible speech", "convert_to_audio"),
#     ("Speak these ideas aloud", "convert_to_audio"),
#     ("Read this like a speaker", "convert_to_audio"),
#     ("Turn this written input into sound", "convert_to_audio"),
#     ("Give me a recorded voice version", "convert_to_audio"),
#     ("Narrate this document", "convert_to_audio"),
#     ("Audio narration of the message, please", "convert_to_audio"),
#     ("I'd like this text to be vocalized", "convert_to_audio"),
#     ("Speak this using synthesized speech", "convert_to_audio"),
# ]

# %%
data7 = [
    {"text": "Turn this into a spoken file", "intent": "convert_to_audio"},
    {"text": "I'd like this text in a voiced format", "intent": "convert_to_audio"},
    {"text": "Please convert my paragraph into speech", "intent": "convert_to_audio"},
    {"text": "Create a vocal version of this text", "intent": "convert_to_audio"},
    {"text": "Audio form of this note, please", "intent": "convert_to_audio"},
    {"text": "Let me listen to this content", "intent": "convert_to_audio"},
    {"text": "Read these lines using voice", "intent": "convert_to_audio"},
    {"text": "Convert the passage to audio format", "intent": "convert_to_audio"},
    {"text": "Transform the message into sound", "intent": "convert_to_audio"},
    {"text": "Please synthesize this into audio", "intent": "convert_to_audio"},
    {"text": "Use voice to read this", "intent": "convert_to_audio"},
    {"text": "Say the content as if in a podcast", "intent": "convert_to_audio"},
    {"text": "I want an MP3 version of these words", "intent": "convert_to_audio"},
    {"text": "Make this text play like a message", "intent": "convert_to_audio"},
    {"text": "Convert this file into audio output", "intent": "convert_to_audio"},
    {"text": "Can you create speech from this file?", "intent": "convert_to_audio"},
    {"text": "Let me hear your voice reading this", "intent": "convert_to_audio"},
    {"text": "Change this into an audible format", "intent": "convert_to_audio"},
    {"text": "Say this out like a newsreader", "intent": "convert_to_audio"},
    {"text": "Please use voice synthesis for this", "intent": "convert_to_audio"},
    {"text": "Transform these lines to speech", "intent": "convert_to_audio"},
    {"text": "I want to hear the following sentence", "intent": "convert_to_audio"},
    {"text": "Play this content using voice", "intent": "convert_to_audio"},
    {"text": "Make this into a speech segment", "intent": "convert_to_audio"},
    {"text": "Generate voice playback for this text", "intent": "convert_to_audio"},
    {"text": "I need to hear this as sound", "intent": "convert_to_audio"},
    {"text": "Say these notes with voice", "intent": "convert_to_audio"},
    {"text": "Read this content like a narrator", "intent": "convert_to_audio"},
    {"text": "Make it sound like a lecture", "intent": "convert_to_audio"},
    {"text": "I'd prefer a voiceover of this", "intent": "convert_to_audio"},
    {"text": "Give this text a voice", "intent": "convert_to_audio"},
    {"text": "I’d appreciate this in audio", "intent": "convert_to_audio"},
    {"text": "Can you play this text aloud?", "intent": "convert_to_audio"},
    {"text": "Make this document soundable", "intent": "convert_to_audio"},
    {"text": "Turn the text into a podcast clip", "intent": "convert_to_audio"},
    {"text": "Convert this sentence to a sound file", "intent": "convert_to_audio"},
    {"text": "Record a podcast-like version of this", "intent": "convert_to_audio"},
    {"text": "Please say these lines for me", "intent": "convert_to_audio"},
    {"text": "Provide voice playback of this", "intent": "convert_to_audio"},
    {"text": "Audible form of the following, please", "intent": "convert_to_audio"},
    {"text": "I would like to hear this in sound", "intent": "convert_to_audio"},
    {"text": "Use a voice to deliver this message", "intent": "convert_to_audio"},
    {"text": "Say these words out loud", "intent": "convert_to_audio"},
    {"text": "Play this sentence back using sound", "intent": "convert_to_audio"},
    {"text": "Can this content be spoken?", "intent": "convert_to_audio"},
    {"text": "Turn the notes into audio narration", "intent": "convert_to_audio"},
    {"text": "Play back this using speech", "intent": "convert_to_audio"},
    {"text": "Please make this file listenable", "intent": "convert_to_audio"},
    {"text": "Give an MP3 output of this content", "intent": "convert_to_audio"},
    {"text": "Read this in a voiceover style", "intent": "convert_to_audio"},
    {"text": "Turn these sentences into speech", "intent": "convert_to_audio"},
    {"text": "Please convert this passage to voice", "intent": "convert_to_audio"},
    {"text": "Convert this writing into verbal format", "intent": "convert_to_audio"},
    {"text": "Narrate this section", "intent": "convert_to_audio"},
    {"text": "Voice these written lines", "intent": "convert_to_audio"},
    {"text": "Can you say this in a natural voice?", "intent": "convert_to_audio"},
    {"text": "Audio playback required for this", "intent": "convert_to_audio"},
    {"text": "Make this text available in audio", "intent": "convert_to_audio"},
    {"text": "Say the words from this paragraph", "intent": "convert_to_audio"},
    {"text": "I want a sound version of this text", "intent": "convert_to_audio"},
    {"text": "Give me a podcast output of this", "intent": "convert_to_audio"},
    {"text": "Speak these notes using AI voice", "intent": "convert_to_audio"},
    {"text": "Generate synthetic voice for this", "intent": "convert_to_audio"},
    {"text": "Please convert this document to spoken English", "intent": "convert_to_audio"},
    {"text": "Voice narration of this sentence needed", "intent": "convert_to_audio"},
    {"text": "Read this aloud like a presentation", "intent": "convert_to_audio"},
    {"text": "Create a readable voice clip", "intent": "convert_to_audio"},
    {"text": "I need this document read out", "intent": "convert_to_audio"},
    {"text": "Play this voice clip", "intent": "convert_to_audio"},
    {"text": "Generate narration for this page", "intent": "convert_to_audio"},
    {"text": "Make this script audible", "intent": "convert_to_audio"},
    {"text": "Please read this message in voice", "intent": "convert_to_audio"},
    {"text": "Make an MP3 narration", "intent": "convert_to_audio"},
    {"text": "Generate a speech recording", "intent": "convert_to_audio"},
    {"text": "Read this using text-to-speech", "intent": "convert_to_audio"},
    {"text": "I want an audio representation of this", "intent": "convert_to_audio"},
    {"text": "Voice playback requested", "intent": "convert_to_audio"},
    {"text": "Make a verbal file of this note", "intent": "convert_to_audio"},
    {"text": "Spoken output needed", "intent": "convert_to_audio"},
    {"text": "Convert my message to sound", "intent": "convert_to_audio"},
    {"text": "Create a reading voice version", "intent": "convert_to_audio"},
    {"text": "Say it like a narrator would", "intent": "convert_to_audio"},
    {"text": "Produce a reading of this text", "intent": "convert_to_audio"},
    {"text": "Speak my paragraph out loud", "intent": "convert_to_audio"},
    {"text": "Let me hear the following message", "intent": "convert_to_audio"},
    {"text": "Sound clip required for this", "intent": "convert_to_audio"},
    {"text": "Use TTS for this content", "intent": "convert_to_audio"},
    {"text": "Play this statement in voice", "intent": "convert_to_audio"},
    {"text": "Generate a reading voice output", "intent": "convert_to_audio"},
    {"text": "I'd like this in podcast voice", "intent": "convert_to_audio"},
    {"text": "Please provide this in MP3 sound", "intent": "convert_to_audio"},
    {"text": "Say it with a friendly voice", "intent": "convert_to_audio"},
    {"text": "Can this be said aloud?", "intent": "convert_to_audio"},
    {"text": "Convert these notes to audible speech", "intent": "convert_to_audio"},
    {"text": "Speak these ideas aloud", "intent": "convert_to_audio"},
    {"text": "Read this like a speaker", "intent": "convert_to_audio"},
    {"text": "Turn this written input into sound", "intent": "convert_to_audio"},
    {"text": "Give me a recorded voice version", "intent": "convert_to_audio"},
    {"text": "Narrate this document", "intent": "convert_to_audio"},
    {"text": "Audio narration of the message, please", "intent": "convert_to_audio"},
    {"text": "I'd like this text to be vocalized", "intent": "convert_to_audio"},
    {"text": "Speak this using synthesized speech", "intent": "convert_to_audio"}
]

# %%
data8 = [
    {"text": "Please read this aloud for me", "intent": "convert_to_audio"},
    {"text": "Make a voice version of this text", "intent": "convert_to_audio"},
    {"text": "Turn this text content into speech", "intent": "convert_to_audio"},
    {"text": "Play this paragraph as audio", "intent": "convert_to_audio"},
    {"text": "Convert these words to sound", "intent": "convert_to_audio"},
    {"text": "Speak this message out loud", "intent": "convert_to_audio"},
    {"text": "Give me a spoken file of this", "intent": "convert_to_audio"},
    {"text": "Create an audio clip from this text", "intent": "convert_to_audio"},
    {"text": "I want to listen to this text", "intent": "convert_to_audio"},
    {"text": "Make a reading of this sentence", "intent": "convert_to_audio"},
    {"text": "Produce an audio track from this", "intent": "convert_to_audio"},
    {"text": "Let me hear this in voice format", "intent": "convert_to_audio"},
    {"text": "Say this text with emotion", "intent": "convert_to_audio"},
    {"text": "Please synthesize speech from this", "intent": "convert_to_audio"},
    {"text": "I want an audible reading of this", "intent": "convert_to_audio"},
    {"text": "Read this text as a voice message", "intent": "convert_to_audio"},
    {"text": "Turn this script into a spoken message", "intent": "convert_to_audio"},
    {"text": "Convert my text input to audio", "intent": "convert_to_audio"},
    {"text": "Play this text using speech output", "intent": "convert_to_audio"},
    {"text": "Please make this text soundable", "intent": "convert_to_audio"},
    {"text": "Give me a vocal version of this", "intent": "convert_to_audio"},
    {"text": "Use TTS to say this text", "intent": "convert_to_audio"},
    {"text": "Can you make an audio file of this?", "intent": "convert_to_audio"},
    {"text": "Speak these words aloud for me", "intent": "convert_to_audio"},
    {"text": "Create a speech version of this message", "intent": "convert_to_audio"},
    {"text": "I want to hear this paragraph", "intent": "convert_to_audio"},
    {"text": "Please read this note using voice", "intent": "convert_to_audio"},
    {"text": "Generate an audio narration", "intent": "convert_to_audio"},
    {"text": "Turn this note into a voice clip", "intent": "convert_to_audio"},
    {"text": "Read this text with your voice", "intent": "convert_to_audio"},
    {"text": "Play this message aloud", "intent": "convert_to_audio"},
    {"text": "Convert this document to spoken word", "intent": "convert_to_audio"},
    {"text": "I need a voice reading of this", "intent": "convert_to_audio"},
    {"text": "Say this paragraph out loud", "intent": "convert_to_audio"},
    {"text": "Make a spoken audio from this text", "intent": "convert_to_audio"},
    {"text": "Create a voiceover for this text", "intent": "convert_to_audio"},
    {"text": "Turn these sentences into audio", "intent": "convert_to_audio"},
    {"text": "Play this writing as speech", "intent": "convert_to_audio"},
    {"text": "Convert these lines to spoken word", "intent": "convert_to_audio"},
    {"text": "Give me an audio playback of this", "intent": "convert_to_audio"},
    {"text": "Speak this passage aloud", "intent": "convert_to_audio"},
    {"text": "Please make a voice file of this", "intent": "convert_to_audio"},
    {"text": "Say this text in a natural voice", "intent": "convert_to_audio"},
    {"text": "Turn this text into a voice recording", "intent": "convert_to_audio"},
    {"text": "Produce a spoken version of this", "intent": "convert_to_audio"},
    {"text": "Use your voice to read this", "intent": "convert_to_audio"},
    {"text": "Make this text listenable", "intent": "convert_to_audio"},
    {"text": "Can you vocalize this message?", "intent": "convert_to_audio"},
    {"text": "Read these words with emotion", "intent": "convert_to_audio"},
    {"text": "Please create a voice message for this", "intent": "convert_to_audio"},
    {"text": "I want an MP3 reading of this", "intent": "convert_to_audio"},
    {"text": "Generate speech from this content", "intent": "convert_to_audio"},
    {"text": "Turn the written text into sound", "intent": "convert_to_audio"},
    {"text": "Speak this as a voice note", "intent": "convert_to_audio"},
    {"text": "Make a voice output for this text", "intent": "convert_to_audio"},
    {"text": "Read this aloud with your voice", "intent": "convert_to_audio"},
    {"text": "Create an audio narration from this", "intent": "convert_to_audio"},
    {"text": "Say these words as a message", "intent": "convert_to_audio"},
    {"text": "Produce a vocal recording of this", "intent": "convert_to_audio"},
    {"text": "Please convert this text to sound", "intent": "convert_to_audio"},
    {"text": "Play this as spoken text", "intent": "convert_to_audio"},
    {"text": "Make an audio version of this", "intent": "convert_to_audio"},
    {"text": "Voice this paragraph", "intent": "convert_to_audio"},
    {"text": "Turn this text into a voice clip", "intent": "convert_to_audio"},
    {"text": "Give me spoken audio for this", "intent": "convert_to_audio"},
    {"text": "Use speech synthesis for this text", "intent": "convert_to_audio"},
    {"text": "Make a vocal playback of this", "intent": "convert_to_audio"},
    {"text": "Read this as a voice message", "intent": "convert_to_audio"},
    {"text": "Convert these notes to audio", "intent": "convert_to_audio"},
    {"text": "Can you say this text aloud?", "intent": "convert_to_audio"},
    {"text": "Turn these words into speech", "intent": "convert_to_audio"},
    {"text": "Make a voice recording of this text", "intent": "convert_to_audio"},
    {"text": "Read this sentence with voice", "intent": "convert_to_audio"},
    {"text": "Create an audio file from this", "intent": "convert_to_audio"},
    {"text": "Please speak this content", "intent": "convert_to_audio"},
    {"text": "Make an audible version of this", "intent": "convert_to_audio"},
    {"text": "I want this spoken aloud", "intent": "convert_to_audio"},
    {"text": "Turn this text into a speech file", "intent": "convert_to_audio"},
    {"text": "Say this message using voice", "intent": "convert_to_audio"},
    {"text": "Convert this paragraph to speech", "intent": "convert_to_audio"},
    {"text": "Make this message vocal", "intent": "convert_to_audio"},
    {"text": "Create a spoken word file", "intent": "convert_to_audio"},
    {"text": "Please voice this text", "intent": "convert_to_audio"},
    {"text": "Produce a speech version of this", "intent": "convert_to_audio"},
    {"text": "Speak these sentences", "intent": "convert_to_audio"},
    {"text": "Play this paragraph using voice", "intent": "convert_to_audio"},
    {"text": "Make an audio playback for this", "intent": "convert_to_audio"},
    {"text": "Turn this note into speech", "intent": "convert_to_audio"},
    {"text": "Give me a voice version of this", "intent": "convert_to_audio"}
]

# %%
data9 = [
    {"text": "Please give me a voice reading", "intent": "convert_to_audio"},
    {"text": "Convert this message to spoken audio", "intent": "convert_to_audio"},
    {"text": "Read these notes aloud", "intent": "convert_to_audio"},
    {"text": "Create an audio narration for this text", "intent": "convert_to_audio"},
    {"text": "Make a speech version of this paragraph", "intent": "convert_to_audio"},
    {"text": "Play this as a voice message", "intent": "convert_to_audio"},
    {"text": "Say these words in audio format", "intent": "convert_to_audio"},
    {"text": "Turn this written content into speech", "intent": "convert_to_audio"},
    {"text": "Generate a voice file from this note", "intent": "convert_to_audio"},
    {"text": "I want an audio version of this message", "intent": "convert_to_audio"},
    {"text": "Please vocalize this text", "intent": "convert_to_audio"},
    {"text": "Speak this out loud for me", "intent": "convert_to_audio"},
    {"text": "Make an audio clip from this text", "intent": "convert_to_audio"},
    {"text": "Convert the following text to speech", "intent": "convert_to_audio"},
    {"text": "Give me a spoken word recording", "intent": "convert_to_audio"},
    {"text": "Play this text as audio", "intent": "convert_to_audio"},
    {"text": "Please read this note using speech", "intent": "convert_to_audio"},
    {"text": "Turn these sentences into spoken words", "intent": "convert_to_audio"},
    {"text": "Create a voice output of this content", "intent": "convert_to_audio"},
    {"text": "Say this paragraph aloud", "intent": "convert_to_audio"},
    {"text": "Make this text audible", "intent": "convert_to_audio"},
    {"text": "Produce an audio reading for this", "intent": "convert_to_audio"},
    {"text": "Use speech to read this", "intent": "convert_to_audio"},
    {"text": "I want to hear this text spoken", "intent": "convert_to_audio"},
    {"text": "Please speak this message", "intent": "convert_to_audio"},
    {"text": "Make a podcast-style recording of this", "intent": "convert_to_audio"},
    {"text": "Generate speech audio from this", "intent": "convert_to_audio"},
    {"text": "Turn this note into an audio clip", "intent": "convert_to_audio"},
    {"text": "Read this text like an audiobook", "intent": "convert_to_audio"},
    {"text": "Play this note as voice output", "intent": "convert_to_audio"},
    {"text": "Convert this sentence to spoken audio", "intent": "convert_to_audio"},
    {"text": "Give me a voice narration for this", "intent": "convert_to_audio"},
    {"text": "Speak out these notes", "intent": "convert_to_audio"},
    {"text": "Make an audible file from this text", "intent": "convert_to_audio"},
    {"text": "Read this paragraph using your voice", "intent": "convert_to_audio"},
    {"text": "Please generate a voice file", "intent": "convert_to_audio"},
    {"text": "Turn this writing into a spoken file", "intent": "convert_to_audio"},
    {"text": "Make a sound version of this sentence", "intent": "convert_to_audio"},
    {"text": "Say this text with natural voice", "intent": "convert_to_audio"},
    {"text": "Produce a vocal version of this", "intent": "convert_to_audio"},
    {"text": "Please read this aloud", "intent": "convert_to_audio"},
    {"text": "Convert this note into speech", "intent": "convert_to_audio"},
    {"text": "Make a voice clip from this content", "intent": "convert_to_audio"},
    {"text": "Speak this message clearly", "intent": "convert_to_audio"},
    {"text": "Create a speech file from this text", "intent": "convert_to_audio"},
    {"text": "Turn these words into a voice recording", "intent": "convert_to_audio"},
    {"text": "Give me an audio playback of this text", "intent": "convert_to_audio"},
    {"text": "Please say these sentences out loud", "intent": "convert_to_audio"},
    {"text": "Make a voice output file from this", "intent": "convert_to_audio"},
    {"text": "Read this document using your voice", "intent": "convert_to_audio"},
    {"text": "Produce an audio narration of this note", "intent": "convert_to_audio"},
    {"text": "Turn this text into audible speech", "intent": "convert_to_audio"},
    {"text": "Say this note aloud", "intent": "convert_to_audio"},
    {"text": "Create a vocal recording of this message", "intent": "convert_to_audio"},
    {"text": "Make an audio file for this text", "intent": "convert_to_audio"},
    {"text": "Speak these words clearly", "intent": "convert_to_audio"},
    {"text": "Turn this text to a sound file", "intent": "convert_to_audio"},
    {"text": "Please read this passage out loud", "intent": "convert_to_audio"},
    {"text": "Make a spoken audio clip from this", "intent": "convert_to_audio"},
    {"text": "Produce a voice message from this text", "intent": "convert_to_audio"},
    {"text": "Give me a vocal version of this note", "intent": "convert_to_audio"},
    {"text": "Speak this paragraph as a voice message", "intent": "convert_to_audio"},
    {"text": "Turn this content into audio", "intent": "convert_to_audio"},
    {"text": "Make this text audible for me", "intent": "convert_to_audio"},
    {"text": "Convert these words into voice", "intent": "convert_to_audio"},
    {"text": "Please generate a voice message", "intent": "convert_to_audio"},
    {"text": "Read this aloud with emotion", "intent": "convert_to_audio"},
    {"text": "Create an audio recording of this text", "intent": "convert_to_audio"},
    {"text": "Say these notes using speech", "intent": "convert_to_audio"},
    {"text": "Make a voice recording for this", "intent": "convert_to_audio"},
    {"text": "Turn this paragraph into an audio file", "intent": "convert_to_audio"},
    {"text": "Give me speech output of this text", "intent": "convert_to_audio"},
    {"text": "Please read this message in voice", "intent": "convert_to_audio"},
    {"text": "Make a spoken word audio file", "intent": "convert_to_audio"},
    {"text": "Produce audio for this paragraph", "intent": "convert_to_audio"},
    {"text": "Turn these notes into a voice clip", "intent": "convert_to_audio"},
    {"text": "Say this message clearly", "intent": "convert_to_audio"},
    {"text": "Create a speech audio from this", "intent": "convert_to_audio"},
    {"text": "Make this content into spoken words", "intent": "convert_to_audio"},
    {"text": "Speak this text as an audio message", "intent": "convert_to_audio"},
    {"text": "Turn this text into vocal output", "intent": "convert_to_audio"},
    {"text": "Make an audio playback of this message", "intent": "convert_to_audio"},
    {"text": "Please vocalize these sentences", "intent": "convert_to_audio"},
    {"text": "Read this note using your voice", "intent": "convert_to_audio"},
    {"text": "Generate speech from these words", "intent": "convert_to_audio"},
    {"text": "Give me an audible file of this text", "intent": "convert_to_audio"},
    {"text": "Turn this text into spoken language", "intent": "convert_to_audio"},
    {"text": "Make a voice file from this paragraph", "intent": "convert_to_audio"},
    {"text": "Speak this text like a narrator", "intent": "convert_to_audio"},
    {"text": "Please make this text into an audio file", "intent": "convert_to_audio"},
    {"text": "Convert this to spoken voice", "intent": "convert_to_audio"},
    {"text": "Create a voice note from this message", "intent": "convert_to_audio"},
    {"text": "Read this text as an audio clip", "intent": "convert_to_audio"},
    {"text": "Turn these words into an audible message", "intent": "convert_to_audio"},
    {"text": "Give me an audio message of this", "intent": "convert_to_audio"}
]

# %%
data10 = [
    {"text": "I want to hear this read out", "intent": "convert_to_audio"},
    {"text": "Read this aloud to me", "intent": "convert_to_audio"},
    {"text": "Use audio to present this information", "intent": "convert_to_audio"},
    {"text": "Produce a speech file for this", "intent": "convert_to_audio"},
    {"text": "Let me listen to this content", "intent": "convert_to_audio"},
    {"text": "I’d like a voice-based version", "intent": "convert_to_audio"},
    {"text": "Can this be turned into an audio summary?", "intent": "convert_to_audio"},
    {"text": "Play a voice response for this", "intent": "convert_to_audio"},
    {"text": "Please audio generate this text", "intent": "convert_to_audio"},
    {"text": "Say this using a synthetic narrator", "intent": "convert_to_audio"},
    {"text": "Please give me a voice output", "intent": "convert_to_audio"},
    {"text": "Use voice to explain this", "intent": "convert_to_audio"},
    {"text": "I'd like a verbal version of the input", "intent": "convert_to_audio"},
    {"text": "Say these lines like a virtual assistant", "intent": "convert_to_audio"},
    {"text": "Speak this out for me", "intent": "convert_to_audio"},
    {"text": "Use artificial voice to narrate this", "intent": "convert_to_audio"},
    {"text": "I want this read out with intonation", "intent": "convert_to_audio"},
    {"text": "Give me a computer-generated voice of this", "intent": "convert_to_audio"},
    {"text": "Create a voice interpretation of this", "intent": "convert_to_audio"},
    {"text": "Turn this written paragraph into a spoken one", "intent": "convert_to_audio"},
    {"text": "Let me hear what this would sound like", "intent": "convert_to_audio"},
    {"text": "Provide an audible translation", "intent": "convert_to_audio"},
    {"text": "Speak this out like Siri", "intent": "convert_to_audio"},
    {"text": "Play back the spoken version", "intent": "convert_to_audio"},
    {"text": "Turn this into something vocal", "intent": "convert_to_audio"},
    {"text": "I'd like to hear how this sounds", "intent": "convert_to_audio"},
    {"text": "Convert this to a playback-friendly format", "intent": "convert_to_audio"},
    {"text": "Read aloud like a radio host", "intent": "convert_to_audio"},
    {"text": "Make this readable through audio", "intent": "convert_to_audio"},
    {"text": "Please give me an MP3 version with voice", "intent": "convert_to_audio"},
    {"text": "Can you provide a sound-based explanation?", "intent": "convert_to_audio"},
    {"text": "Use voice output to present this sentence", "intent": "convert_to_audio"},
    {"text": "Let me experience this via sound", "intent": "convert_to_audio"},
    {"text": "Tell me this line", "intent": "convert_to_audio"},
    {"text": "Vocalize this line in your voice", "intent": "convert_to_audio"},
    {"text": "Put this in voice message format", "intent": "convert_to_audio"},
    {"text": "Give this in a speech bubble format", "intent": "convert_to_audio"},
    {"text": "Speak this to me like Alexa", "intent": "convert_to_audio"},
    {"text": "Read it out loud digitally", "intent": "convert_to_audio"},
    {"text": "Make this paragraph audible", "intent": "convert_to_audio"},
    {"text": "I'd like a robotic narration of this", "intent": "convert_to_audio"},
    {"text": "Create a vocal version of this document", "intent": "convert_to_audio"},
    {"text": "Speak this just like an audiobook", "intent": "convert_to_audio"},
    {"text": "Convert this for hearing", "intent": "convert_to_audio"},
    {"text": "Give an audible review of this", "intent": "convert_to_audio"},
    {"text": "Read this aloud with emotion", "intent": "convert_to_audio"},
    {"text": "Play the sentence using sound", "intent": "convert_to_audio"},
    {"text": "Say this using your synthetic voice generator", "intent": "convert_to_audio"},
    {"text": "Read this with pitch and clarity", "intent": "convert_to_audio"},
    {"text": "Can I hear the digital speech of this?", "intent": "convert_to_audio"},
    {"text": "Convert the statement into a listenable format", "intent": "convert_to_audio"},
    {"text": "Give me a podcast-style playback", "intent": "convert_to_audio"},
    {"text": "I want this expressed through voice", "intent": "convert_to_audio"},
    {"text": "Play this text via voice reader", "intent": "convert_to_audio"},
    {"text": "Speak this paragraph out loud", "intent": "convert_to_audio"},
    {"text": "Generate a talking version of this", "intent": "convert_to_audio"},
    {"text": "Say this out using speech tools", "intent": "convert_to_audio"},
    {"text": "Voice-over this part of the text", "intent": "convert_to_audio"},
    {"text": "Can I get a vocalized version of this?", "intent": "convert_to_audio"},
    {"text": "Make this into voice synthesis output", "intent": "convert_to_audio"},
    {"text": "I'd like to listen to this line", "intent": "convert_to_audio"},
    {"text": "Narrate the following text", "intent": "convert_to_audio"},
    {"text": "Say this like a digital speaker", "intent": "convert_to_audio"},
    {"text": "Read this content using artificial speech", "intent": "convert_to_audio"},
    {"text": "Give a voice demonstration", "intent": "convert_to_audio"},
    {"text": "Speak the following as though presenting", "intent": "convert_to_audio"},
    {"text": "Turn it into a media file with audio", "intent": "convert_to_audio"},
    {"text": "I want a vocal output of this", "intent": "convert_to_audio"},
    {"text": "Use a synthesized tone to read this", "intent": "convert_to_audio"},
    {"text": "Speak these lines with a calm tone", "intent": "convert_to_audio"},
    {"text": "Make this content playable through audio", "intent": "convert_to_audio"},
    {"text": "I'd like an MP3 narration", "intent": "convert_to_audio"},
    {"text": "Can you speak these words back?", "intent": "convert_to_audio"},
    {"text": "Use voice AI to deliver this sentence", "intent": "convert_to_audio"},
    {"text": "Let me hear this section", "intent": "convert_to_audio"},
    {"text": "Convert this paragraph into a sound file", "intent": "convert_to_audio"},
    {"text": "Produce a high-quality voiceover", "intent": "convert_to_audio"},
    {"text": "Say this line in an announcer's voice", "intent": "convert_to_audio"},
    {"text": "Transform this text to be heard", "intent": "convert_to_audio"},
    {"text": "Please turn this into listenable speech", "intent": "convert_to_audio"},
    {"text": "Give me an audio feed of this", "intent": "convert_to_audio"},
    {"text": "Play this phrase using your voice tech", "intent": "convert_to_audio"},
    {"text": "Speak this line like an AI assistant", "intent": "convert_to_audio"},
    {"text": "I want the voice version of the document", "intent": "convert_to_audio"},
    {"text": "Please convert the content to voice tone", "intent": "convert_to_audio"},
    {"text": "Let me hear a digital voice say this", "intent": "convert_to_audio"},
    {"text": "Convert this into vocal storytelling", "intent": "convert_to_audio"},
    {"text": "I want this spoken using your voice engine", "intent": "convert_to_audio"},
    {"text": "Say this aloud in a polite tone", "intent": "convert_to_audio"},
    {"text": "Produce audio for this text content", "intent": "convert_to_audio"},
    {"text": "Play it back like a speech", "intent": "convert_to_audio"},
    {"text": "Make this sentence audible via speaker", "intent": "convert_to_audio"},
    {"text": "Can you voice this excerpt?", "intent": "convert_to_audio"},
    {"text": "I'd like to hear the voice format of this", "intent": "convert_to_audio"},
    {"text": "Please synthesize this content as voice", "intent": "convert_to_audio"},
    {"text": "Can you output this in a spoken form?", "intent": "convert_to_audio"}
]

# %%
data11 = [
    {"text": "Please convert this text into audio", "intent": "convert_to_audio"},
    {"text": "Make this text into a spoken message", "intent": "convert_to_audio"},
    {"text": "Give me an audio playback of these words", "intent": "convert_to_audio"},
    {"text": "Turn this sentence into voice", "intent": "convert_to_audio"},
    {"text": "Read this text aloud for me", "intent": "convert_to_audio"},
    {"text": "Produce an audio version of this content", "intent": "convert_to_audio"},
    {"text": "Speak this text in a natural voice", "intent": "convert_to_audio"},
    {"text": "Generate a speech recording of this", "intent": "convert_to_audio"},
    {"text": "Make a vocal output for this note", "intent": "convert_to_audio"},
    {"text": "Please read this paragraph as audio", "intent": "convert_to_audio"},
    {"text": "Turn these notes into a voice message", "intent": "convert_to_audio"},
    {"text": "Give me a spoken audio clip of this", "intent": "convert_to_audio"},
    {"text": "Say this message using speech synthesis", "intent": "convert_to_audio"},
    {"text": "Convert this written text to voice", "intent": "convert_to_audio"},
    {"text": "Make this content available as audio", "intent": "convert_to_audio"},
    {"text": "Please say these words in a clear voice", "intent": "convert_to_audio"},
    {"text": "Create a speech file for this text", "intent": "convert_to_audio"},
    {"text": "Read this note out loud", "intent": "convert_to_audio"},
    {"text": "Turn this writing into spoken words", "intent": "convert_to_audio"},
    {"text": "Produce voice output for this sentence", "intent": "convert_to_audio"},
    {"text": "Make an audio file from this paragraph", "intent": "convert_to_audio"},
    {"text": "Say these lines aloud", "intent": "convert_to_audio"},
    {"text": "Give me a vocal reading of this message", "intent": "convert_to_audio"},
    {"text": "Turn this text into a sound clip", "intent": "convert_to_audio"},
    {"text": "Please generate a spoken word version", "intent": "convert_to_audio"},
    {"text": "Read these sentences with emotion", "intent": "convert_to_audio"},
    {"text": "Make a voice version of this content", "intent": "convert_to_audio"},
    {"text": "Speak this note in an audio file", "intent": "convert_to_audio"},
    {"text": "Produce an audible file from this text", "intent": "convert_to_audio"},
    {"text": "Create a vocal recording of these notes", "intent": "convert_to_audio"},
    {"text": "Say this paragraph out loud", "intent": "convert_to_audio"},
    {"text": "Convert this content to a spoken file", "intent": "convert_to_audio"},
    {"text": "Make an audio playback of these words", "intent": "convert_to_audio"},
    {"text": "Please read this text with voice", "intent": "convert_to_audio"},
    {"text": "Turn this note into a voice recording", "intent": "convert_to_audio"},
    {"text": "Speak this text like a narrator", "intent": "convert_to_audio"},
    {"text": "Generate speech from this writing", "intent": "convert_to_audio"},
    {"text": "Make a spoken audio clip from these lines", "intent": "convert_to_audio"},
    {"text": "Give me an audio file of this message", "intent": "convert_to_audio"},
    {"text": "Turn this text into vocal sound", "intent": "convert_to_audio"},
    {"text": "Please produce an audio reading", "intent": "convert_to_audio"},
    {"text": "Read this sentence out loud", "intent": "convert_to_audio"},
    {"text": "Make a voice file for these sentences", "intent": "convert_to_audio"},
    {"text": "Say these words as speech", "intent": "convert_to_audio"},
    {"text": "Create an audio recording for this", "intent": "convert_to_audio"},
    {"text": "Turn this message into a sound file", "intent": "convert_to_audio"},
    {"text": "Produce an audible version of this text", "intent": "convert_to_audio"},
    {"text": "Read these words with your voice", "intent": "convert_to_audio"},
    {"text": "Make this note into spoken audio", "intent": "convert_to_audio"},
    {"text": "Please vocalize this paragraph", "intent": "convert_to_audio"},
    {"text": "Turn this text into a voice message", "intent": "convert_to_audio"},
    {"text": "Speak this message clearly", "intent": "convert_to_audio"},
    {"text": "Create a spoken word file from this", "intent": "convert_to_audio"},
    {"text": "Make an audio clip from these words", "intent": "convert_to_audio"},
    {"text": "Read this text like a story", "intent": "convert_to_audio"},
    {"text": "Produce speech from this sentence", "intent": "convert_to_audio"},
    {"text": "Say this note using natural voice", "intent": "convert_to_audio"},
    {"text": "Turn this content into audio playback", "intent": "convert_to_audio"},
    {"text": "Please create a voice recording of this", "intent": "convert_to_audio"},
    {"text": "Make a vocal message from these notes", "intent": "convert_to_audio"},
    {"text": "Read these sentences out loud", "intent": "convert_to_audio"},
    {"text": "Convert this paragraph to speech", "intent": "convert_to_audio"},
    {"text": "Give me a voice playback of this sentence", "intent": "convert_to_audio"},
    {"text": "Turn this text into audio speech", "intent": "convert_to_audio"},
    {"text": "Make this writing into voice output", "intent": "convert_to_audio"},
    {"text": "Speak these words out loud for me", "intent": "convert_to_audio"},
    {"text": "Create an audio message from this text", "intent": "convert_to_audio"},
    {"text": "Please read this note aloud", "intent": "convert_to_audio"},
    {"text": "Make a voice version of this message", "intent": "convert_to_audio"},
    {"text": "Say this text with expression", "intent": "convert_to_audio"},
    {"text": "Produce a spoken recording of this", "intent": "convert_to_audio"},
    {"text": "Turn these notes into voice audio", "intent": "convert_to_audio"},
    {"text": "Read this message with clarity", "intent": "convert_to_audio"},
    {"text": "Generate a vocal file for this text", "intent": "convert_to_audio"},
    {"text": "Please speak this paragraph clearly", "intent": "convert_to_audio"},
    {"text": "Make an audio narration of this note", "intent": "convert_to_audio"},
    {"text": "Turn this writing into an audio file", "intent": "convert_to_audio"},
    {"text": "Give me a voice file of these words", "intent": "convert_to_audio"},
    {"text": "Read this text as an audio message", "intent": "convert_to_audio"},
    {"text": "Please produce speech from this note", "intent": "convert_to_audio"},
    {"text": "Say these lines using voice output", "intent": "convert_to_audio"},
    {"text": "Make a spoken audio file from this", "intent": "convert_to_audio"},
    {"text": "Turn this message into spoken words", "intent": "convert_to_audio"},
    {"text": "Create a voice playback from these notes", "intent": "convert_to_audio"},
    {"text": "Read this paragraph in an audio format", "intent": "convert_to_audio"},
    {"text": "Produce a vocal message from this", "intent": "convert_to_audio"},
    {"text": "Please say this message out loud", "intent": "convert_to_audio"}
]

# %%
data12 = [
    {"text": "Can you convert this text into spoken words?", "intent": "convert_to_audio"},
    {"text": "Please read this aloud for me", "intent": "convert_to_audio"},
    {"text": "Make an audio version of this text", "intent": "convert_to_audio"},
    {"text": "Turn this sentence into a voice message", "intent": "convert_to_audio"},
    {"text": "I want this text spoken", "intent": "convert_to_audio"},
    {"text": "Give me an audio playback of this paragraph", "intent": "convert_to_audio"},
    {"text": "Speak this text using your voice", "intent": "convert_to_audio"},
    {"text": "Produce a sound file from this writing", "intent": "convert_to_audio"},
    {"text": "Make a voice recording of this content", "intent": "convert_to_audio"},
    {"text": "Read these sentences out loud", "intent": "convert_to_audio"},
    {"text": "Please generate a spoken version of this", "intent": "convert_to_audio"},
    {"text": "Turn this note into an audio file", "intent": "convert_to_audio"},
    {"text": "Say this message aloud", "intent": "convert_to_audio"},
    {"text": "Create an audio clip of this text", "intent": "convert_to_audio"},
    {"text": "Make a vocal recording from these words", "intent": "convert_to_audio"},
    {"text": "Convert this paragraph into voice", "intent": "convert_to_audio"},
    {"text": "Read this text with clear voice", "intent": "convert_to_audio"},
    {"text": "Please produce speech from this sentence", "intent": "convert_to_audio"},
    {"text": "Give me a voice message from this writing", "intent": "convert_to_audio"},
    {"text": "Speak this note out loud", "intent": "convert_to_audio"},
    {"text": "Make this text audible", "intent": "convert_to_audio"},
    {"text": "Turn this writing into spoken audio", "intent": "convert_to_audio"},
    {"text": "Say these lines as a voice recording", "intent": "convert_to_audio"},
    {"text": "Create an audio version of this message", "intent": "convert_to_audio"},
    {"text": "Please read this note aloud", "intent": "convert_to_audio"},
    {"text": "Produce a spoken audio file from this text", "intent": "convert_to_audio"},
    {"text": "Make a voiceover of this sentence", "intent": "convert_to_audio"},
    {"text": "Turn this text into vocal output", "intent": "convert_to_audio"},
    {"text": "Give me a reading voice of this paragraph", "intent": "convert_to_audio"},
    {"text": "Speak this message with natural tone", "intent": "convert_to_audio"},
    {"text": "Create a speech file from this content", "intent": "convert_to_audio"},
    {"text": "Convert this note into an audio clip", "intent": "convert_to_audio"},
    {"text": "Please say this sentence aloud", "intent": "convert_to_audio"},
    {"text": "Make a voice message from these words", "intent": "convert_to_audio"},
    {"text": "Read this text in a clear voice", "intent": "convert_to_audio"},
    {"text": "Produce a vocal version of this note", "intent": "convert_to_audio"},
    {"text": "Turn these words into an audio file", "intent": "convert_to_audio"},
    {"text": "Say this paragraph in a spoken form", "intent": "convert_to_audio"},
    {"text": "Create a voice recording from this sentence", "intent": "convert_to_audio"},
    {"text": "Make this text into a sound message", "intent": "convert_to_audio"},
    {"text": "Please read these words aloud", "intent": "convert_to_audio"},
    {"text": "Turn this message into vocal speech", "intent": "convert_to_audio"},
    {"text": "Speak this note clearly", "intent": "convert_to_audio"},
    {"text": "Produce an audio clip for this writing", "intent": "convert_to_audio"},
    {"text": "Give me a spoken message from this text", "intent": "convert_to_audio"},
    {"text": "Make a voice recording of these sentences", "intent": "convert_to_audio"},
    {"text": "Turn this text into an audio playback", "intent": "convert_to_audio"},
    {"text": "Read this note as speech", "intent": "convert_to_audio"},
    {"text": "Please generate a voice file for this message", "intent": "convert_to_audio"},
    {"text": "Say these words in a vocal format", "intent": "convert_to_audio"},
    {"text": "Create a spoken word file from this text", "intent": "convert_to_audio"},
    {"text": "Make this paragraph into an audio message", "intent": "convert_to_audio"},
    {"text": "Turn this content into speech", "intent": "convert_to_audio"},
    {"text": "Speak this writing with expression", "intent": "convert_to_audio"},
    {"text": "Produce a voiceover from this note", "intent": "convert_to_audio"},
    {"text": "Read this message aloud for me", "intent": "convert_to_audio"},
    {"text": "Give me a vocal reading of this text", "intent": "convert_to_audio"},
    {"text": "Make an audio message out of this sentence", "intent": "convert_to_audio"},
    {"text": "Turn this text into a voice note", "intent": "convert_to_audio"},
    {"text": "Please say these sentences aloud", "intent": "convert_to_audio"},
    {"text": "Create a voice clip from this paragraph", "intent": "convert_to_audio"},
    {"text": "Make a spoken version of this note", "intent": "convert_to_audio"},
    {"text": "Turn this writing into a speech file", "intent": "convert_to_audio"},
    {"text": "Say this message clearly", "intent": "convert_to_audio"},
    {"text": "Produce an audio reading of this text", "intent": "convert_to_audio"},
    {"text": "Read these words with natural voice", "intent": "convert_to_audio"},
    {"text": "Make this note into vocal audio", "intent": "convert_to_audio"},
    {"text": "Turn this paragraph into an audio file", "intent": "convert_to_audio"},
    {"text": "Please create a spoken message from this", "intent": "convert_to_audio"},
    {"text": "Say these lines with emotion", "intent": "convert_to_audio"},
    {"text": "Produce a voice recording of these sentences", "intent": "convert_to_audio"},
    {"text": "Read this text like a story", "intent": "convert_to_audio"},
    {"text": "Make a vocal version of this message", "intent": "convert_to_audio"},
    {"text": "Turn this sentence into speech", "intent": "convert_to_audio"},
    {"text": "Give me an audio file for this writing", "intent": "convert_to_audio"},
    {"text": "Speak this note with clarity", "intent": "convert_to_audio"},
    {"text": "Create a voice message from this paragraph", "intent": "convert_to_audio"},
    {"text": "Please read this content aloud", "intent": "convert_to_audio"},
    {"text": "Make an audio clip from these sentences", "intent": "convert_to_audio"},
    {"text": "Turn this text into a vocal message", "intent": "convert_to_audio"},
    {"text": "Say this paragraph with expression", "intent": "convert_to_audio"},
    {"text": "Produce a spoken word message from this", "intent": "convert_to_audio"},
    {"text": "Read this note in a clear voice", "intent": "convert_to_audio"},
    {"text": "Make a voice file of these words", "intent": "convert_to_audio"},
    {"text": "Turn this writing into vocal speech", "intent": "convert_to_audio"},
    {"text": "Speak this message out loud for me", "intent": "convert_to_audio"},
    {"text": "Create an audio recording of this note", "intent": "convert_to_audio"},
    {"text": "Please say this sentence clearly", "intent": "convert_to_audio"},
    {"text": "Make a spoken recording of this text", "intent": "convert_to_audio"},
    {"text": "Turn these words into an audio recording", "intent": "convert_to_audio"}
]

# %%
data13 = [
    {"text": "Convert this text into an audio file", "intent": "convert_to_audio"},
    {"text": "Please read this message out loud", "intent": "convert_to_audio"},
    {"text": "Make a voice version of this paragraph", "intent": "convert_to_audio"},
    {"text": "Turn these words into spoken audio", "intent": "convert_to_audio"},
    {"text": "I want to hear this as a voice message", "intent": "convert_to_audio"},
    {"text": "Speak this text clearly", "intent": "convert_to_audio"},
    {"text": "Produce an audio reading of this note", "intent": "convert_to_audio"},
    {"text": "Make this sentence into a speech file", "intent": "convert_to_audio"},
    {"text": "Give me a vocal playback of this text", "intent": "convert_to_audio"},
    {"text": "Please say this paragraph aloud", "intent": "convert_to_audio"},
    {"text": "Create an audio message from this content", "intent": "convert_to_audio"},
    {"text": "Turn this writing into a voice clip", "intent": "convert_to_audio"},
    {"text": "Read these words aloud for me", "intent": "convert_to_audio"},
    {"text": "Make a spoken recording from this text", "intent": "convert_to_audio"},
    {"text": "Convert this note into vocal speech", "intent": "convert_to_audio"},
    {"text": "Say this text with expression", "intent": "convert_to_audio"},
    {"text": "Produce a voice file from this paragraph", "intent": "convert_to_audio"},
    {"text": "Please make an audio version of this message", "intent": "convert_to_audio"},
    {"text": "Give me a reading voice of this sentence", "intent": "convert_to_audio"},
    {"text": "Turn this content into spoken words", "intent": "convert_to_audio"},
    {"text": "Speak this note loudly", "intent": "convert_to_audio"},
    {"text": "Make a voice clip from these words", "intent": "convert_to_audio"},
    {"text": "Read this text with a clear voice", "intent": "convert_to_audio"},
    {"text": "Create a spoken version of this writing", "intent": "convert_to_audio"},
    {"text": "Turn these sentences into an audio recording", "intent": "convert_to_audio"},
    {"text": "Please say this message aloud", "intent": "convert_to_audio"},
    {"text": "Make a vocal recording of this note", "intent": "convert_to_audio"},
    {"text": "Convert this text to a voice message", "intent": "convert_to_audio"},
    {"text": "Give me an audio file of this paragraph", "intent": "convert_to_audio"},
    {"text": "Speak this sentence clearly", "intent": "convert_to_audio"},
    {"text": "Produce speech audio from this writing", "intent": "convert_to_audio"},
    {"text": "Please read this note loudly", "intent": "convert_to_audio"},
    {"text": "Make an audio version of this text", "intent": "convert_to_audio"},
    {"text": "Turn this sentence into spoken audio", "intent": "convert_to_audio"},
    {"text": "Say this paragraph as a voice clip", "intent": "convert_to_audio"},
    {"text": "Create a voice recording from these words", "intent": "convert_to_audio"},
    {"text": "Read this message out loud for me", "intent": "convert_to_audio"},
    {"text": "Make a vocal playback of this text", "intent": "convert_to_audio"},
    {"text": "Turn this writing into an audio file", "intent": "convert_to_audio"},
    {"text": "Speak this note with clear tone", "intent": "convert_to_audio"},
    {"text": "Produce an audio clip from this sentence", "intent": "convert_to_audio"},
    {"text": "Please say this paragraph loudly", "intent": "convert_to_audio"},
    {"text": "Make a voice message of these words", "intent": "convert_to_audio"},
    {"text": "Convert this note into vocal audio", "intent": "convert_to_audio"},
    {"text": "Give me a spoken version of this text", "intent": "convert_to_audio"},
    {"text": "Speak this sentence with emotion", "intent": "convert_to_audio"},
    {"text": "Produce an audio recording of this note", "intent": "convert_to_audio"},
    {"text": "Please read this text aloud clearly", "intent": "convert_to_audio"},
    {"text": "Make an audio playback of this sentence", "intent": "convert_to_audio"},
    {"text": "Turn this writing into a voice message", "intent": "convert_to_audio"},
    {"text": "Say these words as a vocal clip", "intent": "convert_to_audio"},
    {"text": "Create a spoken word file from this note", "intent": "convert_to_audio"},
    {"text": "Read this paragraph with clear voice", "intent": "convert_to_audio"},
    {"text": "Make a voice file of this message", "intent": "convert_to_audio"},
    {"text": "Turn this text into speech audio", "intent": "convert_to_audio"},
    {"text": "Speak this message clearly for me", "intent": "convert_to_audio"},
    {"text": "Produce a vocal recording from this text", "intent": "convert_to_audio"},
    {"text": "Please say this note out loud", "intent": "convert_to_audio"},
    {"text": "Make an audio file from these words", "intent": "convert_to_audio"},
    {"text": "Turn this sentence into a voice clip", "intent": "convert_to_audio"},
    {"text": "Give me a reading voice of this paragraph", "intent": "convert_to_audio"},
    {"text": "Speak this writing with clarity", "intent": "convert_to_audio"},
    {"text": "Produce a voiceover of this note", "intent": "convert_to_audio"},
    {"text": "Read this message aloud for me", "intent": "convert_to_audio"},
    {"text": "Make a vocal version of this text", "intent": "convert_to_audio"},
    {"text": "Turn this paragraph into a spoken message", "intent": "convert_to_audio"},
    {"text": "Say these sentences with expression", "intent": "convert_to_audio"},
    {"text": "Create a voice clip from this writing", "intent": "convert_to_audio"},
    {"text": "Please read this note with a clear voice", "intent": "convert_to_audio"},
    {"text": "Make an audio recording of this paragraph", "intent": "convert_to_audio"},
    {"text": "Turn these words into a vocal message", "intent": "convert_to_audio"},
    {"text": "Speak this text with clear pronunciation", "intent": "convert_to_audio"},
    {"text": "Produce an audio file from this message", "intent": "convert_to_audio"},
    {"text": "Please say this paragraph with emotion", "intent": "convert_to_audio"},
    {"text": "Make a spoken recording of this text", "intent": "convert_to_audio"},
    {"text": "Turn this writing into a voice note", "intent": "convert_to_audio"},
    {"text": "Say this message clearly for me", "intent": "convert_to_audio"},
    {"text": "Give me an audio version of this sentence", "intent": "convert_to_audio"},
    {"text": "Speak this note out loud with clarity", "intent": "convert_to_audio"},
    {"text": "Create a voice message from this paragraph", "intent": "convert_to_audio"},
    {"text": "Please read this message aloud with feeling", "intent": "convert_to_audio"},
    {"text": "Make an audio clip of this writing", "intent": "convert_to_audio"},
    {"text": "Turn this text into a spoken audio message", "intent": "convert_to_audio"},
    {"text": "Say this sentence as a voice message", "intent": "convert_to_audio"},
    {"text": "Produce a vocal recording from these words", "intent": "convert_to_audio"},
    {"text": "Read this paragraph aloud for me", "intent": "convert_to_audio"},
    {"text": "Make a voice file of this note", "intent": "convert_to_audio"},
    {"text": "Turn these words into an audio clip", "intent": "convert_to_audio"},
    {"text": "Speak this text with natural tone", "intent": "convert_to_audio"},
    {"text": "Produce a spoken word message from this content", "intent": "convert_to_audio"},
    {"text": "Please say this writing aloud", "intent": "convert_to_audio"},
    {"text": "Make an audio message from these sentences", "intent": "convert_to_audio"}
]

# %%
data14 = [
    {"text": "Convert this paragraph into an audio message", "intent": "convert_to_audio"},
    {"text": "Please vocalize this text", "intent": "convert_to_audio"},
    {"text": "Make this writing into a spoken file", "intent": "convert_to_audio"},
    {"text": "Turn these sentences into voice playback", "intent": "convert_to_audio"},
    {"text": "I want to listen to this text as audio", "intent": "convert_to_audio"},
    {"text": "Read this out loud for me", "intent": "convert_to_audio"},
    {"text": "Produce a voice version of this note", "intent": "convert_to_audio"},
    {"text": "Create an audio file from this message", "intent": "convert_to_audio"},
    {"text": "Please say these words in audio", "intent": "convert_to_audio"},
    {"text": "Make a speech audio from this paragraph", "intent": "convert_to_audio"},
    {"text": "Turn this text into a spoken voice file", "intent": "convert_to_audio"},
    {"text": "Speak this sentence in a clear voice", "intent": "convert_to_audio"},
    {"text": "Give me a vocal recording of this message", "intent": "convert_to_audio"},
    {"text": "Convert these notes to a voice clip", "intent": "convert_to_audio"},
    {"text": "Say this message with expression", "intent": "convert_to_audio"},
    {"text": "Produce an audio playback of this writing", "intent": "convert_to_audio"},
    {"text": "Please read this sentence aloud", "intent": "convert_to_audio"},
    {"text": "Make a voice file out of these words", "intent": "convert_to_audio"},
    {"text": "Turn this text into an audio recording", "intent": "convert_to_audio"},
    {"text": "Speak this note clearly and loudly", "intent": "convert_to_audio"},
    {"text": "Create a vocal message from this paragraph", "intent": "convert_to_audio"},
    {"text": "Read this writing aloud for me", "intent": "convert_to_audio"},
    {"text": "Make a speech file from these sentences", "intent": "convert_to_audio"},
    {"text": "Turn this note into spoken audio", "intent": "convert_to_audio"},
    {"text": "Say this text with clear pronunciation", "intent": "convert_to_audio"},
    {"text": "Produce a vocal clip of this message", "intent": "convert_to_audio"},
    {"text": "Please say this paragraph in voice", "intent": "convert_to_audio"},
    {"text": "Make an audio reading of this text", "intent": "convert_to_audio"},
    {"text": "Turn these sentences into a voice recording", "intent": "convert_to_audio"},
    {"text": "Speak this message out loud", "intent": "convert_to_audio"},
    {"text": "Give me a voiceover of this writing", "intent": "convert_to_audio"},
    {"text": "Convert this note to audio playback", "intent": "convert_to_audio"},
    {"text": "Please vocalize these words", "intent": "convert_to_audio"},
    {"text": "Make a spoken word file from this paragraph", "intent": "convert_to_audio"},
    {"text": "Turn this message into voice audio", "intent": "convert_to_audio"},
    {"text": "Say this writing clearly and loudly", "intent": "convert_to_audio"},
    {"text": "Produce a voice message from this note", "intent": "convert_to_audio"},
    {"text": "Please read this sentence with feeling", "intent": "convert_to_audio"},
    {"text": "Make an audio clip from this text", "intent": "convert_to_audio"},
    {"text": "Turn these words into spoken audio", "intent": "convert_to_audio"},
    {"text": "Speak this message with emotion", "intent": "convert_to_audio"},
    {"text": "Create a vocal recording of this paragraph", "intent": "convert_to_audio"},
    {"text": "Read this note aloud with clarity", "intent": "convert_to_audio"},
    {"text": "Make a voice file from this writing", "intent": "convert_to_audio"},
    {"text": "Turn this text into speech playback", "intent": "convert_to_audio"},
    {"text": "Speak this note clearly for me", "intent": "convert_to_audio"},
    {"text": "Produce an audio recording of this message", "intent": "convert_to_audio"},
    {"text": "Please say this paragraph out loud", "intent": "convert_to_audio"},
    {"text": "Make a vocal playback of these words", "intent": "convert_to_audio"},
    {"text": "Turn this writing into an audio message", "intent": "convert_to_audio"},
    {"text": "Say this message in a clear voice", "intent": "convert_to_audio"},
    {"text": "Create a spoken version of this note", "intent": "convert_to_audio"},
    {"text": "Read this paragraph aloud with expression", "intent": "convert_to_audio"},
    {"text": "Make a voice clip from this text", "intent": "convert_to_audio"},
    {"text": "Turn these sentences into voice audio", "intent": "convert_to_audio"},
    {"text": "Speak this writing clearly and softly", "intent": "convert_to_audio"},
    {"text": "Produce a voice recording of this message", "intent": "convert_to_audio"},
    {"text": "Please say this note with emotion", "intent": "convert_to_audio"},
    {"text": "Make an audio version of this paragraph", "intent": "convert_to_audio"},
    {"text": "Turn this text into a vocal message", "intent": "convert_to_audio"},
    {"text": "Say these words aloud for me", "intent": "convert_to_audio"},
    {"text": "Create an audio file from this note", "intent": "convert_to_audio"},
    {"text": "Read this message clearly for me", "intent": "convert_to_audio"},
    {"text": "Make a voice message out of this writing", "intent": "convert_to_audio"},
    {"text": "Turn these sentences into a spoken clip", "intent": "convert_to_audio"},
    {"text": "Speak this paragraph with clarity", "intent": "convert_to_audio"},
    {"text": "Produce a vocal clip from this text", "intent": "convert_to_audio"},
    {"text": "Please read this note with clear voice", "intent": "convert_to_audio"},
    {"text": "Make an audio recording of these sentences", "intent": "convert_to_audio"},
    {"text": "Turn this writing into a speech file", "intent": "convert_to_audio"},
    {"text": "Say this text with clear enunciation", "intent": "convert_to_audio"},
    {"text": "Create a voice file from this paragraph", "intent": "convert_to_audio"},
    {"text": "Read this sentence out loud for me", "intent": "convert_to_audio"},
    {"text": "Make a vocal playback of this note", "intent": "convert_to_audio"},
    {"text": "Turn these words into an audio recording", "intent": "convert_to_audio"},
    {"text": "Speak this message softly", "intent": "convert_to_audio"},
    {"text": "Produce a spoken word file from this message", "intent": "convert_to_audio"},
    {"text": "Please say this writing aloud clearly", "intent": "convert_to_audio"},
    {"text": "Make an audio message from this text", "intent": "convert_to_audio"}
]

# %%
data15 = [
    {"text": "Can you make this spoken content?", "intent": "convert_to_audio"},
    {"text": "Convert this into a voice narration", "intent": "convert_to_audio"},
    {"text": "Give me a soundbite version", "intent": "convert_to_audio"},
    {"text": "I'd prefer to hear this text", "intent": "convert_to_audio"},
    {"text": "Speak this in a professional tone", "intent": "convert_to_audio"},
    {"text": "Narrate this out loud", "intent": "convert_to_audio"},
    {"text": "Turn this into something I can play", "intent": "convert_to_audio"},
    {"text": "Read this like an audio assistant", "intent": "convert_to_audio"},
    {"text": "I want to listen to this instead", "intent": "convert_to_audio"},
    {"text": "Give me an audio expression of this", "intent": "convert_to_audio"},
    {"text": "Say this using automated voice", "intent": "convert_to_audio"},
    {"text": "Generate a narrated voice track", "intent": "convert_to_audio"},
    {"text": "I'd like this in voice narration form", "intent": "convert_to_audio"},
    {"text": "Speak these lines like an AI", "intent": "convert_to_audio"},
    {"text": "Produce a vocal readout", "intent": "convert_to_audio"},
    {"text": "Tell me what’s written here", "intent": "convert_to_audio"},
    {"text": "Use a human-like voice to say this", "intent": "convert_to_audio"},
    {"text": "Can I hear a reading of this?", "intent": "convert_to_audio"},
    {"text": "I'd enjoy hearing this spoken", "intent": "convert_to_audio"},
    {"text": "Give me an audio playback of the text", "intent": "convert_to_audio"},
    {"text": "Please convert this document to audio", "intent": "convert_to_audio"},
    {"text": "Convert this chat into voice", "intent": "convert_to_audio"},
    {"text": "Voice synthesize this response", "intent": "convert_to_audio"},
    {"text": "Can you play this in speech format?", "intent": "convert_to_audio"},
    {"text": "Say these instructions using voice", "intent": "convert_to_audio"},
    {"text": "Transform this chat message into sound", "intent": "convert_to_audio"},
    {"text": "I'd love to hear it spoken", "intent": "convert_to_audio"},
    {"text": "Speak this back to me like a narrator", "intent": "convert_to_audio"},
    {"text": "Use audio synthesis to vocalize this", "intent": "convert_to_audio"},
    {"text": "Let me hear what this sentence sounds like", "intent": "convert_to_audio"},
    {"text": "Say this out using your speech engine", "intent": "convert_to_audio"},
    {"text": "Speak the following using text-to-speech", "intent": "convert_to_audio"},
    {"text": "Provide a verbal conversion of this", "intent": "convert_to_audio"},
    {"text": "Say it like you're reading a script", "intent": "convert_to_audio"},
    {"text": "Render this via speech generation", "intent": "convert_to_audio"},
    {"text": "I'd like to hear this part out loud", "intent": "convert_to_audio"},
    {"text": "Turn this written material into audio", "intent": "convert_to_audio"},
    {"text": "Speak this input as a voice reply", "intent": "convert_to_audio"},
    {"text": "Can you voice this out with clarity?", "intent": "convert_to_audio"},
    {"text": "Use digital speech to express this", "intent": "convert_to_audio"},
    {"text": "Read this back to me in voice format", "intent": "convert_to_audio"},
    {"text": "I need to hear this in spoken tone", "intent": "convert_to_audio"},
    {"text": "Say this aloud in a clear voice", "intent": "convert_to_audio"},
    {"text": "Convert this info into a voice clip", "intent": "convert_to_audio"},
    {"text": "I'd like to play this sentence", "intent": "convert_to_audio"},
    {"text": "Make a voice file of this", "intent": "convert_to_audio"},
    {"text": "Can you read this text using a voice tool?", "intent": "convert_to_audio"},
    {"text": "Let me hear this through voice rendering", "intent": "convert_to_audio"},
    {"text": "Turn this into audio using a robotic voice", "intent": "convert_to_audio"},
    {"text": "Narrate this text as if reading to an audience", "intent": "convert_to_audio"},
    {"text": "I'd like this converted to an audio clip", "intent": "convert_to_audio"},
    {"text": "Speak this part using a virtual assistant tone", "intent": "convert_to_audio"},
    {"text": "I want this message spoken by AI", "intent": "convert_to_audio"},
    {"text": "Use voice technology to say this", "intent": "convert_to_audio"},
    {"text": "Speak it like a synthetic reader", "intent": "convert_to_audio"},
    {"text": "Voice render this entire message", "intent": "convert_to_audio"},
    {"text": "Please make this spoken version available", "intent": "convert_to_audio"},
    {"text": "Can this be heard using voice tech?", "intent": "convert_to_audio"},
    {"text": "Say this as an automated assistant", "intent": "convert_to_audio"},
    {"text": "I need this as a voice output now", "intent": "convert_to_audio"},
    {"text": "Read this through an audio interface", "intent": "convert_to_audio"},
    {"text": "I'd like this transformed into audio", "intent": "convert_to_audio"},
    {"text": "Convert this note into something audible", "intent": "convert_to_audio"},
    {"text": "Produce a voice summary", "intent": "convert_to_audio"},
    {"text": "Please read this text out loud digitally", "intent": "convert_to_audio"},
    {"text": "Say this phrase using your vocal module", "intent": "convert_to_audio"},
    {"text": "Convert this into speech that I can hear", "intent": "convert_to_audio"},
    {"text": "I'd rather hear this out", "intent": "convert_to_audio"},
    {"text": "Use AI to say this message", "intent": "convert_to_audio"},
    {"text": "Play this message with voice AI", "intent": "convert_to_audio"},
    {"text": "Let me hear this reply in speech", "intent": "convert_to_audio"},
    {"text": "Please speak this portion", "intent": "convert_to_audio"},
    {"text": "Give me audio content for this", "intent": "convert_to_audio"},
    {"text": "Can I get this as an audible file?", "intent": "convert_to_audio"},
    {"text": "Tell this to me out loud", "intent": "convert_to_audio"},
    {"text": "Say this sentence using your voice system", "intent": "convert_to_audio"},
    {"text": "Read out loud this part", "intent": "convert_to_audio"},
    {"text": "Use your speech module to say this", "intent": "convert_to_audio"},
    {"text": "Play a voice clip with this content", "intent": "convert_to_audio"},
    {"text": "Say this so I can hear it", "intent": "convert_to_audio"},
    {"text": "I'd like to hear this now", "intent": "convert_to_audio"},
    {"text": "Speak this text clearly", "intent": "convert_to_audio"},
    {"text": "Read the input like a podcast", "intent": "convert_to_audio"},
    {"text": "Give me audio delivery of this info", "intent": "convert_to_audio"},
    {"text": "Please use voice to say this message", "intent": "convert_to_audio"},
    {"text": "Can you make an MP3 audio from this?", "intent": "convert_to_audio"},
    {"text": "Say this section with synthesized voice", "intent": "convert_to_audio"},
    {"text": "Turn this paragraph into a speech format", "intent": "convert_to_audio"},
    {"text": "Convert this chat to a sound clip", "intent": "convert_to_audio"},
    {"text": "Produce a clear spoken file", "intent": "convert_to_audio"},
    {"text": "I'd like to hear this text narrated", "intent": "convert_to_audio"},
    {"text": "Read this aloud as a message", "intent": "convert_to_audio"},
    {"text": "Speak this passage using automated reading", "intent": "convert_to_audio"},
    {"text": "Turn this string into a voice format", "intent": "convert_to_audio"},
    {"text": "Generate audio from these sentences", "intent": "convert_to_audio"},
    {"text": "Say it as if you are a news presenter", "intent": "convert_to_audio"},
    {"text": "Please read this like an audio response", "intent": "convert_to_audio"},
    {"text": "Transform this written line to audio", "intent": "convert_to_audio"},
    {"text": "Use your voice model to speak this", "intent": "convert_to_audio"},
    {"text": "Play this script aloud", "intent": "convert_to_audio"}
]

# %% [markdown]
# ## Combining data

# %%
try:
    data = data1 + data2 + data3 + data4 + data5 + data6 + data7 + data8 + data9 + data10 + data11 + data12 + data13 + data14 + data15
    df = pd.DataFrame(data)
    print(f"DataFrame shape: {df.shape}")
    df.to_csv("convert_to_audio_data.csv", index=False)
    print("CSV file saved successfully.")
except Exception as e:
    print(f"error occurred: {e}")
# Out:
# DataFrame shape: (1284, 2)
# CSV file saved successfully.

# %%
df.shape
# Out:
# (1284, 2)

# %%
df.duplicated().sum()
# Out:
# np.int64(41)
