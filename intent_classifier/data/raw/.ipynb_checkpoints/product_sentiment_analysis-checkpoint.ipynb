# %% [markdown]
# # product sentiment intent data

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd

# %% [markdown]
# ## Generated data

# %%
data2 = [
    {"text": "What do people think about this phone on Flipkart?", "intent": "analyse_product_sentiment"},
    {"text": "Can you analyze reviews for the Samsung Galaxy S21?", "intent": "analyse_product_sentiment"},
    {"text": "Tell me if users like this washing machine", "intent": "analyse_product_sentiment"},
    {"text": "What’s the public opinion on this air fryer?", "intent": "analyse_product_sentiment"},
    {"text": "Give me the sentiment summary of this product", "intent": "analyse_product_sentiment"},
    {"text": "Are customers satisfied with this laptop?", "intent": "analyse_product_sentiment"},
    {"text": "Analyze Flipkart reviews for the iPhone 13", "intent": "analyse_product_sentiment"},
    {"text": "Summarize customer feedback for this smartwatch", "intent": "analyse_product_sentiment"},
    {"text": "Do buyers recommend this refrigerator?", "intent": "analyse_product_sentiment"},
    {"text": "How’s the review sentiment for this product?", "intent": "analyse_product_sentiment"},
    {"text": "What are people saying about this DSLR?", "intent": "analyse_product_sentiment"},
    {"text": "Review the sentiment for these headphones", "intent": "analyse_product_sentiment"},
    {"text": "Check if this product has good reviews", "intent": "analyse_product_sentiment"},
    {"text": "Sentiment analysis of Flipkart ratings for this item", "intent": "analyse_product_sentiment"},
    {"text": "Go through user reviews and tell me the sentiment", "intent": "analyse_product_sentiment"},
]

# %%
data2 += [
    {"text": "Can you check how customers feel about this tablet?", "intent": "analyse_product_sentiment"},
    {"text": "Is this vacuum cleaner getting positive reviews?", "intent": "analyse_product_sentiment"},
    {"text": "Analyze the ratings and feedback for this product", "intent": "analyse_product_sentiment"},
    {"text": "How are people rating this mobile?", "intent": "analyse_product_sentiment"},
    {"text": "Tell me the general opinion about this microwave", "intent": "analyse_product_sentiment"},
    {"text": "Are the reviews for this smartwatch mostly positive or negative?", "intent": "analyse_product_sentiment"},
    {"text": "Give me a quick sentiment analysis for this product", "intent": "analyse_product_sentiment"},
    {"text": "What do customers think about this LED TV?", "intent": "analyse_product_sentiment"},
    {"text": "Check user sentiment on this Bluetooth speaker", "intent": "analyse_product_sentiment"},
    {"text": "What kind of feedback is this fitness band getting?", "intent": "analyse_product_sentiment"},
    {"text": "Summarize the customer sentiment from reviews", "intent": "analyse_product_sentiment"},
    {"text": "Look at the reviews and tell me if this AC is good", "intent": "analyse_product_sentiment"},
    {"text": "Do users like this mixer grinder according to reviews?", "intent": "analyse_product_sentiment"},
    {"text": "Check the overall mood of the reviews for this product", "intent": "analyse_product_sentiment"},
    {"text": "Tell me how people are reacting to this smart TV", "intent": "analyse_product_sentiment"},
    {"text": "Based on reviews, is this device well-received?", "intent": "analyse_product_sentiment"},
    {"text": "Are buyers happy with this printer?", "intent": "analyse_product_sentiment"},
    {"text": "Give me a review sentiment breakdown for this item", "intent": "analyse_product_sentiment"},
    {"text": "What’s the customer sentiment on this kitchen appliance?", "intent": "analyse_product_sentiment"},
    {"text": "Do reviews show that this device is worth buying?", "intent": "analyse_product_sentiment"},
]

# %%
import random

base_prompts = [
    "What do people think about this {product}?",
    "Can you analyze reviews for the {product}?",
    "Tell me if users like this {product}",
    "What’s the public opinion on this {product}?",
    "Give me the sentiment summary of this {product}",
    "Are customers satisfied with this {product}?",
    "Analyze Flipkart reviews for the {product}",
    "Summarize customer feedback for this {product}",
    "Do buyers recommend this {product}?",
    "How’s the review sentiment for this {product}?",
    "What are people saying about this {product}?",
    "Review the sentiment for these {product}",
    "Check if this {product} has good reviews",
    "Sentiment analysis of Flipkart ratings for this {product}",
    "Go through user reviews and tell me the sentiment",
    "Can you check what people feel about this {product}?",
    "Tell me the customer experience of this {product}",
    "Is this {product} getting good feedback?",
    "Look up the reviews and tell me if people like this {product}",
    "Check how users have rated this {product}",
    "Do people have positive things to say about this {product}?",
    "Summarize what reviewers think about this {product}",
    "Give a sentiment overview for this {product}",
    "Is the public happy with this {product}?",
    "Can you evaluate the review sentiment of this {product}?",
    "Read Flipkart reviews for this {product} and tell me the sentiment",
    "Analyze what users are saying about this {product}",
    "What do the reviews say about this {product}?",
    "Give me an analysis of this {product}’s reviews",
    "Find out the review tone for this {product}",
    "Check if people are recommending this {product}",
    "How do customers feel about this {product}?",
    "Are the reviews for this {product} mostly good or bad?",
    "Summarize the Flipkart user opinions for this {product}",
]
base_prompts += [
    "Can you summarize what people are saying about this {product}?",
    "Give me the average opinion from Flipkart reviews for this {product}",
    "Based on user feedback, is this {product} good?",
    "Check whether customers are happy with this {product}",
    "Give an overall rating sentiment for this {product}",
    "Find out if buyers like this {product}",
    "Can you analyze public sentiment on this {product}?",
    "Tell me the user opinion distribution for this {product}",
    "Fetch the reviews and give me a sentiment overview of this {product}",
    "What do Flipkart users mostly say about this {product}?",
    "Scrape reviews for this {product} and analyze the tone",
    "Can you give a summary of ratings for this {product}?",
    "What is the sentiment polarity of this {product} based on reviews?",
    "Get the pros and cons mentioned in reviews of this {product}",
    "Can you gather the customer mood about this {product}?",
    "Give an insight into how this {product} is being reviewed",
    "Fetch sentiment insights about this {product} from Flipkart",
    "Analyze if this {product} is mostly liked or disliked",
    "Aggregate Flipkart feedback and tell how this {product} performs",
    "Tell if people have a favorable opinion about this {product}"
]
base_prompts += [
    "How do users feel overall about this {product}?",
    "Can you break down the reviews for this {product}?",
    "Summarize the general sentiment for this {product}",
    "Is this {product} getting mostly positive reviews?",
    "What kind of feedback is this {product} receiving?",
    "Can you tell if people are happy with this {product}?",
    "Show me the overall impression of this {product}",
    "Are people enjoying their experience with this {product}?",
    "Check what most people are saying about this {product}",
    "How is this {product} rated by customers?",
    "Find the customer sentiment score for this {product}",
    "Give me a snapshot of user reviews for this {product}",
    "Does this {product} have a good reputation online?",
    "What’s the word on the street about this {product}?",
    "Scan the reviews and tell if this {product} is well liked",
    "Give me the vibe people have about this {product}",
    "Tell me what the crowd thinks about this {product}",
    "How’s the online buzz around this {product}?",
    "Check public feedback and rate this {product}",
    "Give me a review sentiment chart for this {product}",
    "Fetch Flipkart ratings and summarize for this {product}",
    "Give the average emotion in the reviews of this {product}",
    "What’s the mood in reviews for this {product}?",
    "Can you extract opinions from reviews of this {product}?",
    "What themes show up in reviews for this {product}?",
    "How popular is this {product} based on reviews?",
    "Give me the user perspective on this {product}",
    "Is the sentiment toward this {product} mostly neutral?",
    "What are the top sentiments expressed about this {product}?",
    "Can you list the main points people like or dislike in this {product}?",
]


product_list = [
    "smartphone", "laptop", "smartwatch", "headphones", "microwave", "refrigerator", "air fryer",
    "gaming console", "printer", "tablet", "DSLR", "mixer grinder", "vacuum cleaner", "TV", "Bluetooth speaker",
    "ceiling fan", "washing machine", "gaming mouse", "air conditioner", "coffee machine", "monitor",
    "projector", "keyboard", "router", "power bank", "fitness tracker", "hair dryer", "eBook reader", "water purifier"
]
product_list += [
    "smart TV", "electric kettle", "induction cooktop", "home theater system", "tripod stand",
    "gaming keyboard", "wireless charger", "smart bulb", "portable fan", "electric shaver",
    "toaster", "bread maker", "steam iron", "hair straightener", "robot vacuum",
    "action camera", "security camera", "Bluetooth headset", "dishwasher", "soundbar",
    "baby monitor", "juicer", "food processor", "rice cooker", "electric blanket",
    "smart plug", "video doorbell", "car dash cam", "Wi-Fi range extender", "3D printer",
    "mechanical keyboard", "noise-cancelling headphones", "graphics tablet", "photo printer", "portable SSD",
    "external hard drive", "LED projector", "monitor stand", "USB hub", "electric scooter",
    "smart scale", "laptop cooling pad", "gaming chair", "tablet stand", "stylus pen",
    "smart mirror", "air purifier", "dehumidifier", "humidifier", "screen protector"
]


data_samples = [
    {
        "text": random.choice(base_prompts).format(product=random.choice(product_list)),
        "intent": "analyse_product_sentiment"
    }
    for _ in range(1000)
]

data2 += data_samples

# %% [markdown]
# ## Combining data

# %%
try:
    df = pd.DataFrame(data2)
    print(f"DataFrame shape: {df.shape}")
    df.to_csv("product_sentiment_data.csv", index=False)
    print("CSV file saved successfully.")
except Exception as e:
    print(f"error occurred: {e}")
# Out:
# DataFrame shape: (1035, 2)
# CSV file saved successfully.

# %%
df.shape
# Out:
# (1035, 2)

# %%
df.duplicated().sum()
# Out:
# np.int64(85)
