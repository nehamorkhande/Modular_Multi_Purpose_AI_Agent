# %% [markdown]
# # gmail operations intent data

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd

# %% [markdown]
# ## Generated data

# %%
email_data = [
    # 📨 fetch_last_n
    {"text": "Show me the last 5 emails", "intent": "fetch_last_n"},
    {"text": "Get recent 10 messages from my inbox", "intent": "fetch_last_n"},
    {"text": "Give me my latest 3 mails", "intent": "fetch_last_n"},
    {"text": "Fetch the last few emails", "intent": "fetch_last_n"},
    {"text": "Display recent mails", "intent": "fetch_last_n"},

    # 👤 fetch_by_sender
    {"text": "Show emails from hr@xyz.com", "intent": "fetch_by_sender"},
    {"text": "Fetch mails sent by Flipkart", "intent": "fetch_by_sender"},
    {"text": "Get messages from John Doe", "intent": "fetch_by_sender"},
    {"text": "Show me emails from my manager", "intent": "fetch_by_sender"},
    {"text": "Find mails from noreply@cdac.in", "intent": "fetch_by_sender"},

    # 🆕 fetch_unread
    {"text": "Show unread emails", "intent": "fetch_unread"},
    {"text": "Get all unread messages", "intent": "fetch_unread"},
    {"text": "Display the mails I haven't seen", "intent": "fetch_unread"},
    {"text": "Fetch only the unread ones", "intent": "fetch_unread"},
    {"text": "What mails are unread?", "intent": "fetch_unread"},

    # ⭐ fetch_important
    {"text": "Show important emails", "intent": "fetch_important"},
    {"text": "Fetch starred mails", "intent": "fetch_important"},
    {"text": "Give me high priority messages", "intent": "fetch_important"},
    {"text": "Get my flagged mails", "intent": "fetch_important"},
    {"text": "Important messages only", "intent": "fetch_important"},

    # 📅 fetch_date_range
    {"text": "Get mails from last 7 days", "intent": "fetch_date_range"},
    {"text": "Show emails between Monday and today", "intent": "fetch_date_range"},
    {"text": "Fetch messages from last week", "intent": "fetch_date_range"},
    {"text": "Display emails from January", "intent": "fetch_date_range"},
    {"text": "Give me mails from yesterday", "intent": "fetch_date_range"},

    # 🏷️ fetch_by_label
    {"text": "Get emails labeled 'Work'", "intent": "fetch_by_label"},
    {"text": "Show messages under 'Personal'", "intent": "fetch_by_label"},
    {"text": "Fetch mails in Updates category", "intent": "fetch_by_label"},
    {"text": "Give me social label messages", "intent": "fetch_by_label"},
    {"text": "Find mails in the Promotions tab", "intent": "fetch_by_label"},

    # 📝 fetch_by_subject
    {"text": "Show emails with subject containing 'invoice'", "intent": "fetch_by_subject"},
    {"text": "Get mails with subject line 'offer'", "intent": "fetch_by_subject"},
    {"text": "Find messages where subject includes 'payment'", "intent": "fetch_by_subject"},
    {"text": "Search emails with subject 'Meeting'", "intent": "fetch_by_subject"},
    {"text": "Filter emails by subject keyword 'Amazon'", "intent": "fetch_by_subject"},

    # 📎 fetch_attachments
    {"text": "Download attachments from last 2 mails", "intent": "fetch_attachments"},
    {"text": "Get files from my recent emails", "intent": "fetch_attachments"},
    {"text": "Fetch documents attached in messages", "intent": "fetch_attachments"},
    {"text": "Show emails with attachments", "intent": "fetch_attachments"},
    {"text": "List all recent mail attachments", "intent": "fetch_attachments"},

    # 🤖 summarize_emails
    {"text": "Summarize last 3 emails from Flipkart", "intent": "summarize_emails"},
    {"text": "Give summary of mails from today", "intent": "summarize_emails"},
    {"text": "Summarize my inbox", "intent": "summarize_emails"},
    {"text": "What's the gist of the last few mails?", "intent": "summarize_emails"},
    {"text": "Brief me on emails from last week", "intent": "summarize_emails"},
]

# %%
email_data += [
    # 📨 fetch_last_n
    {"text": "List the last few emails I got", "intent": "fetch_last_n"},
    {"text": "Can you show me my 8 most recent mails?", "intent": "fetch_last_n"},
    {"text": "I want to see the past 4 emails", "intent": "fetch_last_n"},
    {"text": "Last 6 messages please", "intent": "fetch_last_n"},
    {"text": "Retrieve my latest emails", "intent": "fetch_last_n"},

    # 👤 fetch_by_sender
    {"text": "Show all messages from Amazon", "intent": "fetch_by_sender"},
    {"text": "Emails from my professor", "intent": "fetch_by_sender"},
    {"text": "Can you get messages by support@zomato.com?", "intent": "fetch_by_sender"},
    {"text": "List all mails sent by my boss", "intent": "fetch_by_sender"},
    {"text": "Pull messages from Airtel", "intent": "fetch_by_sender"},

    # 🆕 fetch_unread
    {"text": "List new unread mails", "intent": "fetch_unread"},
    {"text": "What messages haven't I opened?", "intent": "fetch_unread"},
    {"text": "Any unread mail in my inbox?", "intent": "fetch_unread"},
    {"text": "Unread emails from this week", "intent": "fetch_unread"},
    {"text": "Are there any unread ones?", "intent": "fetch_unread"},

    # ⭐ fetch_important
    {"text": "Show me the important emails only", "intent": "fetch_important"},
    {"text": "Do I have any starred messages?", "intent": "fetch_important"},
    {"text": "List my marked important emails", "intent": "fetch_important"},
    {"text": "Fetch priority mails", "intent": "fetch_important"},
    {"text": "What are my flagged emails?", "intent": "fetch_important"},

    # 📅 fetch_date_range
    {"text": "Mails received in the past 3 days", "intent": "fetch_date_range"},
    {"text": "Show emails between 1st and 5th July", "intent": "fetch_date_range"},
    {"text": "Retrieve messages from this weekend", "intent": "fetch_date_range"},
    {"text": "Inbox messages from the last 24 hours", "intent": "fetch_date_range"},
    {"text": "Can I see emails from June?", "intent": "fetch_date_range"},

    # 🏷️ fetch_by_label
    {"text": "Filter by label 'Finance'", "intent": "fetch_by_label"},
    {"text": "Show only work-labeled mails", "intent": "fetch_by_label"},
    {"text": "What do I have in the 'Updates' tab?", "intent": "fetch_by_label"},
    {"text": "Emails marked as 'Personal'", "intent": "fetch_by_label"},
    {"text": "Get only 'Travel' category emails", "intent": "fetch_by_label"},

    # 📝 fetch_by_subject
    {"text": "Any emails about 'registration'?", "intent": "fetch_by_subject"},
    {"text": "Search subject line for 'receipt'", "intent": "fetch_by_subject"},
    {"text": "Mails where subject has 'notification'", "intent": "fetch_by_subject"},
    {"text": "Show me messages with 'Results' in subject", "intent": "fetch_by_subject"},
    {"text": "Filter subject by keyword 'fee'", "intent": "fetch_by_subject"},

    # 📎 fetch_attachments
    {"text": "Download all attachments from today’s mails", "intent": "fetch_attachments"},
    {"text": "List attachments in recent emails", "intent": "fetch_attachments"},
    {"text": "Any files received today?", "intent": "fetch_attachments"},
    {"text": "Show me emails that include attachments", "intent": "fetch_attachments"},
    {"text": "Get PDF files sent recently", "intent": "fetch_attachments"},

    # 🤖 summarize_emails
    {"text": "Give me a short summary of today's emails", "intent": "summarize_emails"},
    {"text": "Summarize all unread messages", "intent": "summarize_emails"},
    {"text": "Quick summary of emails from boss", "intent": "summarize_emails"},
    {"text": "What's in my latest 5 mails?", "intent": "summarize_emails"},
    {"text": "Summarize everything received this week", "intent": "summarize_emails"},
]

# %%
email_data += [
    # 📨 fetch_last_n
    {"text": "Pull up my last three emails", "intent": "fetch_last_n"},
    {"text": "Can I view the 10 most recent mails?", "intent": "fetch_last_n"},
    {"text": "List the latest batch of emails", "intent": "fetch_last_n"},
    {"text": "What are my last few messages?", "intent": "fetch_last_n"},
    {"text": "I want to check the previous emails I received", "intent": "fetch_last_n"},

    # 👤 fetch_by_sender
    {"text": "Retrieve emails from LinkedIn", "intent": "fetch_by_sender"},
    {"text": "Find all messages from the bank", "intent": "fetch_by_sender"},
    {"text": "Show emails sent by customer.support@abc.com", "intent": "fetch_by_sender"},
    {"text": "Do I have any mail from Ravi?", "intent": "fetch_by_sender"},
    {"text": "Get all correspondence from Flipkart", "intent": "fetch_by_sender"},

    # 🆕 fetch_unread
    {"text": "What emails haven’t I read yet?", "intent": "fetch_unread"},
    {"text": "New mails in my inbox?", "intent": "fetch_unread"},
    {"text": "Unread emails only, please", "intent": "fetch_unread"},
    {"text": "I want to see new unread messages", "intent": "fetch_unread"},
    {"text": "Are there any unopened emails?", "intent": "fetch_unread"},

    # ⭐ fetch_important
    {"text": "Show the high-priority emails", "intent": "fetch_important"},
    {"text": "Display only starred conversations", "intent": "fetch_important"},
    {"text": "Get emails marked as important", "intent": "fetch_important"},
    {"text": "What are my flagged or starred messages?", "intent": "fetch_important"},
    {"text": "Important mails only", "intent": "fetch_important"},

    # 📅 fetch_date_range
    {"text": "Emails from last Monday to today", "intent": "fetch_date_range"},
    {"text": "Fetch mails I got this month", "intent": "fetch_date_range"},
    {"text": "Get messages between 1st May and 10th May", "intent": "fetch_date_range"},
    {"text": "Pull emails from yesterday", "intent": "fetch_date_range"},
    {"text": "What emails came in over the weekend?", "intent": "fetch_date_range"},

    # 🏷️ fetch_by_label
    {"text": "Give me all emails tagged 'Official'", "intent": "fetch_by_label"},
    {"text": "Find emails under the 'Social' label", "intent": "fetch_by_label"},
    {"text": "Get messages categorized as 'Promotions'", "intent": "fetch_by_label"},
    {"text": "Retrieve only those labeled as 'Job Alerts'", "intent": "fetch_by_label"},
    {"text": "Show me all emails with the label 'Bills'", "intent": "fetch_by_label"},

    # 📝 fetch_by_subject
    {"text": "Look for mails where subject contains 'offer'", "intent": "fetch_by_subject"},
    {"text": "Search subjects for the word 'project'", "intent": "fetch_by_subject"},
    {"text": "Emails about 'travel itinerary'", "intent": "fetch_by_subject"},
    {"text": "Find all messages with subject line including 'cancelled'", "intent": "fetch_by_subject"},
    {"text": "Subject line contains the word 'invoice'", "intent": "fetch_by_subject"},

    # 📎 fetch_attachments
    {"text": "Any messages with downloadable files?", "intent": "fetch_attachments"},
    {"text": "List all emails with documents attached", "intent": "fetch_attachments"},
    {"text": "Where are my attachment mails?", "intent": "fetch_attachments"},
    {"text": "Find all images or PDFs sent recently", "intent": "fetch_attachments"},
    {"text": "Can I view only emails that have attachments?", "intent": "fetch_attachments"},

    # 🤖 summarize_emails
    {"text": "Can you give me a summary of unread messages?", "intent": "summarize_emails"},
    {"text": "Summarize all emails from yesterday", "intent": "summarize_emails"},
    {"text": "What's the gist of my latest mails?", "intent": "summarize_emails"},
    {"text": "I just need a brief of today's inbox", "intent": "summarize_emails"},
    {"text": "Give me quick points from recent emails", "intent": "summarize_emails"},
]

# %%
email_data += [
    # 📨 fetch_last_n
    {"text": "Show my most recent two emails", "intent": "fetch_last_n"},
    {"text": "Give me the latest five messages", "intent": "fetch_last_n"},
    {"text": "Pull the previous few mails", "intent": "fetch_last_n"},
    {"text": "I'd like to see the last emails I received", "intent": "fetch_last_n"},
    {"text": "Access my 3 latest mails", "intent": "fetch_last_n"},

    # 👤 fetch_by_sender
    {"text": "Get emails sent by Amazon", "intent": "fetch_by_sender"},
    {"text": "Any messages from my professor?", "intent": "fetch_by_sender"},
    {"text": "Retrieve conversations from info@cdac.in", "intent": "fetch_by_sender"},
    {"text": "Do I have any mail from Microsoft?", "intent": "fetch_by_sender"},
    {"text": "Show me all the emails that Ramesh sent", "intent": "fetch_by_sender"},

    # 🆕 fetch_unread
    {"text": "Bring up the emails I haven't read yet", "intent": "fetch_unread"},
    {"text": "Display all fresh emails", "intent": "fetch_unread"},
    {"text": "Open new messages I haven’t checked", "intent": "fetch_unread"},
    {"text": "Let’s see the unread inbox", "intent": "fetch_unread"},
    {"text": "Only new unread mails please", "intent": "fetch_unread"},

    # ⭐ fetch_important
    {"text": "Get only my marked or starred emails", "intent": "fetch_important"},
    {"text": "What are the important mails from this week?", "intent": "fetch_important"},
    {"text": "Load only the emails I flagged", "intent": "fetch_important"},
    {"text": "Starred conversations only", "intent": "fetch_important"},
    {"text": "View my priority messages", "intent": "fetch_important"},

    # 📅 fetch_date_range
    {"text": "Pull emails from the last 3 days", "intent": "fetch_date_range"},
    {"text": "Get my inbox from this week", "intent": "fetch_date_range"},
    {"text": "Check all emails I got in June", "intent": "fetch_date_range"},
    {"text": "What messages came in the last 24 hours?", "intent": "fetch_date_range"},
    {"text": "Emails between Monday and Thursday", "intent": "fetch_date_range"},

    # 🏷️ fetch_by_label
    {"text": "Give me the 'Travel' labeled messages", "intent": "fetch_by_label"},
    {"text": "Get emails from the 'Bills' category", "intent": "fetch_by_label"},
    {"text": "List everything under 'Personal'", "intent": "fetch_by_label"},
    {"text": "Access all mails tagged 'Clients'", "intent": "fetch_by_label"},
    {"text": "Emails labeled as 'Team Updates'", "intent": "fetch_by_label"},

    # 📝 fetch_by_subject
    {"text": "Find messages about 'meeting'", "intent": "fetch_by_subject"},
    {"text": "Look for subject lines that say 'feedback'", "intent": "fetch_by_subject"},
    {"text": "Subject contains the word 'application'", "intent": "fetch_by_subject"},
    {"text": "Search for subjects like 'holiday plans'", "intent": "fetch_by_subject"},
    {"text": "Mail subject has 'results'", "intent": "fetch_by_subject"},

    # 📎 fetch_attachments
    {"text": "List emails with resumes attached", "intent": "fetch_attachments"},
    {"text": "Pull all mail that includes attachments", "intent": "fetch_attachments"},
    {"text": "Do I have any documents in recent mails?", "intent": "fetch_attachments"},
    {"text": "Find all attachment mails from this month", "intent": "fetch_attachments"},
    {"text": "I want only emails that have something attached", "intent": "fetch_attachments"},

    # 🤖 summarize_emails
    {"text": "Give me a summary of today’s inbox", "intent": "summarize_emails"},
    {"text": "Quick highlights from this week's mails", "intent": "summarize_emails"},
    {"text": "Summarize all work-related messages", "intent": "summarize_emails"},
    {"text": "Just give a brief of unread messages", "intent": "summarize_emails"},
    {"text": "Can you summarize my inbox in short?", "intent": "summarize_emails"},
]

# %%
email_data += [
    # 📨 fetch_last_n
    {"text": "Can you fetch the last 10 emails I got?", "intent": "fetch_last_n"},
    {"text": "Show me a list of my recent messages", "intent": "fetch_last_n"},
    {"text": "I'd like to review the last batch of emails", "intent": "fetch_last_n"},
    {"text": "What were my latest 7 messages?", "intent": "fetch_last_n"},
    {"text": "Retrieve my last few received emails", "intent": "fetch_last_n"},

    # 👤 fetch_by_sender
    {"text": "Check for any emails from Flipkart", "intent": "fetch_by_sender"},
    {"text": "Any messages from my boss?", "intent": "fetch_by_sender"},
    {"text": "Do I have mails from swati.patil@abc.com?", "intent": "fetch_by_sender"},
    {"text": "Get communications from my college", "intent": "fetch_by_sender"},
    {"text": "Please list all messages sent by Rahul", "intent": "fetch_by_sender"},

    # 🆕 fetch_unread
    {"text": "Can I see unread emails only?", "intent": "fetch_unread"},
    {"text": "What new messages have I not opened yet?", "intent": "fetch_unread"},
    {"text": "Fetch only unseen emails", "intent": "fetch_unread"},
    {"text": "Display messages I haven't read", "intent": "fetch_unread"},
    {"text": "List the unread ones from my inbox", "intent": "fetch_unread"},

    # ⭐ fetch_important
    {"text": "Get emails I marked as important", "intent": "fetch_important"},
    {"text": "Which mails are in my priority inbox?", "intent": "fetch_important"},
    {"text": "Important mails only, please", "intent": "fetch_important"},
    {"text": "Only retrieve starred messages", "intent": "fetch_important"},
    {"text": "Show me flagged or important emails", "intent": "fetch_important"},

    # 📅 fetch_date_range
    {"text": "Check emails I received this weekend", "intent": "fetch_date_range"},
    {"text": "Emails from last Friday till now", "intent": "fetch_date_range"},
    {"text": "Give me messages from the last 10 days", "intent": "fetch_date_range"},
    {"text": "Pull all emails from April 1 to April 7", "intent": "fetch_date_range"},
    {"text": "Show only emails from this morning", "intent": "fetch_date_range"},

    # 🏷️ fetch_by_label
    {"text": "Open emails labeled as 'Finance'", "intent": "fetch_by_label"},
    {"text": "Check the mails under 'Work'", "intent": "fetch_by_label"},
    {"text": "Get everything tagged with 'Important'", "intent": "fetch_by_label"},
    {"text": "List the messages under 'Project X'", "intent": "fetch_by_label"},
    {"text": "Fetch mails categorized as 'Reports'", "intent": "fetch_by_label"},

    # 📝 fetch_by_subject
    {"text": "Show emails with subject mentioning 'invoice'", "intent": "fetch_by_subject"},
    {"text": "Find messages where subject says 'urgent'", "intent": "fetch_by_subject"},
    {"text": "Get all emails titled 'results'", "intent": "fetch_by_subject"},
    {"text": "Which mails have 'job offer' in subject?", "intent": "fetch_by_subject"},
    {"text": "Locate subjects containing 'project update'", "intent": "fetch_by_subject"},

    # 📎 fetch_attachments
    {"text": "Download attachments from today's emails", "intent": "fetch_attachments"},
    {"text": "Find emails with PDFs", "intent": "fetch_attachments"},
    {"text": "Are there any mails that include files?", "intent": "fetch_attachments"},
    {"text": "Locate all emails that have documents", "intent": "fetch_attachments"},
    {"text": "Any messages with pictures or attachments?", "intent": "fetch_attachments"},

    # 🤖 summarize_emails
    {"text": "Give me a gist of the last few emails", "intent": "summarize_emails"},
    {"text": "Summarize my inbox from this morning", "intent": "summarize_emails"},
    {"text": "Can you quickly summarize the messages I got yesterday?", "intent": "summarize_emails"},
    {"text": "Short summary of the emails I got from HR", "intent": "summarize_emails"},
    {"text": "Summarize only my unread mails", "intent": "summarize_emails"},
]

# %%
email_data += [
    # 📨 fetch_last_n
    {"text": "Just show the last few emails I got", "intent": "fetch_last_n"},
    {"text": "I'd like to see my 3 most recent emails", "intent": "fetch_last_n"},
    {"text": "Can I get my latest messages?", "intent": "fetch_last_n"},
    {"text": "Retrieve the last batch of received emails", "intent": "fetch_last_n"},
    {"text": "Pull up my latest emails", "intent": "fetch_last_n"},

    # 👤 fetch_by_sender
    {"text": "Do I have any updates from admin@xyz.com?", "intent": "fetch_by_sender"},
    {"text": "Search emails sent by Mahesh", "intent": "fetch_by_sender"},
    {"text": "Pull mails from Paytm", "intent": "fetch_by_sender"},
    {"text": "Retrieve all messages from Amazon", "intent": "fetch_by_sender"},
    {"text": "Find emails received from yourbank@services.com", "intent": "fetch_by_sender"},

    # 🆕 fetch_unread
    {"text": "Unread messages only", "intent": "fetch_unread"},
    {"text": "Which emails haven’t I opened yet?", "intent": "fetch_unread"},
    {"text": "Check for any new mails I missed", "intent": "fetch_unread"},
    {"text": "Scan inbox for unread stuff", "intent": "fetch_unread"},
    {"text": "Unread emails from this morning", "intent": "fetch_unread"},

    # ⭐ fetch_important
    {"text": "Get mails marked as high priority", "intent": "fetch_important"},
    {"text": "List my starred items", "intent": "fetch_important"},
    {"text": "Only important or flagged messages", "intent": "fetch_important"},
    {"text": "Important ones from last week", "intent": "fetch_important"},
    {"text": "Filter my inbox for critical mails", "intent": "fetch_important"},

    # 📅 fetch_date_range
    {"text": "Show emails from the last 2 weeks", "intent": "fetch_date_range"},
    {"text": "Fetch my messages from the last 24 hours", "intent": "fetch_date_range"},
    {"text": "Get emails I received during Diwali", "intent": "fetch_date_range"},
    {"text": "Emails between Jan 10 and Jan 15", "intent": "fetch_date_range"},
    {"text": "Pull out messages from Monday", "intent": "fetch_date_range"},

    # 🏷️ fetch_by_label
    {"text": "Get all emails tagged 'Research'", "intent": "fetch_by_label"},
    {"text": "Show mails labeled 'Travel'", "intent": "fetch_by_label"},
    {"text": "Open emails from the 'ToDo' label", "intent": "fetch_by_label"},
    {"text": "What’s under the 'Updates' category?", "intent": "fetch_by_label"},
    {"text": "Fetch mails tagged as 'Recruitment'", "intent": "fetch_by_label"},

    # 📝 fetch_by_subject
    {"text": "Search for subject lines with 'offer'", "intent": "fetch_by_subject"},
    {"text": "Show me emails where subject says 'assignment'", "intent": "fetch_by_subject"},
    {"text": "Any emails titled 'invitation'?", "intent": "fetch_by_subject"},
    {"text": "Check for subjects containing 'CV'", "intent": "fetch_by_subject"},
    {"text": "Retrieve subjects that include 'salary'", "intent": "fetch_by_subject"},

    # 📎 fetch_attachments
    {"text": "Do I have mails with downloadable files?", "intent": "fetch_attachments"},
    {"text": "Search emails that have Excel sheets", "intent": "fetch_attachments"},
    {"text": "Find image attachments from last week", "intent": "fetch_attachments"},
    {"text": "Locate any mails with files in them", "intent": "fetch_attachments"},
    {"text": "Download all recent email attachments", "intent": "fetch_attachments"},

    # 🤖 summarize_emails
    {"text": "Summarize all today's mails", "intent": "summarize_emails"},
    {"text": "Give a brief of unread messages", "intent": "summarize_emails"},
    {"text": "Can you give an overview of last night’s emails?", "intent": "summarize_emails"},
    {"text": "What's the summary of my latest emails?", "intent": "summarize_emails"},
    {"text": "Quickly summarize my inbox", "intent": "summarize_emails"},
]

# %%
email_data += [
    # 📨 fetch_last_n
    {"text": "Show me my latest 10 emails", "intent": "fetch_last_n"},
    {"text": "Can you display the 7 most recent mails?", "intent": "fetch_last_n"},
    {"text": "I want to read the last 15 emails", "intent": "fetch_last_n"},
    {"text": "Pull the last set of emails I got", "intent": "fetch_last_n"},
    {"text": "Retrieve the most recent messages", "intent": "fetch_last_n"},

    # 👤 fetch_by_sender
    {"text": "Give me mails from Infosys HR", "intent": "fetch_by_sender"},
    {"text": "Any updates from Rahul in my inbox?", "intent": "fetch_by_sender"},
    {"text": "Do I have messages from Flipkart?", "intent": "fetch_by_sender"},
    {"text": "Fetch all mails from support@abc.com", "intent": "fetch_by_sender"},
    {"text": "Pull conversations with John Doe", "intent": "fetch_by_sender"},

    # 🆕 fetch_unread
    {"text": "What mails are unread?", "intent": "fetch_unread"},
    {"text": "List all messages I haven’t seen yet", "intent": "fetch_unread"},
    {"text": "Which emails are still unopened?", "intent": "fetch_unread"},
    {"text": "Are there any unseen emails today?", "intent": "fetch_unread"},
    {"text": "Unread messages from this week", "intent": "fetch_unread"},

    # ⭐ fetch_important
    {"text": "Show me flagged emails only", "intent": "fetch_important"},
    {"text": "Get important work emails", "intent": "fetch_important"},
    {"text": "Find mails marked as starred", "intent": "fetch_important"},
    {"text": "List high-priority items in my inbox", "intent": "fetch_important"},
    {"text": "Pull all priority mails", "intent": "fetch_important"},

    # 📅 fetch_date_range
    {"text": "Emails received from 1st to 5th July", "intent": "fetch_date_range"},
    {"text": "Messages between the weekend and now", "intent": "fetch_date_range"},
    {"text": "Can I view last month’s emails?", "intent": "fetch_date_range"},
    {"text": "Emails I received in June", "intent": "fetch_date_range"},
    {"text": "Fetch emails sent during holidays", "intent": "fetch_date_range"},

    # 🏷️ fetch_by_label
    {"text": "Get emails from the 'Finance' label", "intent": "fetch_by_label"},
    {"text": "Show messages under label 'College'", "intent": "fetch_by_label"},
    {"text": "Open all mails in the 'Banking' label", "intent": "fetch_by_label"},
    {"text": "Retrieve messages tagged with 'Family'", "intent": "fetch_by_label"},
    {"text": "Emails labeled as 'Job Offers'", "intent": "fetch_by_label"},

    # 📝 fetch_by_subject
    {"text": "Find emails with subject ‘feedback’", "intent": "fetch_by_subject"},
    {"text": "Check mails with subject about attendance", "intent": "fetch_by_subject"},
    {"text": "Search subject lines with word 'project'", "intent": "fetch_by_subject"},
    {"text": "Emails with subject starting with ‘Alert’", "intent": "fetch_by_subject"},
    {"text": "Pull subject lines related to ‘payment’", "intent": "fetch_by_subject"},

    # 📎 fetch_attachments
    {"text": "Show emails with documents attached", "intent": "fetch_attachments"},
    {"text": "Find emails that include a PDF file", "intent": "fetch_attachments"},
    {"text": "Retrieve emails that contain attachments", "intent": "fetch_attachments"},
    {"text": "Any mails with file downloads?", "intent": "fetch_attachments"},
    {"text": "Download attachments from recent mails", "intent": "fetch_attachments"},

    # 🤖 summarize_emails
    {"text": "Give me a short version of the new emails", "intent": "summarize_emails"},
    {"text": "Summarize last week's messages", "intent": "summarize_emails"},
    {"text": "Quick summary of recent emails", "intent": "summarize_emails"},
    {"text": "What’s the gist of today’s emails?", "intent": "summarize_emails"},
    {"text": "Brief the unread emails", "intent": "summarize_emails"},
]

# %%
email_data += [
    # 📨 fetch_last_n
    {"text": "Can you list the last few emails I received?", "intent": "fetch_last_n"},
    {"text": "I need a look at my previous 20 messages", "intent": "fetch_last_n"},
    {"text": "Load recent mails from my inbox", "intent": "fetch_last_n"},
    {"text": "Bring up the last 3 emails", "intent": "fetch_last_n"},
    {"text": "What were the last emails I got?", "intent": "fetch_last_n"},

    # 👤 fetch_by_sender
    {"text": "Check for any messages from my boss", "intent": "fetch_by_sender"},
    {"text": "Look for emails sent by team@startup.io", "intent": "fetch_by_sender"},
    {"text": "Anything from Rajesh in the mailbox?", "intent": "fetch_by_sender"},
    {"text": "Show emails I got from the director", "intent": "fetch_by_sender"},
    {"text": "Find mails by Paytm", "intent": "fetch_by_sender"},

    # 🆕 fetch_unread
    {"text": "Which messages are still unread?", "intent": "fetch_unread"},
    {"text": "Highlight unseen messages", "intent": "fetch_unread"},
    {"text": "List new emails I haven't opened yet", "intent": "fetch_unread"},
    {"text": "I want to read unread mail only", "intent": "fetch_unread"},
    {"text": "Are there any new emails for me?", "intent": "fetch_unread"},

    # ⭐ fetch_important
    {"text": "Show all important mails", "intent": "fetch_important"},
    {"text": "Which messages are starred?", "intent": "fetch_important"},
    {"text": "Open my priority emails", "intent": "fetch_important"},
    {"text": "Get me flagged messages from inbox", "intent": "fetch_important"},
    {"text": "Fetch all starred items", "intent": "fetch_important"},

    # 📅 fetch_date_range
    {"text": "Show emails I got over the past weekend", "intent": "fetch_date_range"},
    {"text": "Display all mails from 10 to 20 June", "intent": "fetch_date_range"},
    {"text": "Emails I received last Thursday", "intent": "fetch_date_range"},
    {"text": "Mails from this week only", "intent": "fetch_date_range"},
    {"text": "Get me emails from January", "intent": "fetch_date_range"},

    # 🏷️ fetch_by_label
    {"text": "Fetch emails labeled ‘Updates’", "intent": "fetch_by_label"},
    {"text": "Get me ‘Receipts’ label emails", "intent": "fetch_by_label"},
    {"text": "Look into the ‘Newsletters’ folder", "intent": "fetch_by_label"},
    {"text": "Open my ‘To-Do’ labeled emails", "intent": "fetch_by_label"},
    {"text": "What’s under the ‘Internship’ label?", "intent": "fetch_by_label"},

    # 📝 fetch_by_subject
    {"text": "Find emails with subject ‘Meeting rescheduled’", "intent": "fetch_by_subject"},
    {"text": "Locate messages mentioning 'interview' in subject", "intent": "fetch_by_subject"},
    {"text": "Emails about ‘delivery status’ in subject line", "intent": "fetch_by_subject"},
    {"text": "Subjects containing ‘OTP’", "intent": "fetch_by_subject"},
    {"text": "Which messages had 'Assignment' in subject?", "intent": "fetch_by_subject"},

    # 📎 fetch_attachments
    {"text": "Show mails that include pictures", "intent": "fetch_attachments"},
    {"text": "Get emails with resumes attached", "intent": "fetch_attachments"},
    {"text": "I need emails that contain any files", "intent": "fetch_attachments"},
    {"text": "Find the mail with the Excel sheet", "intent": "fetch_attachments"},
    {"text": "Download all email attachments", "intent": "fetch_attachments"},

    # 🤖 summarize_emails
    {"text": "Give me summaries of today’s emails", "intent": "summarize_emails"},
    {"text": "Summarize all unread messages", "intent": "summarize_emails"},
    {"text": "Can you briefly explain recent emails?", "intent": "summarize_emails"},
    {"text": "A quick summary of my latest messages", "intent": "summarize_emails"},
    {"text": "I want a summary of inbox conversations", "intent": "summarize_emails"},
]

# %%
email_data += [

    # 📨 fetch_last_n
    {"text": "Read out the last few emails I got", "intent": "fetch_last_n"},
    {"text": "Show me my 10 most recent mails", "intent": "fetch_last_n"},
    {"text": "Bring up my latest email threads", "intent": "fetch_last_n"},
    {"text": "List my newest emails from inbox", "intent": "fetch_last_n"},
    {"text": "Retrieve the past couple of emails", "intent": "fetch_last_n"},

    # 👤 fetch_by_sender
    {"text": "Open emails from Google", "intent": "fetch_by_sender"},
    {"text": "Do I have anything from Flipkart?", "intent": "fetch_by_sender"},
    {"text": "Check if I received something from infosys.hr@job.com", "intent": "fetch_by_sender"},
    {"text": "Search for emails by customer support", "intent": "fetch_by_sender"},
    {"text": "Any message sent by Shraddha?", "intent": "fetch_by_sender"},

    # 🆕 fetch_unread
    {"text": "Which messages are still pending to be read?", "intent": "fetch_unread"},
    {"text": "Only show the unread emails please", "intent": "fetch_unread"},
    {"text": "Do I have unread mail?", "intent": "fetch_unread"},
    {"text": "Unread messages only", "intent": "fetch_unread"},
    {"text": "List fresh unread messages", "intent": "fetch_unread"},

    # ⭐ fetch_important
    {"text": "Display all flagged messages", "intent": "fetch_important"},
    {"text": "Open my VIP or important emails", "intent": "fetch_important"},
    {"text": "Check if I have any marked messages", "intent": "fetch_important"},
    {"text": "Give me the starred mails from inbox", "intent": "fetch_important"},
    {"text": "Prioritize important messages", "intent": "fetch_important"},

    # 📅 fetch_date_range
    {"text": "Search emails from the last month", "intent": "fetch_date_range"},
    {"text": "Any messages I got between May 10 and May 20?", "intent": "fetch_date_range"},
    {"text": "Show the mails from yesterday", "intent": "fetch_date_range"},
    {"text": "Emails that came in this week", "intent": "fetch_date_range"},
    {"text": "Filter emails from the first week of July", "intent": "fetch_date_range"},

    # 🏷️ fetch_by_label
    {"text": "Read mails from my ‘Shopping’ label", "intent": "fetch_by_label"},
    {"text": "Open ‘College’ label messages", "intent": "fetch_by_label"},
    {"text": "Filter emails marked as ‘Finance’", "intent": "fetch_by_label"},
    {"text": "Fetch all emails categorized under ‘Banking’", "intent": "fetch_by_label"},
    {"text": "Only show me the ‘Personal’ emails", "intent": "fetch_by_label"},

    # 📝 fetch_by_subject
    {"text": "List emails about fee payment in the subject", "intent": "fetch_by_subject"},
    {"text": "Search emails with subject like ‘project deadline’", "intent": "fetch_by_subject"},
    {"text": "Any mail subject containing ‘results’?", "intent": "fetch_by_subject"},
    {"text": "I want all messages with ‘update’ in the title", "intent": "fetch_by_subject"},
    {"text": "Locate subjects with the word ‘holiday’", "intent": "fetch_by_subject"},

    # 📎 fetch_attachments
    {"text": "Find all mails with PDFs attached", "intent": "fetch_attachments"},
    {"text": "Get emails that had photos or media", "intent": "fetch_attachments"},
    {"text": "Mails where files were shared", "intent": "fetch_attachments"},
    {"text": "Download all files from the last 5 emails", "intent": "fetch_attachments"},
    {"text": "Show me messages with zip attachments", "intent": "fetch_attachments"},

    # 🤖 summarize_emails
    {"text": "Give me a short version of the inbox emails", "intent": "summarize_emails"},
    {"text": "Summarize all today's email activity", "intent": "summarize_emails"},
    {"text": "Can you give me a gist of my recent emails?", "intent": "summarize_emails"},
    {"text": "What’s the summary of unread emails?", "intent": "summarize_emails"},
    {"text": "Summarize latest 5 messages", "intent": "summarize_emails"},
]

# %%
email_data += [

    # fetch_last_n
    {"text": "Get me the last three messages I received", "intent": "fetch_last_n"},
    {"text": "What are the most recent emails in my inbox?", "intent": "fetch_last_n"},
    {"text": "Fetch recent 15 emails", "intent": "fetch_last_n"},
    {"text": "Pull up my newest mails", "intent": "fetch_last_n"},
    {"text": "Load the last batch of emails", "intent": "fetch_last_n"},

    # fetch_by_sender
    {"text": "Show messages from my manager", "intent": "fetch_by_sender"},
    {"text": "Do I have anything from Paytm?", "intent": "fetch_by_sender"},
    {"text": "Look for mails sent by HR", "intent": "fetch_by_sender"},
    {"text": "Filter emails from ravi.kumar@company.com", "intent": "fetch_by_sender"},
    {"text": "Read mails from ICICI Bank", "intent": "fetch_by_sender"},

    # fetch_unread
    {"text": "Which mails are unread right now?", "intent": "fetch_unread"},
    {"text": "List only unread emails", "intent": "fetch_unread"},
    {"text": "Unread mails please", "intent": "fetch_unread"},
    {"text": "Any fresh messages I haven’t seen yet?", "intent": "fetch_unread"},
    {"text": "Still unopened emails?", "intent": "fetch_unread"},

    # fetch_important
    {"text": "Prioritize the emails marked as urgent", "intent": "fetch_important"},
    {"text": "Open my flagged messages", "intent": "fetch_important"},
    {"text": "Important emails only", "intent": "fetch_important"},
    {"text": "Any mails marked as priority?", "intent": "fetch_important"},
    {"text": "Show me the top priority mails", "intent": "fetch_important"},

    # fetch_date_range
    {"text": "Grab emails from last Friday", "intent": "fetch_date_range"},
    {"text": "What did I receive on July 10th?", "intent": "fetch_date_range"},
    {"text": "Emails between 1st and 5th of this month", "intent": "fetch_date_range"},
    {"text": "Filter messages from this weekend", "intent": "fetch_date_range"},
    {"text": "Show mails received during the festival week", "intent": "fetch_date_range"},

    # fetch_by_label
    {"text": "Show me all 'Work' tagged emails", "intent": "fetch_by_label"},
    {"text": "Get mails under the 'Travel' category", "intent": "fetch_by_label"},
    {"text": "View emails labelled as 'Receipts'", "intent": "fetch_by_label"},
    {"text": "Only fetch 'Newsletter' emails", "intent": "fetch_by_label"},
    {"text": "I want to check mails in 'Academic' folder", "intent": "fetch_by_label"},

    # fetch_by_subject
    {"text": "Get mails with ‘invoice’ in the subject", "intent": "fetch_by_subject"},
    {"text": "Find messages with the title ‘assignment’", "intent": "fetch_by_subject"},
    {"text": "Subject should contain ‘update’", "intent": "fetch_by_subject"},
    {"text": "Search emails with topic as ‘reschedule’", "intent": "fetch_by_subject"},
    {"text": "Show subject lines with the word ‘interview’", "intent": "fetch_by_subject"},

    # fetch_attachments
    {"text": "Which emails have Excel files attached?", "intent": "fetch_attachments"},
    {"text": "Find messages with any kind of attachment", "intent": "fetch_attachments"},
    {"text": "Show emails that include a resume", "intent": "fetch_attachments"},
    {"text": "Any documents sent to me recently?", "intent": "fetch_attachments"},
    {"text": "Retrieve mails with images or docs", "intent": "fetch_attachments"},

    # summarize_emails
    {"text": "Summarize what I got in my inbox this week", "intent": "summarize_emails"},
    {"text": "Brief summary of all new emails", "intent": "summarize_emails"},
    {"text": "Can you summarize today’s incoming mails?", "intent": "summarize_emails"},
    {"text": "Give me the highlights from my inbox", "intent": "summarize_emails"},
    {"text": "Summarize only the important unread emails", "intent": "summarize_emails"},
]

# %%
email_data += [

    # fetch_last_n
    {"text": "Give me the last few emails I got", "intent": "fetch_last_n"},
    {"text": "What were my latest mails?", "intent": "fetch_last_n"},
    {"text": "Display the most recent five messages", "intent": "fetch_last_n"},
    {"text": "Pull up my last 7 mails", "intent": "fetch_last_n"},
    {"text": "I want to see my last batch of emails", "intent": "fetch_last_n"},

    # fetch_by_sender
    {"text": "Open all messages from Flipkart", "intent": "fetch_by_sender"},
    {"text": "Anything from cdac.pune today?", "intent": "fetch_by_sender"},
    {"text": "Get emails that Ravi sent me", "intent": "fetch_by_sender"},
    {"text": "Do I have anything from notifications@linkedin.com?", "intent": "fetch_by_sender"},
    {"text": "Show me messages sent by my colleague Neha", "intent": "fetch_by_sender"},

    # fetch_unread
    {"text": "Unread emails from this morning?", "intent": "fetch_unread"},
    {"text": "Tell me which messages I haven't opened", "intent": "fetch_unread"},
    {"text": "Any new unread notifications?", "intent": "fetch_unread"},
    {"text": "Mails I haven't checked yet", "intent": "fetch_unread"},
    {"text": "I want to see only unread stuff", "intent": "fetch_unread"},

    # fetch_important
    {"text": "What are my starred emails?", "intent": "fetch_important"},
    {"text": "List flagged mails", "intent": "fetch_important"},
    {"text": "Important emails from the past week", "intent": "fetch_important"},
    {"text": "Just show the marked important messages", "intent": "fetch_important"},
    {"text": "Access only critical priority emails", "intent": "fetch_important"},

    # fetch_date_range
    {"text": "Which mails came between Jan 1 and Jan 10?", "intent": "fetch_date_range"},
    {"text": "Get emails from last Monday", "intent": "fetch_date_range"},
    {"text": "All emails from yesterday", "intent": "fetch_date_range"},
    {"text": "Pull mails from this month only", "intent": "fetch_date_range"},
    {"text": "Retrieve emails from April to May", "intent": "fetch_date_range"},

    # fetch_by_label
    {"text": "Show me emails labeled as ‘Finance’", "intent": "fetch_by_label"},
    {"text": "Get only mails in the Promotions category", "intent": "fetch_by_label"},
    {"text": "Emails tagged under ‘Bills’ please", "intent": "fetch_by_label"},
    {"text": "Read all items in ‘Family’ label", "intent": "fetch_by_label"},
    {"text": "Fetch messages in ‘To-do’ folder", "intent": "fetch_by_label"},

    # fetch_by_subject
    {"text": "Search for messages with subject about ‘meeting’", "intent": "fetch_by_subject"},
    {"text": "Check for titles containing ‘project update’", "intent": "fetch_by_subject"},
    {"text": "Look for subjects that say ‘offer letter’", "intent": "fetch_by_subject"},
    {"text": "Subject line should include ‘notice’", "intent": "fetch_by_subject"},
    {"text": "Emails with subject containing the word ‘form’", "intent": "fetch_by_subject"},

    # fetch_attachments
    {"text": "Any PDF files in my mail today?", "intent": "fetch_attachments"},
    {"text": "Find mails that include any attachment", "intent": "fetch_attachments"},
    {"text": "Get messages with files", "intent": "fetch_attachments"},
    {"text": "Retrieve mails that came with docs or images", "intent": "fetch_attachments"},
    {"text": "Which messages have anything attached?", "intent": "fetch_attachments"},

    # summarize_emails
    {"text": "Can you give me a summary of my recent emails?", "intent": "summarize_emails"},
    {"text": "Summarize my last 10 messages", "intent": "summarize_emails"},
    {"text": "Tell me what my inbox looks like today", "intent": "summarize_emails"},
    {"text": "Give me the key points from today’s emails", "intent": "summarize_emails"},
    {"text": "A brief of unread and flagged mails please", "intent": "summarize_emails"},
]

# %%
email_data += [

    # 📨 fetch_last_n
    {"text": "Show top 7 latest emails", "intent": "fetch_last_n"},
    {"text": "Give me a list of my last 15 messages", "intent": "fetch_last_n"},
    {"text": "I want to see the last few emails I received", "intent": "fetch_last_n"},
    {"text": "List out my 10 most recent mails", "intent": "fetch_last_n"},
    {"text": "Can you show me the recent 8 mails?", "intent": "fetch_last_n"},

    # 👤 fetch_by_sender
    {"text": "Do I have any emails from Amazon?", "intent": "fetch_by_sender"},
    {"text": "Fetch all mails received from my professor", "intent": "fetch_by_sender"},
    {"text": "Any mail from my bank?", "intent": "fetch_by_sender"},
    {"text": "Find all messages sent by support@udemy.com", "intent": "fetch_by_sender"},
    {"text": "Search for emails from newsletter@medium.com", "intent": "fetch_by_sender"},

    # 🆕 fetch_unread
    {"text": "Are there any unread messages?", "intent": "fetch_unread"},
    {"text": "Check for unread notifications in mail", "intent": "fetch_unread"},
    {"text": "Can you filter only unread emails?", "intent": "fetch_unread"},
    {"text": "List all unread mails from my inbox", "intent": "fetch_unread"},
    {"text": "Which mails haven’t I read yet?", "intent": "fetch_unread"},

    # ⭐ fetch_important
    {"text": "I need to see my starred messages", "intent": "fetch_important"},
    {"text": "Show high-priority mails", "intent": "fetch_important"},
    {"text": "List emails marked as important", "intent": "fetch_important"},
    {"text": "Display only the starred ones", "intent": "fetch_important"},
    {"text": "Which emails are flagged?", "intent": "fetch_important"},

    # 📅 fetch_date_range
    {"text": "Show emails from July 1 to July 15", "intent": "fetch_date_range"},
    {"text": "Display mails between last Monday and today", "intent": "fetch_date_range"},
    {"text": "What messages did I receive in the last 3 days?", "intent": "fetch_date_range"},
    {"text": "Get emails from the second week of June", "intent": "fetch_date_range"},
    {"text": "Filter emails from the month of March", "intent": "fetch_date_range"},

    # 🏷️ fetch_by_label
    {"text": "Find emails under the Updates tab", "intent": "fetch_by_label"},
    {"text": "Get messages labeled Finance", "intent": "fetch_by_label"},
    {"text": "Show my Travel labeled emails", "intent": "fetch_by_label"},
    {"text": "Which mails are tagged Personal?", "intent": "fetch_by_label"},
    {"text": "Fetch messages from Promotions", "intent": "fetch_by_label"},

    # 📝 fetch_by_subject
    {"text": "Search for emails with 'Exam Schedule' in the subject", "intent": "fetch_by_subject"},
    {"text": "Find all emails where subject contains 'OTP'", "intent": "fetch_by_subject"},
    {"text": "Get mails with subject line starting with 'Invoice'", "intent": "fetch_by_subject"},
    {"text": "Any mail with subject 'Leave Approval'?", "intent": "fetch_by_subject"},
    {"text": "Search for messages with 'Result Declared' in the title", "intent": "fetch_by_subject"},

    # 📎 fetch_attachments
    {"text": "List out all mails that have attachments", "intent": "fetch_attachments"},
    {"text": "Download PDFs from recent emails", "intent": "fetch_attachments"},
    {"text": "Find documents attached in last 5 mails", "intent": "fetch_attachments"},
    {"text": "I want to see the attachments I got today", "intent": "fetch_attachments"},
    {"text": "Get all email files", "intent": "fetch_attachments"},

    # 🤖 summarize_emails
    {"text": "Summarize emails from yesterday", "intent": "summarize_emails"},
    {"text": "Can you summarize all unread messages?", "intent": "summarize_emails"},
    {"text": "Give me a gist of today's emails", "intent": "summarize_emails"},
    {"text": "Show a brief summary of my latest emails", "intent": "summarize_emails"},
    {"text": "Tell me what all my mails from HR are about", "intent": "summarize_emails"},
]

# %%
email_data += [
    # 📨 fetch_last_n
    {"text": "I want to see my 5 most recent emails", "intent": "fetch_last_n"},
    {"text": "Retrieve my latest email messages", "intent": "fetch_last_n"},
    {"text": "Fetch the newest 7 mails I got", "intent": "fetch_last_n"},
    {"text": "Bring up the last few messages", "intent": "fetch_last_n"},
    {"text": "Get the most recent inbox mails", "intent": "fetch_last_n"},

    # 👤 fetch_by_sender
    {"text": "I want to see emails sent by Priya", "intent": "fetch_by_sender"},
    {"text": "Show me all mails from boss@company.com", "intent": "fetch_by_sender"},
    {"text": "Retrieve messages from my professor", "intent": "fetch_by_sender"},
    {"text": "Give me the emails that came from Amazon", "intent": "fetch_by_sender"},
    {"text": "Get conversations with Ramesh", "intent": "fetch_by_sender"},

    # 🆕 fetch_unread
    {"text": "Can you show only unread ones?", "intent": "fetch_unread"},
    {"text": "I haven't read these—fetch them", "intent": "fetch_unread"},
    {"text": "What are my new mails?", "intent": "fetch_unread"},
    {"text": "Only display mails I haven't opened yet", "intent": "fetch_unread"},
    {"text": "Filter unread mails", "intent": "fetch_unread"},

    # ⭐ fetch_important
    {"text": "Bring only the starred emails", "intent": "fetch_important"},
    {"text": "Get high importance messages", "intent": "fetch_important"},
    {"text": "Which emails are marked as important?", "intent": "fetch_important"},
    {"text": "I want to review my important mails", "intent": "fetch_important"},
    {"text": "Check for any flagged or starred mail", "intent": "fetch_important"},

    # 📅 fetch_date_range
    {"text": "Mails I received over the weekend", "intent": "fetch_date_range"},
    {"text": "Show messages from 1st June to 10th June", "intent": "fetch_date_range"},
    {"text": "Fetch all emails from this month", "intent": "fetch_date_range"},
    {"text": "Only get mails from last Monday", "intent": "fetch_date_range"},
    {"text": "Filter my inbox by date — this week", "intent": "fetch_date_range"},

    # 🏷️ fetch_by_label
    {"text": "Give me the mails tagged as Finance", "intent": "fetch_by_label"},
    {"text": "I need all emails under the 'Academics' label", "intent": "fetch_by_label"},
    {"text": "Get everything labeled 'Friends'", "intent": "fetch_by_label"},
    {"text": "Only show mails from my Work folder", "intent": "fetch_by_label"},
    {"text": "Fetch all updates category messages", "intent": "fetch_by_label"},

    # 📝 fetch_by_subject
    {"text": "Search for emails mentioning 'exam schedule' in subject", "intent": "fetch_by_subject"},
    {"text": "Get mails titled with 'Meeting Agenda'", "intent": "fetch_by_subject"},
    {"text": "Find subjects that include 'Offer Letter'", "intent": "fetch_by_subject"},
    {"text": "Filter messages with 'Project Update' in subject line", "intent": "fetch_by_subject"},
    {"text": "I want to check all subjects mentioning 'interview'", "intent": "fetch_by_subject"},

    # 📎 fetch_attachments
    {"text": "Download all files from recent mails", "intent": "fetch_attachments"},
    {"text": "List all email attachments I received this week", "intent": "fetch_attachments"},
    {"text": "Find messages that include a PDF", "intent": "fetch_attachments"},
    {"text": "Get emails with downloadable content", "intent": "fetch_attachments"},
    {"text": "Are there any docs sent to me recently?", "intent": "fetch_attachments"},

    # 🤖 summarize_emails
    {"text": "Can you summarize today's emails?", "intent": "summarize_emails"},
    {"text": "Summarize important messages I received", "intent": "summarize_emails"},
    {"text": "Provide a brief of last week's emails", "intent": "summarize_emails"},
    {"text": "What's the summary of emails from yesterday?", "intent": "summarize_emails"},
    {"text": "Give me a quick overview of messages from my manager", "intent": "summarize_emails"},
    {"text": "Give me gist of 5 emails from Flipkart", "intent": "summarize_emails"},
    {"text": "What did my boss say in last 3 emails?", "intent": "summarize_emails"},
]

# %%
email_data += [
    # 📨 fetch_last_n
    {"text": "Show the last 10 messages I got", "intent": "fetch_last_n"},
    {"text": "What are my latest few emails?", "intent": "fetch_last_n"},
    {"text": "Can I see my most recent mails?", "intent": "fetch_last_n"},
    {"text": "Give me the previous five mails", "intent": "fetch_last_n"},
    {"text": "I want the last batch of messages", "intent": "fetch_last_n"},

    # 👤 fetch_by_sender
    {"text": "Display messages sent by Rahul", "intent": "fetch_by_sender"},
    {"text": "I want all mails from HDFC Bank", "intent": "fetch_by_sender"},
    {"text": "Which messages came from Aditi?", "intent": "fetch_by_sender"},
    {"text": "Retrieve everything sent by Flipkart", "intent": "fetch_by_sender"},
    {"text": "Get messages from sender email abc@gmail.com", "intent": "fetch_by_sender"},

    # 🆕 fetch_unread
    {"text": "Which mails are still unread?", "intent": "fetch_unread"},
    {"text": "I haven’t opened these emails—show them", "intent": "fetch_unread"},
    {"text": "Display messages I missed reading", "intent": "fetch_unread"},
    {"text": "Are there any unseen emails?", "intent": "fetch_unread"},
    {"text": "List only unread messages", "intent": "fetch_unread"},

    # ⭐ fetch_important
    {"text": "I only want mails marked urgent", "intent": "fetch_important"},
    {"text": "Pull up critical or starred emails", "intent": "fetch_important"},
    {"text": "Filter out all flagged emails", "intent": "fetch_important"},
    {"text": "Highlight mails marked with importance", "intent": "fetch_important"},
    {"text": "Get mails that I tagged important", "intent": "fetch_important"},

    # 📅 fetch_date_range
    {"text": "Search for mails between Jan 1 and Jan 10", "intent": "fetch_date_range"},
    {"text": "Get emails I got in December", "intent": "fetch_date_range"},
    {"text": "Fetch messages received last Friday", "intent": "fetch_date_range"},
    {"text": "What mails came last month?", "intent": "fetch_date_range"},
    {"text": "Show only mails from today", "intent": "fetch_date_range"},

    # 🏷️ fetch_by_label
    {"text": "Check my inbox for 'Work' label", "intent": "fetch_by_label"},
    {"text": "Get all messages labeled 'Family'", "intent": "fetch_by_label"},
    {"text": "I want to browse through the 'Updates' tab", "intent": "fetch_by_label"},
    {"text": "Only show 'Promotions' emails", "intent": "fetch_by_label"},
    {"text": "Filter messages from the 'Newsletters' folder", "intent": "fetch_by_label"},

    # 📝 fetch_by_subject
    {"text": "Look for subject lines with 'Deadline'", "intent": "fetch_by_subject"},
    {"text": "Search for messages about 'Fee Payment'", "intent": "fetch_by_subject"},
    {"text": "Get all subjects with 'Invoice' in it", "intent": "fetch_by_subject"},
    {"text": "Find emails related to 'Reminder'", "intent": "fetch_by_subject"},
    {"text": "Any mails with 'Results' as the subject?", "intent": "fetch_by_subject"},

    # 📎 fetch_attachments
    {"text": "List emails that include attachments", "intent": "fetch_attachments"},
    {"text": "Get all photos or documents sent recently", "intent": "fetch_attachments"},
    {"text": "Are there any emails with files attached?", "intent": "fetch_attachments"},
    {"text": "Show emails with ZIP or DOC files", "intent": "fetch_attachments"},
    {"text": "I want the mails where a file was shared", "intent": "fetch_attachments"},

    # 🤖 summarize_emails
    {"text": "Summarize all unread emails", "intent": "summarize_emails"},
    {"text": "Can you quickly summarize my inbox?", "intent": "summarize_emails"},
    {"text": "I need a summary of today's conversations", "intent": "summarize_emails"},
    {"text": "Give me the gist of recent important mails", "intent": "summarize_emails"},
    {"text": "Brief me on the last 3 mails from boss", "intent": "summarize_emails"},
    {"text": "Provide highlights of my emails", "intent": "summarize_emails"},
    {"text": "Make a summary of my messages from Google", "intent": "summarize_emails"},
    {"text": "Can you tell me what my last emails were about?", "intent": "summarize_emails"},
]

# %%
email_data += [
    # 📨 fetch_last_n
    {"text": "Just show me my last 3 emails", "intent": "fetch_last_n"},
    {"text": "Display the latest batch of emails", "intent": "fetch_last_n"},
    {"text": "Open the most recent five mails", "intent": "fetch_last_n"},
    {"text": "Get my newest few emails", "intent": "fetch_last_n"},
    {"text": "Check latest inbox entries", "intent": "fetch_last_n"},

    # 👤 fetch_by_sender
    {"text": "I only want emails from my HR", "intent": "fetch_by_sender"},
    {"text": "Show me all mail from Flipkart", "intent": "fetch_by_sender"},
    {"text": "Get everything that John sent", "intent": "fetch_by_sender"},
    {"text": "Any updates from support@xyz.com?", "intent": "fetch_by_sender"},
    {"text": "Emails from Paytm only", "intent": "fetch_by_sender"},

    # 🆕 fetch_unread
    {"text": "Get me mails I haven't seen yet", "intent": "fetch_unread"},
    {"text": "Unread emails only, please", "intent": "fetch_unread"},
    {"text": "Which messages are pending to be read?", "intent": "fetch_unread"},
    {"text": "Only fetch unread items", "intent": "fetch_unread"},
    {"text": "New messages I haven’t opened yet", "intent": "fetch_unread"},

    # ⭐ fetch_important
    {"text": "Important emails from this week", "intent": "fetch_important"},
    {"text": "What are my flagged mails?", "intent": "fetch_important"},
    {"text": "Find the high priority emails", "intent": "fetch_important"},
    {"text": "I want to view starred emails only", "intent": "fetch_important"},
    {"text": "Pull out critical messages", "intent": "fetch_important"},

    # 📅 fetch_date_range
    {"text": "Emails I got in the last 2 days", "intent": "fetch_date_range"},
    {"text": "Filter messages from July 1 to July 15", "intent": "fetch_date_range"},
    {"text": "Get mails from the past weekend", "intent": "fetch_date_range"},
    {"text": "All emails received during the holidays", "intent": "fetch_date_range"},
    {"text": "Show me emails from last month", "intent": "fetch_date_range"},

    # 🏷️ fetch_by_label
    {"text": "Only work-related messages", "intent": "fetch_by_label"},
    {"text": "Show personal emails category", "intent": "fetch_by_label"},
    {"text": "Mails marked 'Urgent'", "intent": "fetch_by_label"},
    {"text": "Open all emails from the Promotions tab", "intent": "fetch_by_label"},
    {"text": "Get emails tagged as 'Social'", "intent": "fetch_by_label"},

    # 📝 fetch_by_subject
    {"text": "Find subjects containing 'schedule'", "intent": "fetch_by_subject"},
    {"text": "Search subject lines for 'Meeting'", "intent": "fetch_by_subject"},
    {"text": "Emails with subject 'Offer Update'", "intent": "fetch_by_subject"},
    {"text": "All messages titled 'Results'", "intent": "fetch_by_subject"},
    {"text": "Anything with 'Deadline' in the subject", "intent": "fetch_by_subject"},

    # 📎 fetch_attachments
    {"text": "Fetch messages that have attachments", "intent": "fetch_attachments"},
    {"text": "Get emails with Excel files", "intent": "fetch_attachments"},
    {"text": "Download all PDFs from recent mails", "intent": "fetch_attachments"},
    {"text": "Any email that came with a document?", "intent": "fetch_attachments"},
    {"text": "Get all emails with file attachments", "intent": "fetch_attachments"},

    # 🤖 summarize_emails
    {"text": "Can you give me a gist of this week's mails?", "intent": "summarize_emails"},
    {"text": "I want a short summary of emails from yesterday", "intent": "summarize_emails"},
    {"text": "Summarize emails from my professor", "intent": "summarize_emails"},
    {"text": "What are the key points in today's inbox?", "intent": "summarize_emails"},
    {"text": "Read and summarize 5 latest messages", "intent": "summarize_emails"},
    {"text": "Give quick notes of important mails", "intent": "summarize_emails"},
    {"text": "Summarize emails from Rahul sent this morning", "intent": "summarize_emails"},
]

# %%
email_data += [
    # 📨 fetch_last_n
    {"text": "Just show me my last 10 emails", "intent": "fetch_last_n"},
    {"text": "Bring me the latest couple of emails", "intent": "fetch_last_n"},
    {"text": "Can you get my most recent 3 messages?", "intent": "fetch_last_n"},
    {"text": "Check what's in the last few emails", "intent": "fetch_last_n"},
    {"text": "Display previous few emails", "intent": "fetch_last_n"},

    # 👤 fetch_by_sender
    {"text": "Do I have anything from HR?", "intent": "fetch_by_sender"},
    {"text": "Search for emails from my recruiter", "intent": "fetch_by_sender"},
    {"text": "Filter by sender 'info@newsletter.com'", "intent": "fetch_by_sender"},
    {"text": "Find emails that Riya sent", "intent": "fetch_by_sender"},
    {"text": "Did I receive anything from support@abc.com?", "intent": "fetch_by_sender"},

    # 🆕 fetch_unread
    {"text": "Anything I haven’t read yet?", "intent": "fetch_unread"},
    {"text": "Unseen emails only please", "intent": "fetch_unread"},
    {"text": "What’s new in my inbox?", "intent": "fetch_unread"},
    {"text": "Unread items from today", "intent": "fetch_unread"},
    {"text": "List the emails I missed", "intent": "fetch_unread"},

    # ⭐ fetch_important
    {"text": "Only the critical or flagged emails", "intent": "fetch_important"},
    {"text": "Highlight the priority mails", "intent": "fetch_important"},
    {"text": "Show only mails with high importance", "intent": "fetch_important"},
    {"text": "Find urgent messages", "intent": "fetch_important"},
    {"text": "What are my most important emails today?", "intent": "fetch_important"},

    # 📅 fetch_date_range
    {"text": "Check what I got last Friday", "intent": "fetch_date_range"},
    {"text": "Give emails between 10th and 15th", "intent": "fetch_date_range"},
    {"text": "Show this week's inbox", "intent": "fetch_date_range"},
    {"text": "Filter mails from last two days", "intent": "fetch_date_range"},
    {"text": "Fetch only mails from this morning", "intent": "fetch_date_range"},

    # 🏷️ fetch_by_label
    {"text": "Get everything from my Social label", "intent": "fetch_by_label"},
    {"text": "Open messages under 'Updates'", "intent": "fetch_by_label"},
    {"text": "Can I view my 'Promotions' folder?", "intent": "fetch_by_label"},
    {"text": "Check emails in my Shopping tag", "intent": "fetch_by_label"},
    {"text": "Show 'Banking' category emails", "intent": "fetch_by_label"},

    # 📝 fetch_by_subject
    {"text": "Find mails with the subject 'Reminder'", "intent": "fetch_by_subject"},
    {"text": "Any subjects titled 'Payment Received'?", "intent": "fetch_by_subject"},
    {"text": "Look for emails titled with 'Flight Ticket'", "intent": "fetch_by_subject"},
    {"text": "Fetch based on subject line 'Invoice'", "intent": "fetch_by_subject"},
    {"text": "Scan for 'Notice' in subject", "intent": "fetch_by_subject"},

    # 📎 fetch_attachments
    {"text": "Pull emails with Excel files", "intent": "fetch_attachments"},
    {"text": "Download recent attachments", "intent": "fetch_attachments"},
    {"text": "Find emails that contain media", "intent": "fetch_attachments"},
    {"text": "Locate mails with attached ZIP files", "intent": "fetch_attachments"},
    {"text": "Show me image attachments", "intent": "fetch_attachments"},

    # 🤖 summarize_emails
    {"text": "Quick summary of this week’s email", "intent": "summarize_emails"},
    {"text": "Give me insights from recent messages", "intent": "summarize_emails"},
    {"text": "Summarize last 10 emails into short notes", "intent": "summarize_emails"},
    {"text": "Make a summary from emails by Anjali", "intent": "summarize_emails"},
    {"text": "Read and condense messages from today", "intent": "summarize_emails"},
    {"text": "Create a report from last few emails", "intent": "summarize_emails"},
    {"text": "Help me understand the main points of my inbox", "intent": "summarize_emails"},
]

# %%
email_data += [

    # 📨 fetch_last_n
    {"text": "Can you retrieve the last few emails I got?", "intent": "fetch_last_n"},
    {"text": "Get me my last 10 messages", "intent": "fetch_last_n"},
    {"text": "Show my most recent mails", "intent": "fetch_last_n"},
    {"text": "Access last set of emails", "intent": "fetch_last_n"},
    {"text": "Open recent inbox mails", "intent": "fetch_last_n"},

    # 👤 fetch_by_sender
    {"text": "What emails did I get from Akash?", "intent": "fetch_by_sender"},
    {"text": "Show all messages sent by Flipkart", "intent": "fetch_by_sender"},
    {"text": "Get conversations with my professor", "intent": "fetch_by_sender"},
    {"text": "Only mails from Deepika", "intent": "fetch_by_sender"},
    {"text": "I want emails that came from recruiter@gmail.com", "intent": "fetch_by_sender"},

    # 🆕 fetch_unread
    {"text": "Do I have any unread messages?", "intent": "fetch_unread"},
    {"text": "Only show mails I haven’t seen yet", "intent": "fetch_unread"},
    {"text": "Give me the new mails", "intent": "fetch_unread"},
    {"text": "Fetch unread messages from yesterday", "intent": "fetch_unread"},
    {"text": "Show me all the unseen emails", "intent": "fetch_unread"},

    # ⭐ fetch_important
    {"text": "Retrieve only the high priority emails", "intent": "fetch_important"},
    {"text": "Which mails are marked as important?", "intent": "fetch_important"},
    {"text": "Important ones only please", "intent": "fetch_important"},
    {"text": "What are my flagged messages?", "intent": "fetch_important"},
    {"text": "Access only priority emails", "intent": "fetch_important"},

    # 🗓️ fetch_date_range
    {"text": "Can I see the emails from last Friday?", "intent": "fetch_date_range"},
    {"text": "Get all mails between March 1st and March 5th", "intent": "fetch_date_range"},
    {"text": "Fetch emails from the past 2 days", "intent": "fetch_date_range"},
    {"text": "Only show mails I got this week", "intent": "fetch_date_range"},
    {"text": "Show mails received during last month", "intent": "fetch_date_range"},

    # 🏷️ fetch_by_label
    {"text": "Retrieve emails under Promotions", "intent": "fetch_by_label"},
    {"text": "Open mails tagged as 'Newsletters'", "intent": "fetch_by_label"},
    {"text": "Filter inbox by 'Work' label", "intent": "fetch_by_label"},
    {"text": "I want only social category messages", "intent": "fetch_by_label"},
    {"text": "View updates labeled 'Banking'", "intent": "fetch_by_label"},

    # 📝 fetch_by_subject
    {"text": "Search mails with subject 'Flight Booking'", "intent": "fetch_by_subject"},
    {"text": "Find emails titled 'Rent Receipt'", "intent": "fetch_by_subject"},
    {"text": "Get mails containing 'Assignment Due' in subject", "intent": "fetch_by_subject"},
    {"text": "Look for subject lines with 'Deadline'", "intent": "fetch_by_subject"},
    {"text": "Show me messages that have 'Interview Call' as subject", "intent": "fetch_by_subject"},

    # 📎 fetch_attachments
    {"text": "Find mails that include attachments", "intent": "fetch_attachments"},
    {"text": "Get emails with files attached", "intent": "fetch_attachments"},
    {"text": "Look for messages with Excel files", "intent": "fetch_attachments"},
    {"text": "Download attachments from inbox", "intent": "fetch_attachments"},
    {"text": "Check for PowerPoint files I received", "intent": "fetch_attachments"},

    # 🤖 summarize_emails
    {"text": "Can you summarize last 5 emails from HR?", "intent": "summarize_emails"},
    {"text": "Give me a summary of recent messages", "intent": "summarize_emails"},
    {"text": "Summarize unread mails", "intent": "summarize_emails"},
    {"text": "What do all emails from boss say this week?", "intent": "summarize_emails"},
    {"text": "Give short summary of today's important mails", "intent": "summarize_emails"},
    {"text": "Summarize what Amazon has sent me recently", "intent": "summarize_emails"},
    {"text": "I need a quick gist of my inbox", "intent": "summarize_emails"},
    {"text": "Just summarize the attachments I received", "intent": "summarize_emails"},
    {"text": "What's the overall message in my new mails?", "intent": "summarize_emails"},
    {"text": "Give a brief overview of conversations with my team", "intent": "summarize_emails"},
]

# %%
email_data += [
    # 📨 fetch_last_n
    {"text": "Pull up my last 10 emails", "intent": "fetch_last_n"},
    {"text": "List the most recent mails I received", "intent": "fetch_last_n"},
    {"text": "Can you get the last batch of emails?", "intent": "fetch_last_n"},
    {"text": "Retrieve my last few email conversations", "intent": "fetch_last_n"},
    {"text": "Access my previous 3 messages", "intent": "fetch_last_n"},

    # 👤 fetch_by_sender
    {"text": "Get messages from Neha", "intent": "fetch_by_sender"},
    {"text": "Filter emails by sender: shruti.patil@xyz.com", "intent": "fetch_by_sender"},
    {"text": "I need mails sent by CDAC Mumbai", "intent": "fetch_by_sender"},
    {"text": "Show all emails exchanged with Raj", "intent": "fetch_by_sender"},
    {"text": "Fetch only those mails which are from Mohan", "intent": "fetch_by_sender"},

    # 🆕 fetch_unread
    {"text": "Highlight the mails I haven’t opened yet", "intent": "fetch_unread"},
    {"text": "List unread messages from the inbox", "intent": "fetch_unread"},
    {"text": "Only show me new unread emails", "intent": "fetch_unread"},
    {"text": "Which mails are pending to be read?", "intent": "fetch_unread"},
    {"text": "I want the messages I haven't seen yet", "intent": "fetch_unread"},

    # ⭐ fetch_important
    {"text": "Pick out my flagged messages", "intent": "fetch_important"},
    {"text": "Which mails are marked with a star?", "intent": "fetch_important"},
    {"text": "Give me the emails with high priority", "intent": "fetch_important"},
    {"text": "Filter out critical or marked messages", "intent": "fetch_important"},
    {"text": "List all priority mails", "intent": "fetch_important"},

    # 📅 fetch_date_range
    {"text": "Get my inbox activity between May 1 and May 5", "intent": "fetch_date_range"},
    {"text": "Show all emails from the second week of April", "intent": "fetch_date_range"},
    {"text": "I want messages received last weekend", "intent": "fetch_date_range"},
    {"text": "Fetch emails sent on March 15", "intent": "fetch_date_range"},
    {"text": "View only mails received yesterday", "intent": "fetch_date_range"},

    # 🏷️ fetch_by_label
    {"text": "Access only the 'Promotions' label", "intent": "fetch_by_label"},
    {"text": "Filter my inbox by 'Personal' folder", "intent": "fetch_by_label"},
    {"text": "I only want to see emails from my 'Newsletters'", "intent": "fetch_by_label"},
    {"text": "Give me mails in the 'Updates' category", "intent": "fetch_by_label"},
    {"text": "Get the emails from 'Social' section", "intent": "fetch_by_label"},

    # 📝 fetch_by_subject
    {"text": "Find mails with 'invoice' in the subject", "intent": "fetch_by_subject"},
    {"text": "Look for subjects that mention 'result'", "intent": "fetch_by_subject"},
    {"text": "Get all messages titled 'Welcome'", "intent": "fetch_by_subject"},
    {"text": "Search for emails that have 'Job Offer' in the subject", "intent": "fetch_by_subject"},
    {"text": "Can you fetch mails that say 'Deadline Reminder'?", "intent": "fetch_by_subject"},

    # 📎 fetch_attachments
    {"text": "Get all documents from my recent mails", "intent": "fetch_attachments"},
    {"text": "Find emails that contain images or PDFs", "intent": "fetch_attachments"},
    {"text": "List the messages which have attachments", "intent": "fetch_attachments"},
    {"text": "Access all files received via mail", "intent": "fetch_attachments"},
    {"text": "Filter only emails with downloadable content", "intent": "fetch_attachments"},

    # 🤖 summarize_emails
    {"text": "Summarize all emails I got from my manager", "intent": "summarize_emails"},
    {"text": "Give me short summaries of 10 recent messages", "intent": "summarize_emails"},
    {"text": "Can you compress my inbox into key points?", "intent": "summarize_emails"},
    {"text": "Briefly explain the last few important mails", "intent": "summarize_emails"},
    {"text": "I want a quick summary of today’s mail conversations", "intent": "summarize_emails"},
    {"text": "What are the main points from my last 3 emails?", "intent": "summarize_emails"},
    {"text": "Summarize everything Neha mailed me this week", "intent": "summarize_emails"},
]

# %%
email_data += [
    # 📨 fetch_last_n
    {"text": "Get my last 3 emails", "intent": "fetch_last_n"},
    {"text": "Please show me my most recent mails", "intent": "fetch_last_n"},
    {"text": "I'd like to read my last 10 messages", "intent": "fetch_last_n"},
    {"text": "Bring up the 5 emails I got most recently", "intent": "fetch_last_n"},
    {"text": "What were the last few emails I received?", "intent": "fetch_last_n"},

    # 👤 fetch_by_sender
    {"text": "Give me all emails that came from Google", "intent": "fetch_by_sender"},
    {"text": "I need to find mails sent by my HR", "intent": "fetch_by_sender"},
    {"text": "Fetch emails from my class coordinator", "intent": "fetch_by_sender"},
    {"text": "What did Ravi mail me recently?", "intent": "fetch_by_sender"},
    {"text": "Show only messages received from contact@service.com", "intent": "fetch_by_sender"},

    # 🆕 fetch_unread
    {"text": "List out unread mails in inbox", "intent": "fetch_unread"},
    {"text": "Check for unopened emails", "intent": "fetch_unread"},
    {"text": "Do I have anything new I haven't seen?", "intent": "fetch_unread"},
    {"text": "Bring the unread ones to the top", "intent": "fetch_unread"},
    {"text": "Display all unseen emails", "intent": "fetch_unread"},

    # ⭐ fetch_important
    {"text": "Retrieve mails marked as important", "intent": "fetch_important"},
    {"text": "Check if there are any critical messages", "intent": "fetch_important"},
    {"text": "Fetch mails that are flagged", "intent": "fetch_important"},
    {"text": "I want the high priority emails only", "intent": "fetch_important"},
    {"text": "Show me urgent mail", "intent": "fetch_important"},

    # 📅 fetch_date_range
    {"text": "What emails did I get last Sunday?", "intent": "fetch_date_range"},
    {"text": "Show my inbox from yesterday", "intent": "fetch_date_range"},
    {"text": "Get all emails between July 1 and July 5", "intent": "fetch_date_range"},
    {"text": "Pull emails from the previous month", "intent": "fetch_date_range"},
    {"text": "List emails dated last Friday", "intent": "fetch_date_range"},

    # 🏷️ fetch_by_label
    {"text": "Mails categorized as 'Newsletter'", "intent": "fetch_by_label"},
    {"text": "Display messages labeled as Promotions", "intent": "fetch_by_label"},
    {"text": "Bring up all emails tagged with 'Jobs'", "intent": "fetch_by_label"},
    {"text": "Filter mails by the 'Updates' tag", "intent": "fetch_by_label"},
    {"text": "What’s in the Social label?", "intent": "fetch_by_label"},

    # 📝 fetch_by_subject
    {"text": "Search for emails about invoice", "intent": "fetch_by_subject"},
    {"text": "I want to see all subjects that mention 'resume'", "intent": "fetch_by_subject"},
    {"text": "Do I have any subject line containing 'Reminder'?", "intent": "fetch_by_subject"},
    {"text": "Get emails with 'Assignment' in the subject", "intent": "fetch_by_subject"},
    {"text": "Look up subjects mentioning 'Result'", "intent": "fetch_by_subject"},

    # 📎 fetch_attachments
    {"text": "Check which mails contain files", "intent": "fetch_attachments"},
    {"text": "List all messages that have images or docs", "intent": "fetch_attachments"},
    {"text": "Did I get any attachments today?", "intent": "fetch_attachments"},
    {"text": "Download PDFs from my inbox", "intent": "fetch_attachments"},
    {"text": "Which emails have files attached?", "intent": "fetch_attachments"},

    # 🤖 summarize_emails
    {"text": "Give me summary of today’s emails", "intent": "summarize_emails"},
    {"text": "Summarize mails I received in the morning", "intent": "summarize_emails"},
    {"text": "Give overview of yesterday’s important messages", "intent": "summarize_emails"},
    {"text": "Brief me about recent emails from my professor", "intent": "summarize_emails"},
    {"text": "What’s the gist of my unread emails?", "intent": "summarize_emails"},
]

# %%
email_data += [
    # 📨 fetch_last_n
    {"text": "Just show me the last 3 messages", "intent": "fetch_last_n"},
    {"text": "Only the latest 2 emails please", "intent": "fetch_last_n"},
    {"text": "Give me a peek at the newest messages", "intent": "fetch_last_n"},
    {"text": "I want to read the most recent emails", "intent": "fetch_last_n"},
    {"text": "Display the last five mails", "intent": "fetch_last_n"},

    # 👤 fetch_by_sender
    {"text": "Do I have any mails from Rahul?", "intent": "fetch_by_sender"},
    {"text": "Bring messages from the HR department", "intent": "fetch_by_sender"},
    {"text": "Show mails coming from Flipkart", "intent": "fetch_by_sender"},
    {"text": "List messages sent by Deepa", "intent": "fetch_by_sender"},
    {"text": "Did Google send me anything recently?", "intent": "fetch_by_sender"},

    # 🆕 fetch_unread
    {"text": "What new mails are unread?", "intent": "fetch_unread"},
    {"text": "Is anything unread in my inbox?", "intent": "fetch_unread"},
    {"text": "Highlight new incoming messages", "intent": "fetch_unread"},
    {"text": "Any unseen mails today?", "intent": "fetch_unread"},
    {"text": "Which messages haven’t I opened?", "intent": "fetch_unread"},

    # ⭐ fetch_important
    {"text": "Do I have any flagged messages?", "intent": "fetch_important"},
    {"text": "Get the ones marked with a star", "intent": "fetch_important"},
    {"text": "Important emails only", "intent": "fetch_important"},
    {"text": "Pull up priority mails", "intent": "fetch_important"},
    {"text": "Access high-priority items", "intent": "fetch_important"},

    # 📅 fetch_date_range
    {"text": "I want emails from last Friday", "intent": "fetch_date_range"},
    {"text": "Only show messages I received yesterday", "intent": "fetch_date_range"},
    {"text": "What did I get during last week?", "intent": "fetch_date_range"},
    {"text": "Fetch emails from March 10 to March 12", "intent": "fetch_date_range"},
    {"text": "Display inbox from past 2 days", "intent": "fetch_date_range"},

    # 🏷️ fetch_by_label
    {"text": "Get messages under Promotions tab", "intent": "fetch_by_label"},
    {"text": "Mails in the 'Work' label", "intent": "fetch_by_label"},
    {"text": "Filter messages in the 'Personal' category", "intent": "fetch_by_label"},
    {"text": "Show me what’s inside the 'Notifications' folder", "intent": "fetch_by_label"},
    {"text": "Retrieve all 'Offers' category emails", "intent": "fetch_by_label"},

    # 📝 fetch_by_subject
    {"text": "Any emails with subject 'Payment Reminder'?", "intent": "fetch_by_subject"},
    {"text": "Get mails that mention 'Assignment Submission'", "intent": "fetch_by_subject"},
    {"text": "Search subjects for 'Deadline'", "intent": "fetch_by_subject"},
    {"text": "Find subject lines with 'Invoice'", "intent": "fetch_by_subject"},
    {"text": "Display emails with 'Congratulations' in the subject", "intent": "fetch_by_subject"},

    # 📎 fetch_attachments
    {"text": "Get all my emails that had attachments", "intent": "fetch_attachments"},
    {"text": "Find messages with Excel files", "intent": "fetch_attachments"},
    {"text": "I need mails containing documents", "intent": "fetch_attachments"},
    {"text": "Which emails have images or files?", "intent": "fetch_attachments"},
    {"text": "Locate mails that came with attached files", "intent": "fetch_attachments"},

    # 🤖 summarize_emails
    {"text": "Summarize the recent emails from professor", "intent": "summarize_emails"},
    {"text": "Give me a summary of unread messages", "intent": "summarize_emails"},
    {"text": "Summarize today's inbox", "intent": "summarize_emails"},
    {"text": "Can you give me a short version of these emails?", "intent": "summarize_emails"},
    {"text": "What's the summary of all messages from HDFC?", "intent": "summarize_emails"},
]

# %%
email_data += [
    # 📨 fetch_last_n
    {"text": "Can I see my last 10 emails?", "intent": "fetch_last_n"},
    {"text": "Show me the most recent messages I received", "intent": "fetch_last_n"},
    {"text": "Display the previous 3 emails", "intent": "fetch_last_n"},
    {"text": "List the latest emails in my inbox", "intent": "fetch_last_n"},
    {"text": "Open up my 8 newest emails", "intent": "fetch_last_n"},

    # 👤 fetch_by_sender
    {"text": "Pull up messages from my HR", "intent": "fetch_by_sender"},
    {"text": "Retrieve all emails that Alice sent", "intent": "fetch_by_sender"},
    {"text": "I want the mails that came from sales@xyz.com", "intent": "fetch_by_sender"},
    {"text": "What has Neha emailed me lately?", "intent": "fetch_by_sender"},
    {"text": "Search for messages from John", "intent": "fetch_by_sender"},

    # 🆕 fetch_unread
    {"text": "Any unread emails in my inbox?", "intent": "fetch_unread"},
    {"text": "Show just the new mails", "intent": "fetch_unread"},
    {"text": "Filter only the ones I haven't checked", "intent": "fetch_unread"},
    {"text": "Get unseen messages", "intent": "fetch_unread"},
    {"text": "Display fresh unread emails", "intent": "fetch_unread"},

    # ⭐ fetch_important
    {"text": "Find priority messages", "intent": "fetch_important"},
    {"text": "Which emails are marked urgent?", "intent": "fetch_important"},
    {"text": "List my important conversations", "intent": "fetch_important"},
    {"text": "Only show the mails that are flagged", "intent": "fetch_important"},
    {"text": "Get emails marked high priority", "intent": "fetch_important"},

    # 📅 fetch_date_range
    {"text": "Can you show emails from last Friday?", "intent": "fetch_date_range"},
    {"text": "Retrieve messages received on 15th March", "intent": "fetch_date_range"},
    {"text": "Fetch mails between April 1st and April 5th", "intent": "fetch_date_range"},
    {"text": "Get inbox items from this past weekend", "intent": "fetch_date_range"},
    {"text": "Filter messages by 2023-07-01 to 2023-07-10", "intent": "fetch_date_range"},

    # 🏷️ fetch_by_label
    {"text": "I want all emails labeled as Urgent", "intent": "fetch_by_label"},
    {"text": "Get my emails in the 'Travel' category", "intent": "fetch_by_label"},
    {"text": "Check the mails in the Personal label", "intent": "fetch_by_label"},
    {"text": "Filter by label: Work", "intent": "fetch_by_label"},
    {"text": "Give me mails that are in the Promotions label", "intent": "fetch_by_label"},

    # 📝 fetch_by_subject
    {"text": "Show me mails with 'Admission' in the subject", "intent": "fetch_by_subject"},
    {"text": "Look for emails titled 'Invoice'", "intent": "fetch_by_subject"},
    {"text": "Find emails with 'Schedule' in the subject line", "intent": "fetch_by_subject"},
    {"text": "Get all subject lines containing 'Reminder'", "intent": "fetch_by_subject"},
    {"text": "Pull up emails having 'Newsletter' in subject", "intent": "fetch_by_subject"},

    # 📎 fetch_attachments
    {"text": "Do I have any emails with Excel files?", "intent": "fetch_attachments"},
    {"text": "List all emails that have attachments", "intent": "fetch_attachments"},
    {"text": "I want to see mails with downloadable documents", "intent": "fetch_attachments"},
    {"text": "Get emails with images or files", "intent": "fetch_attachments"},
    {"text": "Fetch emails that contain file attachments", "intent": "fetch_attachments"},

    # 🤖 summarize_emails
    {"text": "Summarize the latest 3 messages from Paytm", "intent": "summarize_emails"},
    {"text": "Give me a summary of recent unread mails", "intent": "summarize_emails"},
    {"text": "What's the summary of all Gmail updates?", "intent": "summarize_emails"},
    {"text": "Summarize the contents of emails from the director", "intent": "summarize_emails"},
    {"text": "I want a brief of the messages from today", "intent": "summarize_emails"},
    {"text": "Make a summary of this week’s important emails", "intent": "summarize_emails"},
    {"text": "Give an overview of work emails from last 2 days", "intent": "summarize_emails"},
    {"text": "Can you generate a short summary of my inbox?", "intent": "summarize_emails"},
]

# %%
email_data += [
    # 📨 fetch_last_n
    {"text": "Can you pull up my 10 most recent emails?", "intent": "fetch_last_n"},
    {"text": "Just show me the last few messages I received", "intent": "fetch_last_n"},
    {"text": "Load the most recent 3 emails", "intent": "fetch_last_n"},
    {"text": "Access my last 15 mails", "intent": "fetch_last_n"},
    {"text": "I want a list of my latest emails", "intent": "fetch_last_n"},

    # 👤 fetch_by_sender
    {"text": "Any new messages from Rahul?", "intent": "fetch_by_sender"},
    {"text": "Do I have anything from HR?", "intent": "fetch_by_sender"},
    {"text": "Pull mails that came from my team lead", "intent": "fetch_by_sender"},
    {"text": "Check if there’s any mail from Flipkart", "intent": "fetch_by_sender"},
    {"text": "Look up emails sent by my mentor", "intent": "fetch_by_sender"},

    # 🆕 fetch_unread
    {"text": "What unread mails do I have?", "intent": "fetch_unread"},
    {"text": "List my unseen messages", "intent": "fetch_unread"},
    {"text": "Is there anything I haven’t opened yet?", "intent": "fetch_unread"},
    {"text": "Display only the emails I missed", "intent": "fetch_unread"},
    {"text": "Do I have any fresh mails?", "intent": "fetch_unread"},

    # ⭐ fetch_important
    {"text": "Any important or urgent mails today?", "intent": "fetch_important"},
    {"text": "What are my flagged emails?", "intent": "fetch_important"},
    {"text": "List today's priority messages", "intent": "fetch_important"},
    {"text": "Check mails marked as high importance", "intent": "fetch_important"},
    {"text": "Filter inbox by importance", "intent": "fetch_important"},

    # 📅 fetch_date_range
    {"text": "Retrieve mails from last Sunday", "intent": "fetch_date_range"},
    {"text": "What messages came between 5th and 10th July?", "intent": "fetch_date_range"},
    {"text": "Show all emails from March", "intent": "fetch_date_range"},
    {"text": "Get all inbox items from 2 days ago", "intent": "fetch_date_range"},
    {"text": "Mails from earlier this week only", "intent": "fetch_date_range"},

    # 🏷️ fetch_by_label
    {"text": "Pull my 'Shopping' category emails", "intent": "fetch_by_label"},
    {"text": "I want messages from 'Promotions'", "intent": "fetch_by_label"},
    {"text": "Access my Social updates", "intent": "fetch_by_label"},
    {"text": "Show all mails labeled as Personal", "intent": "fetch_by_label"},
    {"text": "Filter based on label 'ProjectX'", "intent": "fetch_by_label"},

    # 📝 fetch_by_subject
    {"text": "Find emails titled 'Assignment Submission'", "intent": "fetch_by_subject"},
    {"text": "Search for subjects with 'Test Results'", "intent": "fetch_by_subject"},
    {"text": "Get the mail that mentions 'Your Bill' in subject", "intent": "fetch_by_subject"},
    {"text": "Locate mails with subject 'Flight Booking'", "intent": "fetch_by_subject"},
    {"text": "Look up emails having 'Congrats' in title", "intent": "fetch_by_subject"},

    # 📎 fetch_attachments
    {"text": "Grab all attachments from last week", "intent": "fetch_attachments"},
    {"text": "Were there any ZIP files in recent emails?", "intent": "fetch_attachments"},
    {"text": "Fetch only the mails with attached files", "intent": "fetch_attachments"},
    {"text": "Do I have any invoices attached in mail?", "intent": "fetch_attachments"},
    {"text": "Download docs from emails", "intent": "fetch_attachments"},

    # 🤖 summarize_emails
    {"text": "Summarize my inbox briefly", "intent": "summarize_emails"},
    {"text": "What’s the summary of unread emails from last 2 days?", "intent": "summarize_emails"},
    {"text": "Can you give a gist of this week's updates?", "intent": "summarize_emails"},
    {"text": "Quickly summarize messages from LinkedIn", "intent": "summarize_emails"},
    {"text": "I want a short report of today's mails", "intent": "summarize_emails"},
]

# %% [markdown]
# ## Combining data

# %%
try:
    df = pd.DataFrame(email_data)
    df['intent'] = 'gmail_operations'
    print(f"DataFrame shape: {df.shape}")
    df.to_csv("gmail_operations_data.csv", index=False)
    print("CSV file saved successfully.")
except Exception as e:
    print(f"error occurred: {e}")
# Out:
# DataFrame shape: (1009, 2)
# CSV file saved successfully.

# %%
df.shape
# Out:
# (1009, 2)

# %%
df.duplicated().sum()
# Out:
# np.int64(8)
