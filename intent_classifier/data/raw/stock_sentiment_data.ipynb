# %% [markdown]
# # Stock sentiment intent data

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd

# %% [markdown]
# ## Generated Data

# %%
data1 = [
    {"text": "What is the sentiment of Apple stock?", "intent": "stock_sentiment"},
    {"text": "Tell me if Tesla is going up or down", "intent": "stock_sentiment"},
    {"text": "Analyze the stock sentiment for Microsoft", "intent": "stock_sentiment"},
    {"text": "Is Amazon stock bullish or bearish?", "intent": "stock_sentiment"},
    {"text": "How is the market feeling about Nvidia?", "intent": "stock_sentiment"},
    {"text": "Give me the current sentiment for Google stock", "intent": "stock_sentiment"},
    {"text": "What’s the investor sentiment on Facebook shares?", "intent": "stock_sentiment"},
    {"text": "Are investors positive or negative on Netflix stock?", "intent": "stock_sentiment"},
    {"text": "Check the sentiment for Intel stock", "intent": "stock_sentiment"},
    {"text": "How are people reacting to Twitter shares?", "intent": "stock_sentiment"},
    {"text": "Is the market optimistic about AMD stock?", "intent": "stock_sentiment"},
    {"text": "Tell me if Apple shares are trending up or down", "intent": "stock_sentiment"},
    {"text": "What’s the mood around Tesla stock today?", "intent": "stock_sentiment"},
    {"text": "Is the sentiment bullish for Microsoft right now?", "intent": "stock_sentiment"},
    {"text": "Are Amazon shares expected to rise?", "intent": "stock_sentiment"},
    {"text": "Analyze how investors feel about Nvidia stock", "intent": "stock_sentiment"},
    {"text": "What’s the overall sentiment for Google today?", "intent": "stock_sentiment"},
    {"text": "Is Facebook stock considered risky currently?", "intent": "stock_sentiment"},
    {"text": "How do traders feel about Netflix shares?", "intent": "stock_sentiment"},
    {"text": "Check if Intel stock is under positive sentiment", "intent": "stock_sentiment"},
    {"text": "Are investors optimistic about Twitter’s stock?", "intent": "stock_sentiment"},
    {"text": "What’s the latest sentiment on AMD shares?", "intent": "stock_sentiment"},
    {"text": "Tell me if Apple’s stock is gaining positive buzz", "intent": "stock_sentiment"},
    {"text": "What’s the current trend for Tesla stock?", "intent": "stock_sentiment"},
    {"text": "Are Microsoft shares seeing positive sentiment?", "intent": "stock_sentiment"},
    {"text": "Is Amazon stock getting good reviews from traders?", "intent": "stock_sentiment"},
    {"text": "How is the market sentiment for Nvidia stocks?", "intent": "stock_sentiment"},
    {"text": "Give me sentiment analysis for Google stock", "intent": "stock_sentiment"},
    {"text": "Are investors confident in Facebook shares?", "intent": "stock_sentiment"},
    {"text": "Check the public sentiment for Netflix stock", "intent": "stock_sentiment"},
    {"text": "Is Intel stock showing positive signs?", "intent": "stock_sentiment"},
    {"text": "How are Twitter shares perceived by traders?", "intent": "stock_sentiment"},
    {"text": "Is the AMD stock sentiment bullish or bearish?", "intent": "stock_sentiment"},
    {"text": "What’s the investor sentiment for Apple today?", "intent": "stock_sentiment"},
    {"text": "Are traders optimistic about Tesla stock?", "intent": "stock_sentiment"},
    {"text": "Is Microsoft stock trending positively?", "intent": "stock_sentiment"},
    {"text": "Tell me if Amazon shares have a positive outlook", "intent": "stock_sentiment"},
    {"text": "Analyze Nvidia’s stock sentiment from recent news", "intent": "stock_sentiment"},
    {"text": "What’s the general market sentiment on Google stock?", "intent": "stock_sentiment"},
    {"text": "Are Facebook shares viewed positively right now?", "intent": "stock_sentiment"},
    {"text": "How do investors feel about Netflix stock recently?", "intent": "stock_sentiment"},
    {"text": "Check the sentiment for Intel shares today", "intent": "stock_sentiment"},
    {"text": "Is Twitter’s stock sentiment favorable?", "intent": "stock_sentiment"},
    {"text": "Are AMD stocks in a bullish mood?", "intent": "stock_sentiment"},
    {"text": "What’s the public opinion on Apple stock?", "intent": "stock_sentiment"},
    {"text": "Tell me if Tesla shares are favored by investors", "intent": "stock_sentiment"},
    {"text": "How is the sentiment on Microsoft shares?", "intent": "stock_sentiment"},
    {"text": "Is Amazon stock viewed as bullish currently?", "intent": "stock_sentiment"},
    {"text": "Analyze market sentiment for Nvidia shares", "intent": "stock_sentiment"},
    {"text": "What’s the trend for Google stock sentiment?", "intent": "stock_sentiment"},
    {"text": "Are Facebook shares considered stable by traders?", "intent": "stock_sentiment"},
    {"text": "How do investors perceive Netflix stock right now?", "intent": "stock_sentiment"},
    {"text": "Check if Intel shares are in positive sentiment", "intent": "stock_sentiment"},
    {"text": "Is Twitter stock sentiment trending upward?", "intent": "stock_sentiment"},
    {"text": "Are AMD stocks gaining positive feedback?", "intent": "stock_sentiment"},
    {"text": "What’s the overall feeling about Apple stock?", "intent": "stock_sentiment"},
    {"text": "Are Tesla shares gaining positive momentum?", "intent": "stock_sentiment"},
    {"text": "Tell me if Microsoft stock is bullish or bearish", "intent": "stock_sentiment"},
    {"text": "Is Amazon shares sentiment positive today?", "intent": "stock_sentiment"},
    {"text": "Analyze Nvidia stock sentiment from social media", "intent": "stock_sentiment"},
    {"text": "What’s the public sentiment for Google shares?", "intent": "stock_sentiment"},
    {"text": "Are Facebook shares seeing increased investor confidence?", "intent": "stock_sentiment"},
    {"text": "How is Netflix stock sentiment trending?", "intent": "stock_sentiment"},
    {"text": "Check if Intel stock is receiving positive feedback", "intent": "stock_sentiment"},
    {"text": "Is Twitter stock sentiment positive or negative?", "intent": "stock_sentiment"},
    {"text": "Are AMD shares trending bullish currently?", "intent": "stock_sentiment"},
    {"text": "What’s the investor mood around Apple stock?", "intent": "stock_sentiment"},
    {"text": "Are Tesla shares favored in today’s market?", "intent": "stock_sentiment"},
    {"text": "How is the sentiment on Microsoft stock evolving?", "intent": "stock_sentiment"},
    {"text": "Is Amazon stock considered bullish right now?", "intent": "stock_sentiment"},
    {"text": "Analyze Nvidia’s stock sentiment from recent trends", "intent": "stock_sentiment"},
    {"text": "What’s the general sentiment for Google shares?", "intent": "stock_sentiment"},
    {"text": "Are Facebook stocks viewed positively by investors?", "intent": "stock_sentiment"},
    {"text": "How do traders feel about Netflix stock today?", "intent": "stock_sentiment"},
    {"text": "Check the sentiment trend for Intel shares", "intent": "stock_sentiment"},
    {"text": "Is Twitter stock sentiment improving?", "intent": "stock_sentiment"},
    {"text": "Are AMD shares receiving positive market sentiment?", "intent": "stock_sentiment"},
    {"text": "What’s the overall sentiment on Apple shares?", "intent": "stock_sentiment"},
    {"text": "Are Tesla shares trending up in sentiment?", "intent": "stock_sentiment"},
    {"text": "Tell me if Microsoft stock sentiment is positive", "intent": "stock_sentiment"},
    {"text": "Is Amazon stock sentiment bullish or bearish?", "intent": "stock_sentiment"},
    {"text": "Analyze Nvidia stock sentiment from latest news", "intent": "stock_sentiment"},
    {"text": "What’s the market sentiment for Google shares?", "intent": "stock_sentiment"},
    {"text": "Are Facebook shares seen as good investments now?", "intent": "stock_sentiment"},
    {"text": "How is Netflix stock sentiment trending lately?", "intent": "stock_sentiment"},
    {"text": "Check if Intel shares have positive investor sentiment", "intent": "stock_sentiment"},
    {"text": "Is Twitter stock sentiment currently positive?", "intent": "stock_sentiment"},
    {"text": "Are AMD shares favored by investors recently?", "intent": "stock_sentiment"}
]

# %%
data2 = [
    {"text": "What is the sentiment of Reliance Industries stock?", "intent": "stock_sentiment"},
    {"text": "Tell me if TCS is trending up or down", "intent": "stock_sentiment"},
    {"text": "Analyze the stock sentiment for Infosys", "intent": "stock_sentiment"},
    {"text": "Is HDFC Bank stock bullish or bearish?", "intent": "stock_sentiment"},
    {"text": "How is the market feeling about ICICI Bank?", "intent": "stock_sentiment"},
    {"text": "Give me the current sentiment for Larsen & Toubro stock", "intent": "stock_sentiment"},
    {"text": "What’s the investor sentiment on SBI shares?", "intent": "stock_sentiment"},
    {"text": "Are investors positive or negative on Bharti Airtel stock?", "intent": "stock_sentiment"},
    {"text": "Check the sentiment for Asian Paints stock", "intent": "stock_sentiment"},
    {"text": "How are people reacting to Bajaj Finance shares?", "intent": "stock_sentiment"},
    {"text": "Is the market optimistic about Maruti Suzuki stock?", "intent": "stock_sentiment"},
    {"text": "Tell me if Reliance Industries shares are trending up or down", "intent": "stock_sentiment"},
    {"text": "What’s the mood around TCS stock today?", "intent": "stock_sentiment"},
    {"text": "Is the sentiment bullish for Infosys right now?", "intent": "stock_sentiment"},
    {"text": "Are HDFC Bank shares expected to rise?", "intent": "stock_sentiment"},
    {"text": "Analyze how investors feel about ICICI Bank stock", "intent": "stock_sentiment"},
    {"text": "What’s the overall sentiment for Larsen & Toubro today?", "intent": "stock_sentiment"},
    {"text": "Is SBI stock considered risky currently?", "intent": "stock_sentiment"},
    {"text": "How do traders feel about Bharti Airtel shares?", "intent": "stock_sentiment"},
    {"text": "Check if Asian Paints stock is under positive sentiment", "intent": "stock_sentiment"},
    {"text": "Are investors optimistic about Bajaj Finance’s stock?", "intent": "stock_sentiment"},
    {"text": "What’s the latest sentiment on Maruti Suzuki shares?", "intent": "stock_sentiment"},
    {"text": "Tell me if Reliance Industries stock is gaining positive buzz", "intent": "stock_sentiment"},
    {"text": "What’s the current trend for TCS stock?", "intent": "stock_sentiment"},
    {"text": "Are Infosys shares seeing positive sentiment?", "intent": "stock_sentiment"},
    {"text": "Is HDFC Bank stock getting good reviews from traders?", "intent": "stock_sentiment"},
    {"text": "How is the market sentiment for ICICI Bank stocks?", "intent": "stock_sentiment"},
    {"text": "Give me sentiment analysis for Larsen & Toubro stock", "intent": "stock_sentiment"},
    {"text": "Are investors confident in SBI shares?", "intent": "stock_sentiment"},
    {"text": "Check the public sentiment for Bharti Airtel stock", "intent": "stock_sentiment"},
    {"text": "Is Asian Paints stock showing positive signs?", "intent": "stock_sentiment"},
    {"text": "How are Bajaj Finance shares perceived by traders?", "intent": "stock_sentiment"},
    {"text": "Is the Maruti Suzuki stock sentiment bullish or bearish?", "intent": "stock_sentiment"},
    {"text": "What’s the investor sentiment for Reliance Industries today?", "intent": "stock_sentiment"},
    {"text": "Are traders optimistic about TCS stock?", "intent": "stock_sentiment"},
    {"text": "Is Infosys stock trending positively?", "intent": "stock_sentiment"},
    {"text": "Tell me if HDFC Bank shares have a positive outlook", "intent": "stock_sentiment"},
    {"text": "Analyze ICICI Bank’s stock sentiment from recent news", "intent": "stock_sentiment"},
    {"text": "What’s the general market sentiment on Larsen & Toubro stock?", "intent": "stock_sentiment"},
    {"text": "Are SBI shares viewed positively right now?", "intent": "stock_sentiment"},
    {"text": "How do investors feel about Bharti Airtel stock recently?", "intent": "stock_sentiment"},
    {"text": "Check the sentiment for Asian Paints shares today", "intent": "stock_sentiment"},
    {"text": "Is Bajaj Finance stock sentiment favorable?", "intent": "stock_sentiment"},
    {"text": "Are Maruti Suzuki stocks in a bullish mood?", "intent": "stock_sentiment"},
    {"text": "What’s the public opinion on Reliance Industries stock?", "intent": "stock_sentiment"},
    {"text": "Tell me if TCS shares are favored by investors", "intent": "stock_sentiment"},
    {"text": "How is the sentiment on Infosys shares?", "intent": "stock_sentiment"},
    {"text": "Is HDFC Bank stock viewed as bullish currently?", "intent": "stock_sentiment"},
    {"text": "Analyze ICICI Bank stock sentiment from social media", "intent": "stock_sentiment"},
    {"text": "What’s the public sentiment for Larsen & Toubro shares?", "intent": "stock_sentiment"},
    {"text": "Are SBI shares seeing increased investor confidence?", "intent": "stock_sentiment"},
    {"text": "How is Bharti Airtel stock sentiment trending?", "intent": "stock_sentiment"},
    {"text": "Check if Asian Paints stock is receiving positive feedback", "intent": "stock_sentiment"},
    {"text": "Is Bajaj Finance stock sentiment positive or negative?", "intent": "stock_sentiment"},
    {"text": "Are Maruti Suzuki shares trending bullish currently?", "intent": "stock_sentiment"},
    {"text": "What’s the investor mood around Reliance Industries stock?", "intent": "stock_sentiment"},
    {"text": "Are TCS shares favored in today’s market?", "intent": "stock_sentiment"},
    {"text": "How is the sentiment on Infosys stock evolving?", "intent": "stock_sentiment"},
    {"text": "Is HDFC Bank stock considered bullish right now?", "intent": "stock_sentiment"},
    {"text": "Analyze ICICI Bank’s stock sentiment from recent trends", "intent": "stock_sentiment"},
    {"text": "What’s the general sentiment for Larsen & Toubro shares?", "intent": "stock_sentiment"},
    {"text": "Are SBI stocks viewed positively by investors?", "intent": "stock_sentiment"},
    {"text": "How do traders feel about Bharti Airtel stock today?", "intent": "stock_sentiment"},
    {"text": "Check the sentiment trend for Asian Paints shares", "intent": "stock_sentiment"},
    {"text": "Is Bajaj Finance stock sentiment improving?", "intent": "stock_sentiment"},
    {"text": "Are Maruti Suzuki shares receiving positive market sentiment?", "intent": "stock_sentiment"},
    {"text": "What’s the overall sentiment on Reliance Industries shares?", "intent": "stock_sentiment"},
    {"text": "Are TCS shares trending up in sentiment?", "intent": "stock_sentiment"},
    {"text": "Tell me if Infosys stock sentiment is positive", "intent": "stock_sentiment"},
    {"text": "Is HDFC Bank stock sentiment bullish or bearish?", "intent": "stock_sentiment"},
    {"text": "Analyze ICICI Bank stock sentiment from latest news", "intent": "stock_sentiment"},
    {"text": "What’s the market sentiment for Larsen & Toubro shares?", "intent": "stock_sentiment"},
    {"text": "Are SBI shares seen as good investments now?", "intent": "stock_sentiment"},
    {"text": "How is Bharti Airtel stock sentiment trending lately?", "intent": "stock_sentiment"},
    {"text": "Check if Asian Paints shares have positive investor sentiment", "intent": "stock_sentiment"},
    {"text": "Is Bajaj Finance stock sentiment currently positive?", "intent": "stock_sentiment"},
    {"text": "Are Maruti Suzuki shares favored by investors recently?", "intent": "stock_sentiment"}
]

# %%
data3 = [
    {"text": "What is the sentiment of Reliance Industries stock?", "intent": "stock_sentiment"},
    {"text": "Tell me if Tesla is going up or down", "intent": "stock_sentiment"},
    {"text": "Analyze the stock sentiment for Microsoft", "intent": "stock_sentiment"},
    {"text": "Is Amazon stock bullish or bearish?", "intent": "stock_sentiment"},
    {"text": "How is the market feeling about Infosys?", "intent": "stock_sentiment"},
    {"text": "Give me the current sentiment for Apple shares", "intent": "stock_sentiment"},
    {"text": "What’s the investor sentiment on TCS stock?", "intent": "stock_sentiment"},
    {"text": "Are investors positive or negative on Google stock?", "intent": "stock_sentiment"},
    {"text": "Check the sentiment for ICICI Bank stock", "intent": "stock_sentiment"},
    {"text": "How are people reacting to Nvidia shares?", "intent": "stock_sentiment"},
    {"text": "Is HDFC Bank stock showing bullish signs?", "intent": "stock_sentiment"},
    {"text": "Tell me if Facebook stock is trending up", "intent": "stock_sentiment"},
    {"text": "What’s the mood around Amazon stock today?", "intent": "stock_sentiment"},
    {"text": "Are Infosys shares seeing positive sentiment?", "intent": "stock_sentiment"},
    {"text": "Is HDFC Bank stock getting good reviews from traders?", "intent": "stock_sentiment"},
    {"text": "How is the market sentiment for ICICI Bank stocks?", "intent": "stock_sentiment"},
    {"text": "Give me sentiment analysis for Tesla stock", "intent": "stock_sentiment"},
    {"text": "Are investors confident in SBI shares?", "intent": "stock_sentiment"},
    {"text": "Check the public sentiment for Bharti Airtel stock", "intent": "stock_sentiment"},
    {"text": "Is Asian Paints stock showing positive signs?", "intent": "stock_sentiment"},
    {"text": "How are Bajaj Finance shares perceived by traders?", "intent": "stock_sentiment"},
    {"text": "Is the Maruti Suzuki stock sentiment bullish or bearish?", "intent": "stock_sentiment"},
    {"text": "What’s the investor sentiment for Reliance Industries today?", "intent": "stock_sentiment"},
    {"text": "Are traders optimistic about Apple stock?", "intent": "stock_sentiment"},
    {"text": "Is Infosys stock trending positively?", "intent": "stock_sentiment"},
    {"text": "Tell me if HDFC Bank shares have a positive outlook", "intent": "stock_sentiment"},
    {"text": "Analyze ICICI Bank’s stock sentiment from recent news", "intent": "stock_sentiment"},
    {"text": "What’s the general market sentiment on Larsen & Toubro stock?", "intent": "stock_sentiment"},
    {"text": "Are SBI shares viewed positively right now?", "intent": "stock_sentiment"},
    {"text": "How do investors feel about Bharti Airtel stock recently?", "intent": "stock_sentiment"},
    {"text": "Check the sentiment for Asian Paints shares today", "intent": "stock_sentiment"},
    {"text": "Is Bajaj Finance stock sentiment favorable?", "intent": "stock_sentiment"},
    {"text": "Are Maruti Suzuki shares in a bullish mood?", "intent": "stock_sentiment"},
    {"text": "What’s the public opinion on Reliance Industries stock?", "intent": "stock_sentiment"},
    {"text": "Tell me if Netflix shares are favored by investors", "intent": "stock_sentiment"},
    {"text": "How is the sentiment on Infosys shares?", "intent": "stock_sentiment"},
    {"text": "Is HDFC Bank stock viewed as bullish currently?", "intent": "stock_sentiment"},
    {"text": "Analyze ICICI Bank stock sentiment from social media", "intent": "stock_sentiment"},
    {"text": "What’s the public sentiment for Larsen & Toubro shares?", "intent": "stock_sentiment"},
    {"text": "Are SBI shares seeing increased investor confidence?", "intent": "stock_sentiment"},
    {"text": "How is Bharti Airtel stock sentiment trending?", "intent": "stock_sentiment"},
    {"text": "Check if Asian Paints stock is receiving positive feedback", "intent": "stock_sentiment"},
    {"text": "Is Bajaj Finance stock sentiment positive or negative?", "intent": "stock_sentiment"},
    {"text": "Are Maruti Suzuki shares trending bullish currently?", "intent": "stock_sentiment"},
    {"text": "What’s the investor mood around Reliance Industries stock?", "intent": "stock_sentiment"},
    {"text": "Are TCS shares favored in today’s market?", "intent": "stock_sentiment"},
    {"text": "How is the sentiment on Infosys stock evolving?", "intent": "stock_sentiment"},
    {"text": "Is HDFC Bank stock considered bullish right now?", "intent": "stock_sentiment"},
    {"text": "Analyze ICICI Bank’s stock sentiment from recent trends", "intent": "stock_sentiment"},
    {"text": "What’s the general sentiment for Larsen & Toubro shares?", "intent": "stock_sentiment"},
    {"text": "Are SBI stocks viewed positively by investors?", "intent": "stock_sentiment"},
    {"text": "How do traders feel about Bharti Airtel stock today?", "intent": "stock_sentiment"},
    {"text": "Check the sentiment trend for Asian Paints shares", "intent": "stock_sentiment"},
    {"text": "Is Bajaj Finance stock sentiment improving?", "intent": "stock_sentiment"},
    {"text": "Are Maruti Suzuki shares receiving positive market sentiment?", "intent": "stock_sentiment"},
    {"text": "What’s the overall sentiment on Reliance Industries shares?", "intent": "stock_sentiment"},
    {"text": "Are TCS shares trending up in sentiment?", "intent": "stock_sentiment"},
    {"text": "Tell me if Infosys stock sentiment is positive", "intent": "stock_sentiment"},
    {"text": "Is HDFC Bank stock sentiment bullish or bearish?", "intent": "stock_sentiment"},
    {"text": "Analyze ICICI Bank stock sentiment from latest news", "intent": "stock_sentiment"},
    {"text": "What’s the market sentiment for Larsen & Toubro shares?", "intent": "stock_sentiment"},
    {"text": "Are SBI shares seen as good investments now?", "intent": "stock_sentiment"},
    {"text": "How is Bharti Airtel stock sentiment trending lately?", "intent": "stock_sentiment"},
    {"text": "Check if Asian Paints shares have positive investor sentiment", "intent": "stock_sentiment"},
    {"text": "Is Bajaj Finance stock sentiment currently positive?", "intent": "stock_sentiment"},
    {"text": "Are Maruti Suzuki shares favored by investors recently?", "intent": "stock_sentiment"},
    {"text": "What is the sentiment of Coca-Cola stock?", "intent": "stock_sentiment"},
    {"text": "Is Google stock showing a positive trend?", "intent": "stock_sentiment"},
    {"text": "Analyze the sentiment for Walmart shares", "intent": "stock_sentiment"},
    {"text": "Is IBM stock bullish or bearish?", "intent": "stock_sentiment"},
    {"text": "What is the sentiment on Netflix shares?", "intent": "stock_sentiment"},
    {"text": "How is the market sentiment on Pfizer stock?", "intent": "stock_sentiment"},
    {"text": "Are investors optimistic about Adobe stock?", "intent": "stock_sentiment"},
    {"text": "What’s the sentiment on Zoom Video Communications stock?", "intent": "stock_sentiment"},
    {"text": "Is Boeing stock viewed positively by traders?", "intent": "stock_sentiment"},
    {"text": "Analyze sentiment for ExxonMobil shares", "intent": "stock_sentiment"},
    {"text": "Is Twitter stock trending up or down?", "intent": "stock_sentiment"},
    {"text": "Tell me the market feeling about Spotify stock", "intent": "stock_sentiment"},
    {"text": "Are investors bullish on Uber Technologies?", "intent": "stock_sentiment"},
    {"text": "What’s the sentiment for PayPal stock?", "intent": "stock_sentiment"},
    {"text": "Is the sentiment positive for Shopify stock?", "intent": "stock_sentiment"}
]

# %%
data4 = [
    {"text": "What is the current sentiment for Adani Enterprises stock?", "intent": "stock_sentiment"},
    {"text": "How are investors feeling about Wipro shares?", "intent": "stock_sentiment"},
    {"text": "Analyze the sentiment around Paytm stock", "intent": "stock_sentiment"},
    {"text": "Is Bajaj Auto stock showing bullish trends?", "intent": "stock_sentiment"},
    {"text": "What’s the market mood on Tata Steel shares?", "intent": "stock_sentiment"},
    {"text": "Tell me if Ford stock is trending positively", "intent": "stock_sentiment"},
    {"text": "Check the sentiment for HCL Technologies shares", "intent": "stock_sentiment"},
    {"text": "Are investors optimistic about Netflix stock?", "intent": "stock_sentiment"},
    {"text": "How is the sentiment on Asian Paints stock?", "intent": "stock_sentiment"},
    {"text": "Is Sony stock bullish or bearish today?", "intent": "stock_sentiment"},
    {"text": "What’s the investor sentiment on ITC stock?", "intent": "stock_sentiment"},
    {"text": "How do traders feel about Ford shares recently?", "intent": "stock_sentiment"},
    {"text": "Check sentiment for Cipla stock", "intent": "stock_sentiment"},
    {"text": "Is Tesla stock viewed positively by investors now?", "intent": "stock_sentiment"},
    {"text": "What’s the sentiment on Maruti Suzuki shares?", "intent": "stock_sentiment"},
    {"text": "Tell me if Axis Bank shares are favored by traders", "intent": "stock_sentiment"},
    {"text": "Analyze the market sentiment for Google stock", "intent": "stock_sentiment"},
    {"text": "Are investors positive about Britannia Industries shares?", "intent": "stock_sentiment"},
    {"text": "How is the sentiment on Reliance Industries today?", "intent": "stock_sentiment"},
    {"text": "Is Zoom stock trending up in investor sentiment?", "intent": "stock_sentiment"},
    {"text": "What’s the public opinion on Coal India stock?", "intent": "stock_sentiment"},
    {"text": "Check if Pfizer shares have bullish sentiment", "intent": "stock_sentiment"},
    {"text": "Are Bharti Airtel shares viewed favorably by investors?", "intent": "stock_sentiment"},
    {"text": "How do traders feel about Microsoft stock lately?", "intent": "stock_sentiment"},
    {"text": "Is Infosys stock receiving positive market feedback?", "intent": "stock_sentiment"},
    {"text": "What is the market mood on ICICI Bank shares?", "intent": "stock_sentiment"},
    {"text": "Are investors optimistic about Amazon stock?", "intent": "stock_sentiment"},
    {"text": "Tell me the sentiment trend for Wipro shares", "intent": "stock_sentiment"},
    {"text": "How is the sentiment for Apple stock evolving?", "intent": "stock_sentiment"},
    {"text": "Is Larsen & Toubro stock showing positive signs?", "intent": "stock_sentiment"},
    {"text": "Analyze the sentiment of Tesla stock from social media", "intent": "stock_sentiment"},
    {"text": "Are SBI shares viewed as bullish right now?", "intent": "stock_sentiment"},
    {"text": "What is the current sentiment on Google shares?", "intent": "stock_sentiment"},
    {"text": "How are traders feeling about Tata Motors stock?", "intent": "stock_sentiment"},
    {"text": "Is Uber Technologies stock trending positively?", "intent": "stock_sentiment"},
    {"text": "Check the sentiment for Nestle India shares", "intent": "stock_sentiment"},
    {"text": "What’s the investor mood on Bajaj Finance stock?", "intent": "stock_sentiment"},
    {"text": "Tell me if Facebook stock is bullish or bearish", "intent": "stock_sentiment"},
    {"text": "How is the sentiment on HDFC Bank stock?", "intent": "stock_sentiment"},
    {"text": "Are investors confident in Paytm shares?", "intent": "stock_sentiment"},
    {"text": "What is the sentiment on Netflix shares today?", "intent": "stock_sentiment"},
    {"text": "Is Reliance Industries stock viewed positively by traders?", "intent": "stock_sentiment"},
    {"text": "How do investors feel about Axis Bank stock?", "intent": "stock_sentiment"},
    {"text": "Check if Coca-Cola shares have positive sentiment", "intent": "stock_sentiment"},
    {"text": "What is the market sentiment for Tata Steel shares?", "intent": "stock_sentiment"},
    {"text": "Are traders optimistic about Sony stock?", "intent": "stock_sentiment"},
    {"text": "How is the sentiment trend for ICICI Bank shares?", "intent": "stock_sentiment"},
    {"text": "Tell me if Microsoft stock is receiving positive reviews", "intent": "stock_sentiment"},
    {"text": "Analyze the sentiment on Wipro stock from recent news", "intent": "stock_sentiment"},
    {"text": "Are investors bullish on Bajaj Auto shares?", "intent": "stock_sentiment"},
    {"text": "What’s the sentiment on Asian Paints stock currently?", "intent": "stock_sentiment"},
    {"text": "How do traders view Larsen & Toubro stock?", "intent": "stock_sentiment"},
    {"text": "Is Amazon stock trending positively today?", "intent": "stock_sentiment"},
    {"text": "What’s the market feeling about Pfizer stock?", "intent": "stock_sentiment"},
    {"text": "Are investors optimistic about Uber Technologies stock?", "intent": "stock_sentiment"},
    {"text": "Tell me if Facebook shares are trending bullish", "intent": "stock_sentiment"},
    {"text": "How is the sentiment on Nestle India stock?", "intent": "stock_sentiment"},
    {"text": "Check the public sentiment for Britannia Industries stock", "intent": "stock_sentiment"},
    {"text": "Is Coca-Cola stock viewed favorably by traders?", "intent": "stock_sentiment"},
    {"text": "Analyze the market sentiment on Ford stock", "intent": "stock_sentiment"},
    {"text": "Are Tesla shares bullish or bearish right now?", "intent": "stock_sentiment"},
    {"text": "What’s the sentiment for Bajaj Finance shares?", "intent": "stock_sentiment"},
    {"text": "Tell me if Infosys stock is trending positively", "intent": "stock_sentiment"},
    {"text": "How is the sentiment on Axis Bank stock evolving?", "intent": "stock_sentiment"},
    {"text": "Are investors confident about Tata Motors shares?", "intent": "stock_sentiment"},
    {"text": "What’s the current market sentiment for HCL Technologies?", "intent": "stock_sentiment"},
    {"text": "Is Reliance Industries stock sentiment bullish today?", "intent": "stock_sentiment"},
    {"text": "Check the investor sentiment for ICICI Bank shares", "intent": "stock_sentiment"},
    {"text": "How do traders feel about Microsoft stock?", "intent": "stock_sentiment"},
    {"text": "What’s the general mood about Netflix stock?", "intent": "stock_sentiment"},
    {"text": "Tell me if Tata Steel shares are favored by investors", "intent": "stock_sentiment"},
    {"text": "Is Uber stock viewed positively by market participants?", "intent": "stock_sentiment"},
    {"text": "Analyze the sentiment for Amazon shares from social media", "intent": "stock_sentiment"},
    {"text": "Are Facebook shares trending up or down?", "intent": "stock_sentiment"},
    {"text": "What’s the current sentiment on Apple stock?", "intent": "stock_sentiment"}
]

# %%
data5 = [
    {"text": "What’s the investor sentiment on Dr. Reddy’s Laboratories shares?", "intent": "stock_sentiment"},
    {"text": "How is the market feeling about Qualcomm stock?", "intent": "stock_sentiment"},
    {"text": "Is the sentiment positive for State Bank of India shares?", "intent": "stock_sentiment"},
    {"text": "Tell me the current mood around Goldman Sachs stock", "intent": "stock_sentiment"},
    {"text": "Are investors bullish on ICICI Prudential Life shares?", "intent": "stock_sentiment"},
    {"text": "Analyze the sentiment on Johnson & Johnson stock", "intent": "stock_sentiment"},
    {"text": "What is the general sentiment for Larsen & Toubro Infotech stock?", "intent": "stock_sentiment"},
    {"text": "How are traders feeling about Mahindra & Mahindra shares?", "intent": "stock_sentiment"},
    {"text": "Is the market sentiment optimistic for Boeing stock?", "intent": "stock_sentiment"},
    {"text": "Check the sentiment for Nestle India stock", "intent": "stock_sentiment"},
    {"text": "What’s the sentiment trend for HDFC Life shares?", "intent": "stock_sentiment"},
    {"text": "Are investors positive about Apple Inc stock recently?", "intent": "stock_sentiment"},
    {"text": "How do market participants view Axis Bank shares now?", "intent": "stock_sentiment"},
    {"text": "Tell me if Tata Consultancy Services shares have bullish sentiment", "intent": "stock_sentiment"},
    {"text": "What is the investor mood on Facebook stock?", "intent": "stock_sentiment"},
    {"text": "Analyze the sentiment for Infosys stock from recent reports", "intent": "stock_sentiment"},
    {"text": "Are traders optimistic about Netflix shares?", "intent": "stock_sentiment"},
    {"text": "How is the sentiment on Adani Ports stock?", "intent": "stock_sentiment"},
    {"text": "What’s the sentiment for Tesla stock after latest earnings?", "intent": "stock_sentiment"},
    {"text": "Tell me if Reliance Industries shares are favored by investors today", "intent": "stock_sentiment"},
    {"text": "How do investors feel about PepsiCo stock?", "intent": "stock_sentiment"},
    {"text": "Is the market mood positive for Bajaj Finance shares?", "intent": "stock_sentiment"},
    {"text": "Check if Wipro stock is bullish or bearish", "intent": "stock_sentiment"},
    {"text": "What is the sentiment on Maruti Suzuki stock currently?", "intent": "stock_sentiment"},
    {"text": "Are investors confident about Bharti Airtel shares?", "intent": "stock_sentiment"},
    {"text": "How do traders view Cisco Systems stock?", "intent": "stock_sentiment"},
    {"text": "Is Tata Power stock trending up or down in sentiment?", "intent": "stock_sentiment"},
    {"text": "What’s the investor sentiment on Uber Technologies shares?", "intent": "stock_sentiment"},
    {"text": "Tell me if Bajaj Auto stock is viewed positively by traders", "intent": "stock_sentiment"},
    {"text": "How is the sentiment on Johnson Controls stock?", "intent": "stock_sentiment"},
    {"text": "Are investors bullish on Oil and Natural Gas Corporation shares?", "intent": "stock_sentiment"},
    {"text": "What is the current sentiment trend for Facebook stock?", "intent": "stock_sentiment"},
    {"text": "Analyze the market mood for ICICI Bank shares", "intent": "stock_sentiment"},
    {"text": "Is the sentiment favorable for Britannia Industries shares?", "intent": "stock_sentiment"},
    {"text": "How do investors feel about Qualcomm shares?", "intent": "stock_sentiment"},
    {"text": "What is the sentiment on Tata Chemicals stock?", "intent": "stock_sentiment"},
    {"text": "Tell me if Apple stock has positive sentiment this week", "intent": "stock_sentiment"},
    {"text": "Are traders optimistic about Infosys shares currently?", "intent": "stock_sentiment"},
    {"text": "How is the market sentiment on Siemens India stock?", "intent": "stock_sentiment"},
    {"text": "What’s the investor mood on Ford Motor Company shares?", "intent": "stock_sentiment"},
    {"text": "Is Reliance Industries stock trending positively this month?", "intent": "stock_sentiment"},
    {"text": "Check sentiment for Tata Steel shares", "intent": "stock_sentiment"},
    {"text": "Are investors confident about Nestle India stock?", "intent": "stock_sentiment"},
    {"text": "Tell me if Microsoft stock is bullish or bearish today", "intent": "stock_sentiment"},
    {"text": "What’s the sentiment for Asian Paints shares?", "intent": "stock_sentiment"},
    {"text": "Analyze the current sentiment on Bajaj Finance stock", "intent": "stock_sentiment"},
    {"text": "Is the investor sentiment positive for Tata Motors shares?", "intent": "stock_sentiment"},
    {"text": "How do traders feel about Amazon stock now?", "intent": "stock_sentiment"},
    {"text": "What is the market sentiment on HDFC Bank stock?", "intent": "stock_sentiment"},
    {"text": "Are investors bullish on Bharti Airtel stock today?", "intent": "stock_sentiment"},
    {"text": "Tell me the general sentiment for Tesla stock", "intent": "stock_sentiment"},
    {"text": "How is the sentiment on Infosys stock trending?", "intent": "stock_sentiment"},
    {"text": "Is Wipro stock receiving positive market feedback?", "intent": "stock_sentiment"},
    {"text": "What’s the investor mood on ICICI Prudential Life shares?", "intent": "stock_sentiment"},
    {"text": "Analyze sentiment trends for Maruti Suzuki stock", "intent": "stock_sentiment"},
    {"text": "Are traders optimistic about Tata Power shares?", "intent": "stock_sentiment"},
    {"text": "What’s the sentiment for State Bank of India stock?", "intent": "stock_sentiment"},
    {"text": "Tell me if Uber stock has positive sentiment currently", "intent": "stock_sentiment"},
    {"text": "How do investors feel about Pfizer shares?", "intent": "stock_sentiment"},
    {"text": "Is the market sentiment favorable for Larsen & Toubro Infotech?", "intent": "stock_sentiment"},
    {"text": "What’s the current investor sentiment on Apple stock?", "intent": "stock_sentiment"}
]

# %%
data6 = [
    {"text": "Check the sentiment for Asian Paints stock", "intent": "stock_sentiment"},
    {"text": "What is the investor mood on Tata Steel shares?", "intent": "stock_sentiment"},
    {"text": "Are traders optimistic about Reliance Industries stock?", "intent": "stock_sentiment"},
    {"text": "Tell me if Infosys stock is bullish or bearish today", "intent": "stock_sentiment"},
    {"text": "How is the market sentiment on Microsoft shares?", "intent": "stock_sentiment"},
    {"text": "Is the investor sentiment positive for ICICI Bank shares?", "intent": "stock_sentiment"},
    {"text": "What’s the sentiment for Bajaj Finance stock?", "intent": "stock_sentiment"},
    {"text": "Analyze the sentiment for Tesla stock", "intent": "stock_sentiment"},
    {"text": "Are investors confident about HDFC Bank stock?", "intent": "stock_sentiment"},
    {"text": "How do traders feel about Amazon shares?", "intent": "stock_sentiment"},
    {"text": "Tell me the current sentiment on Tata Consultancy Services stock", "intent": "stock_sentiment"},
    {"text": "What is the market mood for Bharti Airtel shares?", "intent": "stock_sentiment"},
    {"text": "Is the sentiment favorable for Larsen & Toubro stock?", "intent": "stock_sentiment"},
    {"text": "How is the investor sentiment on Facebook stock?", "intent": "stock_sentiment"},
    {"text": "Check if Apple stock has bullish sentiment today", "intent": "stock_sentiment"},
    {"text": "Are traders optimistic about Nestle India shares?", "intent": "stock_sentiment"},
    {"text": "What is the sentiment trend for State Bank of India stock?", "intent": "stock_sentiment"},
    {"text": "Tell me if Wipro stock is viewed positively by investors", "intent": "stock_sentiment"},
    {"text": "How do investors feel about Boeing stock?", "intent": "stock_sentiment"},
    {"text": "Is the market mood optimistic for Johnson & Johnson shares?", "intent": "stock_sentiment"},
    {"text": "Analyze the sentiment for Tata Motors stock", "intent": "stock_sentiment"},
    {"text": "Are investors bullish on Mahindra & Mahindra stock?", "intent": "stock_sentiment"},
    {"text": "What’s the current investor sentiment on Netflix shares?", "intent": "stock_sentiment"},
    {"text": "How is the sentiment on Pfizer stock?", "intent": "stock_sentiment"},
    {"text": "Tell me if ICICI Prudential Life shares have positive sentiment", "intent": "stock_sentiment"},
    {"text": "Check the sentiment for Uber Technologies stock", "intent": "stock_sentiment"},
    {"text": "Is the investor mood positive for Asian Paints shares?", "intent": "stock_sentiment"},
    {"text": "What’s the market sentiment for Tata Chemicals stock?", "intent": "stock_sentiment"},
    {"text": "Are traders optimistic about Reliance Power stock?", "intent": "stock_sentiment"},
    {"text": "How do investors feel about Cisco Systems shares?", "intent": "stock_sentiment"},
    {"text": "Tell me the sentiment on Johnson Controls stock", "intent": "stock_sentiment"},
    {"text": "Is the market mood bullish for Bajaj Auto shares?", "intent": "stock_sentiment"},
    {"text": "Analyze the investor sentiment for Ford Motor Company stock", "intent": "stock_sentiment"},
    {"text": "Are investors confident about Oil and Natural Gas Corporation shares?", "intent": "stock_sentiment"},
    {"text": "What’s the sentiment trend for Britannia Industries stock?", "intent": "stock_sentiment"},
    {"text": "Tell me if Tesla stock is viewed positively by traders", "intent": "stock_sentiment"},
    {"text": "How is the sentiment on HDFC Life shares?", "intent": "stock_sentiment"},
    {"text": "Check the current investor sentiment on Maruti Suzuki stock", "intent": "stock_sentiment"},
    {"text": "Are investors bullish on Tata Power stock?", "intent": "stock_sentiment"},
    {"text": "What’s the sentiment for Infosys shares?", "intent": "stock_sentiment"},
    {"text": "Tell me if Facebook stock has positive sentiment now", "intent": "stock_sentiment"},
    {"text": "How do traders feel about Bajaj Finance stock?", "intent": "stock_sentiment"},
    {"text": "Is the investor mood favorable for ICICI Bank shares?", "intent": "stock_sentiment"},
    {"text": "What is the sentiment on Nestle India stock?", "intent": "stock_sentiment"},
    {"text": "Are traders optimistic about Larsen & Toubro Infotech stock?", "intent": "stock_sentiment"},
    {"text": "Tell me if Amazon stock is bullish or bearish", "intent": "stock_sentiment"},
    {"text": "How is the market feeling about Qualcomm shares?", "intent": "stock_sentiment"},
    {"text": "What’s the investor sentiment on Tata Steel shares?", "intent": "stock_sentiment"},
    {"text": "Are investors confident about Bharti Airtel shares?", "intent": "stock_sentiment"},
    {"text": "Analyze the sentiment for Microsoft stock", "intent": "stock_sentiment"},
    {"text": "Is the market mood positive for Apple Inc stock?", "intent": "stock_sentiment"},
    {"text": "Tell me if Wipro stock is bullish or bearish today", "intent": "stock_sentiment"},
    {"text": "How do investors feel about Tata Consultancy Services shares?", "intent": "stock_sentiment"},
    {"text": "What’s the sentiment for Mahindra & Mahindra stock?", "intent": "stock_sentiment"},
    {"text": "Are traders optimistic about Netflix stock?", "intent": "stock_sentiment"},
    {"text": "Check the sentiment on ICICI Prudential Life stock", "intent": "stock_sentiment"},
    {"text": "Tell me if Tesla stock has bullish sentiment", "intent": "stock_sentiment"},
    {"text": "How is the market sentiment on Reliance Industries stock?", "intent": "stock_sentiment"},
    {"text": "What’s the investor mood on Bajaj Auto shares?", "intent": "stock_sentiment"},
    {"text": "Are investors confident about Larsen & Toubro stock?", "intent": "stock_sentiment"},
    {"text": "Tell me if Facebook stock is viewed positively", "intent": "stock_sentiment"},
    {"text": "How do traders feel about Uber stock?", "intent": "stock_sentiment"},
    {"text": "Is the market sentiment favorable for Tata Motors stock?", "intent": "stock_sentiment"},
    {"text": "Analyze the investor sentiment on Johnson & Johnson shares", "intent": "stock_sentiment"},
    {"text": "What’s the sentiment trend for Infosys shares?", "intent": "stock_sentiment"},
    {"text": "Are investors bullish on Apple stock today?", "intent": "stock_sentiment"},
    {"text": "Tell me if Bajaj Finance stock has positive sentiment", "intent": "stock_sentiment"},
    {"text": "How is the sentiment on HDFC Bank stock?", "intent": "stock_sentiment"},
    {"text": "What’s the investor sentiment on Nestle India shares?", "intent": "stock_sentiment"},
    {"text": "Are traders optimistic about State Bank of India stock?", "intent": "stock_sentiment"},
    {"text": "Check if Amazon stock is bullish or bearish", "intent": "stock_sentiment"},
    {"text": "Tell me the current sentiment on Microsoft shares", "intent": "stock_sentiment"}
]

# %%
data7 = [
    {"text": "What’s the sentiment on Maruti Suzuki stock?", "intent": "stock_sentiment"},
    {"text": "Are traders bullish on Tata Steel shares?", "intent": "stock_sentiment"},
    {"text": "Analyze investor mood for Reliance Industries today", "intent": "stock_sentiment"},
    {"text": "Is the market sentiment positive for Infosys stock?", "intent": "stock_sentiment"},
    {"text": "Tell me if Tesla shares have bullish sentiment now", "intent": "stock_sentiment"},
    {"text": "How do investors feel about ICICI Bank stock today?", "intent": "stock_sentiment"},
    {"text": "Check if Amazon stock is being viewed positively", "intent": "stock_sentiment"},
    {"text": "What’s the sentiment trend for Asian Paints shares?", "intent": "stock_sentiment"},
    {"text": "Are traders optimistic about HDFC Bank shares?", "intent": "stock_sentiment"},
    {"text": "Tell me if Microsoft stock is gaining positive sentiment", "intent": "stock_sentiment"},
    {"text": "How is the investor mood on Bharti Airtel stock?", "intent": "stock_sentiment"},
    {"text": "Is the market sentiment bullish for Tata Motors shares?", "intent": "stock_sentiment"},
    {"text": "Analyze current sentiment for Facebook stock", "intent": "stock_sentiment"},
    {"text": "Are investors confident about Bajaj Finance stock?", "intent": "stock_sentiment"},
    {"text": "Tell me if Wipro stock sentiment is positive today", "intent": "stock_sentiment"},
    {"text": "What’s the investor mood for Netflix shares?", "intent": "stock_sentiment"},
    {"text": "How do traders feel about Larsen & Toubro stock?", "intent": "stock_sentiment"},
    {"text": "Check the sentiment for Johnson & Johnson stock", "intent": "stock_sentiment"},
    {"text": "Is the market optimistic about Tata Power shares?", "intent": "stock_sentiment"},
    {"text": "Tell me if Uber stock is experiencing bullish sentiment", "intent": "stock_sentiment"},
    {"text": "What’s the sentiment on Pfizer stock today?", "intent": "stock_sentiment"},
    {"text": "Are investors positive about ICICI Prudential Life shares?", "intent": "stock_sentiment"},
    {"text": "How is the market feeling about Ford Motor Company stock?", "intent": "stock_sentiment"},
    {"text": "Tell me if Sony stock has positive investor sentiment", "intent": "stock_sentiment"},
    {"text": "Check if Apple stock is showing bullish signals", "intent": "stock_sentiment"},
    {"text": "What’s the sentiment on Tata Chemicals shares?", "intent": "stock_sentiment"},
    {"text": "Are traders optimistic about Reliance Power stock?", "intent": "stock_sentiment"},
    {"text": "Analyze the sentiment for Boeing stock", "intent": "stock_sentiment"},
    {"text": "How do investors feel about Cisco Systems shares?", "intent": "stock_sentiment"},
    {"text": "Is the market mood positive for Bajaj Auto stock?", "intent": "stock_sentiment"},
    {"text": "Tell me the current sentiment on Britannia Industries stock", "intent": "stock_sentiment"},
    {"text": "Are traders bullish on Tata Consultancy Services shares?", "intent": "stock_sentiment"},
    {"text": "What’s the investor sentiment on State Bank of India stock?", "intent": "stock_sentiment"},
    {"text": "Check if Amazon shares have positive sentiment", "intent": "stock_sentiment"},
    {"text": "How do investors feel about Facebook stock today?", "intent": "stock_sentiment"},
    {"text": "Is the market optimistic about Maruti Suzuki shares?", "intent": "stock_sentiment"},
    {"text": "Tell me if Tesla stock is showing bearish signs", "intent": "stock_sentiment"},
    {"text": "Analyze current investor sentiment for ICICI Bank shares", "intent": "stock_sentiment"},
    {"text": "What’s the sentiment trend for Infosys stock?", "intent": "stock_sentiment"},
    {"text": "Are traders bullish on Larsen & Toubro Infotech shares?", "intent": "stock_sentiment"},
    {"text": "Tell me if Microsoft shares are viewed positively", "intent": "stock_sentiment"},
    {"text": "How do investors feel about Bajaj Finance stock?", "intent": "stock_sentiment"},
    {"text": "Is the market mood favorable for Tata Motors stock?", "intent": "stock_sentiment"},
    {"text": "Check the investor sentiment on Netflix shares", "intent": "stock_sentiment"},
    {"text": "What’s the market feeling about ICICI Prudential Life stock?", "intent": "stock_sentiment"},
    {"text": "Are traders optimistic about Apple stock?", "intent": "stock_sentiment"},
    {"text": "Tell me if Reliance Industries stock sentiment is bullish", "intent": "stock_sentiment"},
    {"text": "How do investors feel about Bajaj Auto stock today?", "intent": "stock_sentiment"},
    {"text": "Is the market positive about Tata Steel shares?", "intent": "stock_sentiment"},
    {"text": "Check if Amazon stock is showing bullish momentum", "intent": "stock_sentiment"},
    {"text": "Tell me the current investor mood for Microsoft shares", "intent": "stock_sentiment"},
    {"text": "Are investors confident about HDFC Life stock?", "intent": "stock_sentiment"},
    {"text": "What’s the sentiment on Bharti Airtel shares today?", "intent": "stock_sentiment"},
    {"text": "Analyze the market sentiment for Larsen & Toubro stock", "intent": "stock_sentiment"},
    {"text": "Is the investor mood positive for Tesla stock?", "intent": "stock_sentiment"},
    {"text": "How do traders feel about Tata Consultancy Services shares?", "intent": "stock_sentiment"},
    {"text": "Tell me if Apple stock is showing positive sentiment", "intent": "stock_sentiment"},
    {"text": "Are investors bullish on Netflix stock?", "intent": "stock_sentiment"},
    {"text": "What’s the sentiment trend for Facebook shares?", "intent": "stock_sentiment"},
    {"text": "Check if ICICI Bank shares are viewed positively", "intent": "stock_sentiment"},
    {"text": "How is the market mood about Infosys stock?", "intent": "stock_sentiment"},
    {"text": "Tell me if Tata Power stock has bullish sentiment", "intent": "stock_sentiment"},
    {"text": "Are traders optimistic about Amazon stock today?", "intent": "stock_sentiment"}
]

# %%
data8 = [
    {"text": "What’s the sentiment on HCL Technologies stock?", "intent": "stock_sentiment"},
    {"text": "Are investors bullish about Mahindra & Mahindra shares?", "intent": "stock_sentiment"},
    {"text": "Analyze market mood for Paytm stock", "intent": "stock_sentiment"},
    {"text": "Is the sentiment positive for Google stock today?", "intent": "stock_sentiment"},
    {"text": "Tell me if Wipro shares are gaining bullish momentum", "intent": "stock_sentiment"},
    {"text": "How do traders feel about SBI Life stock?", "intent": "stock_sentiment"},
    {"text": "Is Tesla stock being viewed negatively?", "intent": "stock_sentiment"},
    {"text": "What’s the current investor sentiment for UltraTech Cement?", "intent": "stock_sentiment"},
    {"text": "Are traders optimistic about IBM shares?", "intent": "stock_sentiment"},
    {"text": "Tell me if Tata Consumer Products stock is bullish", "intent": "stock_sentiment"},
    {"text": "Check the sentiment for Adobe stock", "intent": "stock_sentiment"},
    {"text": "How is the market feeling about Kotak Mahindra Bank shares?", "intent": "stock_sentiment"},
    {"text": "What’s the investor mood for Netflix stock?", "intent": "stock_sentiment"},
    {"text": "Are investors positive about Maruti Suzuki shares?", "intent": "stock_sentiment"},
    {"text": "Tell me if Apple stock is showing bearish sentiment", "intent": "stock_sentiment"},
    {"text": "Analyze the sentiment for Asian Paints shares", "intent": "stock_sentiment"},
    {"text": "Is the market optimistic about HDFC Bank stock?", "intent": "stock_sentiment"},
    {"text": "How do traders feel about Tesla shares today?", "intent": "stock_sentiment"},
    {"text": "Check if Infosys stock is trending bullish", "intent": "stock_sentiment"},
    {"text": "Tell me the current investor mood for ICICI Bank stock", "intent": "stock_sentiment"},
    {"text": "Are traders bullish on Reliance Industries shares?", "intent": "stock_sentiment"},
    {"text": "What’s the sentiment on Tata Steel stock?", "intent": "stock_sentiment"},
    {"text": "How is the market feeling about Facebook shares?", "intent": "stock_sentiment"},
    {"text": "Is the sentiment positive for Microsoft stock?", "intent": "stock_sentiment"},
    {"text": "Tell me if Amazon stock is bullish or bearish", "intent": "stock_sentiment"},
    {"text": "Are investors confident about Larsen & Toubro shares?", "intent": "stock_sentiment"},
    {"text": "Check the market mood for Sony stock", "intent": "stock_sentiment"},
    {"text": "How do traders feel about Bharat Petroleum stock?", "intent": "stock_sentiment"},
    {"text": "What’s the investor sentiment on Tata Power shares?", "intent": "stock_sentiment"},
    {"text": "Are investors optimistic about Zoom Video stock?", "intent": "stock_sentiment"},
    {"text": "Tell me if Boeing stock is showing bullish trends", "intent": "stock_sentiment"},
    {"text": "How is the market mood for Bajaj Finance stock?", "intent": "stock_sentiment"},
    {"text": "Are traders bullish on HDFC Life shares?", "intent": "stock_sentiment"},
    {"text": "What’s the sentiment trend for ICICI Prudential Life stock?", "intent": "stock_sentiment"},
    {"text": "Tell me if Uber stock has positive investor sentiment", "intent": "stock_sentiment"},
    {"text": "How do investors feel about Tata Consultancy Services stock?", "intent": "stock_sentiment"},
    {"text": "Check if Reliance Power shares are gaining bullish momentum", "intent": "stock_sentiment"},
    {"text": "Are traders optimistic about Pfizer stock?", "intent": "stock_sentiment"},
    {"text": "What’s the investor mood for Bajaj Auto shares?", "intent": "stock_sentiment"},
    {"text": "Tell me if Adobe shares are trending bullish", "intent": "stock_sentiment"},
    {"text": "How is the market sentiment for Mahindra Electric stock?", "intent": "stock_sentiment"},
    {"text": "Are investors positive about Facebook stock?", "intent": "stock_sentiment"},
    {"text": "Check the sentiment on Tata Chemicals shares", "intent": "stock_sentiment"},
    {"text": "What’s the market feeling about Infosys stock today?", "intent": "stock_sentiment"},
    {"text": "Tell me if ICICI Bank shares are showing bearish signs", "intent": "stock_sentiment"},
    {"text": "Are traders bullish on Maruti Suzuki stock?", "intent": "stock_sentiment"},
    {"text": "How do investors feel about Google stock?", "intent": "stock_sentiment"},
    {"text": "What’s the sentiment on Wipro stock?", "intent": "stock_sentiment"},
    {"text": "Tell me if Tesla shares are gaining positive sentiment", "intent": "stock_sentiment"},
    {"text": "Are traders optimistic about Reliance Industries stock?", "intent": "stock_sentiment"},
    {"text": "How is the market mood for Amazon stock?", "intent": "stock_sentiment"},
    {"text": "Check if Microsoft stock is trending bullish", "intent": "stock_sentiment"},
    {"text": "Tell me the investor sentiment for Larsen & Toubro stock", "intent": "stock_sentiment"},
    {"text": "Are investors confident about Bajaj Finance shares?", "intent": "stock_sentiment"},
    {"text": "What’s the sentiment trend for Tata Motors stock?", "intent": "stock_sentiment"},
    {"text": "How do traders feel about Netflix stock?", "intent": "stock_sentiment"},
    {"text": "Tell me if ICICI Prudential Life stock is bullish", "intent": "stock_sentiment"},
    {"text": "Are investors positive about Apple stock?", "intent": "stock_sentiment"},
    {"text": "What’s the market feeling about Bajaj Auto stock?", "intent": "stock_sentiment"},
    {"text": "Check if Amazon shares are gaining bullish momentum", "intent": "stock_sentiment"},
    {"text": "How do investors feel about Tata Steel stock?", "intent": "stock_sentiment"}
]

# %%
data9 = [
    {"text": "What is the current sentiment for Axis Bank stock?", "intent": "stock_sentiment"},
    {"text": "Are investors bullish on HDFC shares today?", "intent": "stock_sentiment"},
    {"text": "Analyze the market sentiment for ITC stock", "intent": "stock_sentiment"},
    {"text": "How is the investor mood for Infosys stock?", "intent": "stock_sentiment"},
    {"text": "Is the sentiment positive for Reliance Industries stock?", "intent": "stock_sentiment"},
    {"text": "Tell me if Tata Steel shares are bullish or bearish", "intent": "stock_sentiment"},
    {"text": "What do traders think about Wipro stock?", "intent": "stock_sentiment"},
    {"text": "How do investors feel about Adani Enterprises shares?", "intent": "stock_sentiment"},
    {"text": "Are the market sentiments favorable for Bharti Airtel stock?", "intent": "stock_sentiment"},
    {"text": "Is there bullish momentum in Asian Paints shares?", "intent": "stock_sentiment"},
    {"text": "Check the current investor sentiment on Google stock", "intent": "stock_sentiment"},
    {"text": "Is Tesla stock showing signs of bearish trend?", "intent": "stock_sentiment"},
    {"text": "How is the market sentiment for Nestle India stock?", "intent": "stock_sentiment"},
    {"text": "Tell me if Amazon shares are gaining positive investor sentiment", "intent": "stock_sentiment"},
    {"text": "What’s the sentiment around Maruti Suzuki stock?", "intent": "stock_sentiment"},
    {"text": "Are traders optimistic about Bajaj Finance stock?", "intent": "stock_sentiment"},
    {"text": "Analyze the stock sentiment for Pfizer shares", "intent": "stock_sentiment"},
    {"text": "Is the market mood bullish for ICICI Bank stock?", "intent": "stock_sentiment"},
    {"text": "Tell me if Netflix stock is seeing positive investor interest", "intent": "stock_sentiment"},
    {"text": "What is the sentiment for UltraTech Cement shares?", "intent": "stock_sentiment"},
    {"text": "Are investors positive about Microsoft stock?", "intent": "stock_sentiment"},
    {"text": "How do traders feel about Sony stock today?", "intent": "stock_sentiment"},
    {"text": "What’s the investor sentiment for Tata Motors shares?", "intent": "stock_sentiment"},
    {"text": "Check if Reliance Power stock is bullish or bearish", "intent": "stock_sentiment"},
    {"text": "How is the market feeling about HDFC Life stock?", "intent": "stock_sentiment"},
    {"text": "Are the investors optimistic about Bharat Petroleum shares?", "intent": "stock_sentiment"},
    {"text": "Tell me if Uber stock is showing bullish trends", "intent": "stock_sentiment"},
    {"text": "What’s the sentiment for Bajaj Auto stock today?", "intent": "stock_sentiment"},
    {"text": "How do investors feel about Infosys shares?", "intent": "stock_sentiment"},
    {"text": "Are traders confident about Larsen & Toubro stock?", "intent": "stock_sentiment"},
    {"text": "Is Amazon stock being viewed positively by the market?", "intent": "stock_sentiment"},
    {"text": "What is the current mood for Axis Bank shares?", "intent": "stock_sentiment"},
    {"text": "Tell me if HCL Technologies stock is bullish", "intent": "stock_sentiment"},
    {"text": "How’s the market sentiment on Tata Consumer Products stock?", "intent": "stock_sentiment"},
    {"text": "Are investors positive about ICICI Prudential Life shares?", "intent": "stock_sentiment"},
    {"text": "Is the stock sentiment bullish for Adani Ports and SEZ?", "intent": "stock_sentiment"},
    {"text": "What’s the current investor mood for Paytm stock?", "intent": "stock_sentiment"},
    {"text": "Check the sentiment trend for Bajaj Finance shares", "intent": "stock_sentiment"},
    {"text": "Are traders optimistic about Google stock?", "intent": "stock_sentiment"},
    {"text": "How do investors feel about Facebook shares?", "intent": "stock_sentiment"},
    {"text": "What’s the market sentiment on Mahindra & Mahindra stock?", "intent": "stock_sentiment"},
    {"text": "Tell me if ICICI Bank shares are trending bullish", "intent": "stock_sentiment"},
    {"text": "Are investors confident about Tata Power stock?", "intent": "stock_sentiment"},
    {"text": "How is the sentiment for Nestle India shares?", "intent": "stock_sentiment"},
    {"text": "What’s the sentiment around Sony stock today?", "intent": "stock_sentiment"},
    {"text": "Are traders positive about Bajaj Auto shares?", "intent": "stock_sentiment"},
    {"text": "Check if Maruti Suzuki stock has bullish momentum", "intent": "stock_sentiment"},
    {"text": "What do investors think about Pfizer shares?", "intent": "stock_sentiment"},
    {"text": "Is Tesla stock being perceived negatively?", "intent": "stock_sentiment"},
    {"text": "How is the market feeling about UltraTech Cement shares?", "intent": "stock_sentiment"},
    {"text": "Are traders optimistic about Adobe stock?", "intent": "stock_sentiment"},
    {"text": "What’s the investor sentiment on Wipro shares?", "intent": "stock_sentiment"},
    {"text": "Tell me if Amazon stock is bullish or bearish today", "intent": "stock_sentiment"},
    {"text": "Are investors positive about Tata Steel stock?", "intent": "stock_sentiment"},
    {"text": "How do traders feel about HDFC Bank stock?", "intent": "stock_sentiment"},
    {"text": "What’s the market sentiment for Reliance Industries shares?", "intent": "stock_sentiment"},
    {"text": "Is ICICI Prudential Life stock trending bullish?", "intent": "stock_sentiment"},
    {"text": "Tell me if Facebook stock is being viewed positively", "intent": "stock_sentiment"},
    {"text": "Are investors confident about Bajaj Finance shares?", "intent": "stock_sentiment"}
]

# %% [markdown]
# ## Randomizing company names

# %%
import random
import json

templates = [
    "What is the sentiment of {company} stock?",
    "Tell me if {company} is going up or down.",
    "Analyze the stock sentiment for {company}.",
    "Is {company} stock bullish or bearish?",
    "How is the market feeling about {company}?",
    "Give me the current sentiment for {company} shares.",
    "What’s the investor sentiment on {company} stock?",
    "Are investors positive or negative on {company} stock?",
    "Check the sentiment for {company} stock.",
    "How are people reacting to {company} shares?",
    "Is {company} stock showing bullish signs?",
    "Tell me if {company} stock is trending up.",
    "What’s the mood around {company} stock today?",
    "Are {company} shares seeing positive sentiment?",
    "Is {company} stock getting good reviews from traders?",
    "How is the market sentiment for {company} stocks?",
    "Give me sentiment analysis for {company} stock.",
    "Are investors confident in {company} shares?",
    "Check the public sentiment for {company} stock.",
    "Is {company} stock showing positive signs?",
    "How are {company} shares perceived by traders?",
    "Is the {company} stock sentiment bullish or bearish?",
    "What’s the investor sentiment for {company} today?",
    "Are traders optimistic about {company} stock?",
    "Is {company} stock trending positively?",
    "Tell me if {company} shares have a positive outlook.",
    "Analyze {company}’s stock sentiment from recent news.",
    "What’s the general market sentiment on {company} stock?",
    "Are {company} shares viewed positively right now?",
    "How do investors feel about {company} stock recently?",
    "Check the sentiment for {company} shares today.",
    "Is {company} stock sentiment favorable?",
    "Are {company} shares in a bullish mood?",
    "What’s the public opinion on {company} stock?",
    "Tell me if {company} shares are favored by investors.",
    "How is the sentiment on {company} shares?",
    "Is {company} stock viewed as bullish currently?",
    "Analyze {company} stock sentiment from social media.",
    "What’s the public sentiment for {company} shares?",
    "Are {company} shares seeing increased investor confidence?",
    "How is {company} stock sentiment trending?",
    "Check if {company} stock is receiving positive feedback.",
    "Is {company} stock sentiment positive or negative?",
    "Are {company} shares trending bullish currently?",
    "What’s the investor mood around {company} stock?",
    "Are {company} shares favored in today’s market?",
    "How is the sentiment on {company} stock evolving?",
]

companies = [
    "Reliance Industries", "Tesla", "Microsoft", "Amazon", "Infosys", "Apple", "TCS",
    "Google", "ICICI Bank", "Nvidia", "HDFC Bank", "Facebook", "SBI", "Bharti Airtel",
    "Asian Paints", "Bajaj Finance", "Maruti Suzuki", "Netflix", "Tata Motors", "Paytm",
    "Adani Enterprises", "LIC", "JSW Steel", "Wipro", "Dell", "Meta", "Zomato", "Uber",
    "Tata Steel", "BYJU’s", "Flipkart", "Axis Bank", "Tech Mahindra", "Tata Elxsi",
    "Marico", "Bharat Electronics", "ITC", "Vedanta", "ONGC", "HUL", "Britannia",
    "Ashok Leyland", "NTPC", "Twitter"
]

generated_data = [
    {"text": template.format(company=random.choice(companies)), "intent": "stock_sentiment"}
    for template in random.choices(templates, k=500)
]

# %%
data10 = [
    {"text": "What is the investor sentiment for Sun Pharma stock?", "intent": "stock_sentiment"},
    {"text": "Is Tesla stock gaining bullish momentum?", "intent": "stock_sentiment"},
    {"text": "How do traders view HDFC Bank shares?", "intent": "stock_sentiment"},
    {"text": "Are investors optimistic about Reliance Industries today?", "intent": "stock_sentiment"},
    {"text": "Analyze market mood for Google stock", "intent": "stock_sentiment"},
    {"text": "Is Infosys stock showing signs of positive sentiment?", "intent": "stock_sentiment"},
    {"text": "What’s the sentiment around Tata Motors shares?", "intent": "stock_sentiment"},
    {"text": "Are traders bearish on Amazon stock?", "intent": "stock_sentiment"},
    {"text": "Tell me if Bajaj Finance shares are bullish", "intent": "stock_sentiment"},
    {"text": "How is the market sentiment for Adani Enterprises?", "intent": "stock_sentiment"},
    {"text": "Is Microsoft stock viewed positively by investors?", "intent": "stock_sentiment"},
    {"text": "What do investors think about ICICI Bank shares?", "intent": "stock_sentiment"},
    {"text": "Are investors bullish on Bharti Airtel stock?", "intent": "stock_sentiment"},
    {"text": "How is the sentiment for Maruti Suzuki shares?", "intent": "stock_sentiment"},
    {"text": "Tell me if Facebook stock is trending up", "intent": "stock_sentiment"},
    {"text": "Are traders positive on Wipro stock?", "intent": "stock_sentiment"},
    {"text": "What is the sentiment for Larsen & Toubro shares?", "intent": "stock_sentiment"},
    {"text": "How do investors feel about Tata Steel stock?", "intent": "stock_sentiment"},
    {"text": "Is the market mood bearish for Netflix stock?", "intent": "stock_sentiment"},
    {"text": "What’s the sentiment trend for Bajaj Auto shares?", "intent": "stock_sentiment"},
    {"text": "Are investors confident about Uber stock?", "intent": "stock_sentiment"},
    {"text": "Tell me if UltraTech Cement shares are seeing positive sentiment", "intent": "stock_sentiment"},
    {"text": "What’s the current investor mood on ICICI Prudential Life?", "intent": "stock_sentiment"},
    {"text": "Are traders optimistic about Paytm stock?", "intent": "stock_sentiment"},
    {"text": "How do investors feel about Sony shares?", "intent": "stock_sentiment"},
    {"text": "Is the stock sentiment bullish for HCL Technologies?", "intent": "stock_sentiment"},
    {"text": "Check if Tata Consumer Products stock is favored by investors", "intent": "stock_sentiment"},
    {"text": "Are investors positive on Bajaj Finance stock?", "intent": "stock_sentiment"},
    {"text": "What’s the sentiment for Nestle India shares?", "intent": "stock_sentiment"},
    {"text": "How do traders view Mahindra & Mahindra stock?", "intent": "stock_sentiment"},
    {"text": "Tell me if ICICI Bank shares are bullish or bearish", "intent": "stock_sentiment"},
    {"text": "Are investors confident about Tata Power stock?", "intent": "stock_sentiment"},
    {"text": "What’s the investor sentiment on Google shares?", "intent": "stock_sentiment"},
    {"text": "Is Amazon stock showing bullish signals?", "intent": "stock_sentiment"},
    {"text": "How is the market feeling about Axis Bank stock?", "intent": "stock_sentiment"},
    {"text": "Are traders optimistic about HDFC Life shares?", "intent": "stock_sentiment"},
    {"text": "What is the sentiment for Reliance Power stock?", "intent": "stock_sentiment"},
    {"text": "Tell me if Bajaj Auto shares are favored by investors", "intent": "stock_sentiment"},
    {"text": "Are investors positive about Pfizer stock?", "intent": "stock_sentiment"},
    {"text": "What’s the market mood on Netflix shares?", "intent": "stock_sentiment"},
    {"text": "Is Tesla stock viewed negatively?", "intent": "stock_sentiment"},
    {"text": "How do investors feel about Adobe stock?", "intent": "stock_sentiment"},
    {"text": "Are traders bullish on Facebook stock?", "intent": "stock_sentiment"},
    {"text": "Tell me if HDFC Bank stock is gaining positive sentiment", "intent": "stock_sentiment"},
    {"text": "What is the investor sentiment on Tata Steel shares?", "intent": "stock_sentiment"},
    {"text": "Are traders optimistic about Infosys stock?", "intent": "stock_sentiment"},
    {"text": "How do investors view Maruti Suzuki shares?", "intent": "stock_sentiment"},
    {"text": "Is ICICI Prudential Life stock showing signs of bullish momentum?", "intent": "stock_sentiment"},
    {"text": "What’s the current sentiment for Reliance Industries stock?", "intent": "stock_sentiment"},
    {"text": "Are investors confident about Wipro shares?", "intent": "stock_sentiment"},
    {"text": "Tell me if Amazon stock is trending positive", "intent": "stock_sentiment"},
    {"text": "What is the sentiment around Bharti Airtel stock?", "intent": "stock_sentiment"},
    {"text": "Are traders bullish on Tata Motors stock?", "intent": "stock_sentiment"},
    {"text": "How is the market mood for Uber shares?", "intent": "stock_sentiment"},
    {"text": "Are investors optimistic about Nestle India stock?", "intent": "stock_sentiment"}
]

# %% [markdown]
# ## Combining Data

# %%
try:
    data = data1 + data2 + data3 + data4 + data5 + data6 + data7 + data8 + data9 + data10 + generated_data
    df = pd.DataFrame(data)
    df.to_csv('stock_sentiment_data.csv', index=False)
    print("CSV file saved successfully.")
except Exception as e:
    print(f"error occurred: {e}")
# Out:
# CSV file has been saved successfully.
