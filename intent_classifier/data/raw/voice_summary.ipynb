# %% [markdown]
# # Voice Summary intent data

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd

# %% [markdown]
# ## AI Generated data

# %%
data1 = [
  {"text": "Summarize this audio file", "intent": "voice_summary"},
  {"text": "What is this audio clip about?", "intent": "voice_summary"},
  {"text": "Can you give a summary of the voice recording?", "intent": "voice_summary"},
  {"text": "Tell me the gist of this audio", "intent": "voice_summary"},
  {"text": "Provide a brief summary of the audio content", "intent": "voice_summary"},
  {"text": "Summarize the speech I just uploaded", "intent": "voice_summary"},
  {"text": "What are the main points in this recording?", "intent": "voice_summary"},
  {"text": "Can you break down this audio for me?", "intent": "voice_summary"},
  {"text": "Give a short overview of the voice note", "intent": "voice_summary"},
  {"text": "Extract the summary from this sound file", "intent": "voice_summary"},
  {"text": "I want a brief idea of what this audio says", "intent": "voice_summary"},
  {"text": "What does this audio recording discuss?", "intent": "voice_summary"},
  {"text": "Could you summarize this voice clip?", "intent": "voice_summary"},
  {"text": "Tell me the main idea from this audio file", "intent": "voice_summary"},
  {"text": "Give me the key points from the voice note", "intent": "voice_summary"},
  {"text": "Please provide a concise summary of this audio", "intent": "voice_summary"},
  {"text": "What is the content of this recording?", "intent": "voice_summary"},
  {"text": "Summarize what is said in this voice recording", "intent": "voice_summary"},
  {"text": "Give me a quick rundown of this audio", "intent": "voice_summary"},
  {"text": "Break down the main topics from this speech", "intent": "voice_summary"},
  {"text": "Tell me what this audio is about in short", "intent": "voice_summary"},
  {"text": "Can you capture the summary of this sound clip?", "intent": "voice_summary"},
  {"text": "I need a summary for the voice recording", "intent": "voice_summary"},
  {"text": "What are the highlights of this audio?", "intent": "voice_summary"},
  {"text": "Provide a brief recap of the audio content", "intent": "voice_summary"},
  {"text": "Can you tell me the gist of this voice note?", "intent": "voice_summary"},
  {"text": "Summarize the content of this speech recording", "intent": "voice_summary"},
  {"text": "Give a brief overview of the sound recording", "intent": "voice_summary"},
  {"text": "What is being discussed in this audio clip?", "intent": "voice_summary"},
  {"text": "Can you explain what this audio file says in brief?", "intent": "voice_summary"}
]

# %%
data2 = [
  {"text": "Summarize this audio file", "intent": "voice_summary"},
  {"text": "What is this audio clip about?", "intent": "voice_summary"},
  {"text": "Can you give a summary of the voice recording?", "intent": "voice_summary"},
  {"text": "Tell me the gist of this audio", "intent": "voice_summary"},
  {"text": "Provide a brief summary of the audio content", "intent": "voice_summary"},
  {"text": "Summarize the speech I just uploaded", "intent": "voice_summary"},
  {"text": "What are the main points in this recording?", "intent": "voice_summary"},
  {"text": "Can you break down this audio for me?", "intent": "voice_summary"},
  {"text": "Give a short overview of the voice note", "intent": "voice_summary"},
  {"text": "Extract the summary from this sound file", "intent": "voice_summary"},
  {"text": "I want a brief idea of what this audio says", "intent": "voice_summary"},
  {"text": "What’s the core message in this audio?", "intent": "voice_summary"},
  {"text": "Can you tell me what’s being discussed in this voice clip?", "intent": "voice_summary"},
  {"text": "Just give me a quick audio summary", "intent": "voice_summary"},
  {"text": "What’s the topic of this voice message?", "intent": "voice_summary"},
  {"text": "Summarize the contents of this voice file", "intent": "voice_summary"},
  {"text": "Please summarize what’s spoken in this audio", "intent": "voice_summary"},
  {"text": "Give me a short summary of this voice memo", "intent": "voice_summary"},
  {"text": "Tell me briefly what this voice clip is saying", "intent": "voice_summary"},
  {"text": "What is discussed in this audio file?", "intent": "voice_summary"}
]

# %%
data3 = [
  {"text": "Please summarize this voice note", "intent": "voice_summary"},
  {"text": "What’s the overall message in this audio?", "intent": "voice_summary"},
  {"text": "Give me a breakdown of this recording", "intent": "voice_summary"},
  {"text": "Can you highlight the important points in this audio?", "intent": "voice_summary"},
  {"text": "Summarize the conversation in this clip", "intent": "voice_summary"},
  {"text": "What does the speaker talk about here?", "intent": "voice_summary"},
  {"text": "What is the takeaway from this voice message?", "intent": "voice_summary"},
  {"text": "Can I get a short explanation of this audio?", "intent": "voice_summary"},
  {"text": "Summarize the audio in a few sentences", "intent": "voice_summary"},
  {"text": "Tell me what was said in this voice recording", "intent": "voice_summary"},
  {"text": "What’s this sound file trying to convey?", "intent": "voice_summary"},
  {"text": "Give me the essence of this voice note", "intent": "voice_summary"},
  {"text": "Extract and summarize the core message", "intent": "voice_summary"},
  {"text": "I'd like a brief summary of this voice clip", "intent": "voice_summary"},
  {"text": "Can you explain what this person is saying?", "intent": "voice_summary"},
  {"text": "Please provide the key takeaways from the audio", "intent": "voice_summary"},
  {"text": "Give me a recap of this audio file", "intent": "voice_summary"},
  {"text": "What’s the summary of the recording?", "intent": "voice_summary"},
  {"text": "Break this voice clip down into key points", "intent": "voice_summary"},
  {"text": "Summarize the information in this voice message", "intent": "voice_summary"},
  {"text": "Tell me briefly what this audio contains", "intent": "voice_summary"},
  {"text": "What’s being talked about in this voice recording?", "intent": "voice_summary"},
  {"text": "Can you help me understand this audio in a few words?", "intent": "voice_summary"},
  {"text": "Capture the summary from this audio note", "intent": "voice_summary"},
  {"text": "Give me a quick idea of what this person said", "intent": "voice_summary"},
  {"text": "Summarize what the speaker is saying", "intent": "voice_summary"},
  {"text": "What does the audio talk about?", "intent": "voice_summary"},
  {"text": "Provide a summary of the voice file contents", "intent": "voice_summary"},
  {"text": "Explain what is being discussed in the audio", "intent": "voice_summary"},
  {"text": "Give a short summary of what this recording says", "intent": "voice_summary"}
]

# %%
data4 = [
  {"text": "Could you tell me what this audio is saying?", "intent": "voice_summary"},
  {"text": "What’s this recording all about?", "intent": "voice_summary"},
  {"text": "Just give me the highlights from this voice note", "intent": "voice_summary"},
  {"text": "Quick summary of this voice file, please", "intent": "voice_summary"},
  {"text": "Tell me the important stuff from this audio", "intent": "voice_summary"},
  {"text": "Break down the content of this voice recording", "intent": "voice_summary"},
  {"text": "Help me understand the voice clip", "intent": "voice_summary"},
  {"text": "Can you extract the key message here?", "intent": "voice_summary"},
  {"text": "In short, what’s being said in the audio?", "intent": "voice_summary"},
  {"text": "Summarize the message in this clip", "intent": "voice_summary"},
  {"text": "Give me the main message from this sound clip", "intent": "voice_summary"},
  {"text": "I want a short version of this voice message", "intent": "voice_summary"},
  {"text": "Just the summary from this audio, please", "intent": "voice_summary"},
  {"text": "Please help me with a summary of this clip", "intent": "voice_summary"},
  {"text": "What is the speaker talking about here?", "intent": "voice_summary"},
  {"text": "What’s the core message of this voice file?", "intent": "voice_summary"},
  {"text": "Condense this audio into a few points", "intent": "voice_summary"},
  {"text": "Summarize what I’m hearing in this recording", "intent": "voice_summary"},
  {"text": "Wrap up the content of this voice message", "intent": "voice_summary"},
  {"text": "Can you give a TL;DR of this recording?", "intent": "voice_summary"},
  {"text": "What’s the summary of this talk?", "intent": "voice_summary"},
  {"text": "Capture the main content from this voice file", "intent": "voice_summary"},
  {"text": "Explain this audio in simple terms", "intent": "voice_summary"},
  {"text": "What’s the narration about in this clip?", "intent": "voice_summary"},
  {"text": "I'd like a gist of what this recording says", "intent": "voice_summary"},
  {"text": "Tell me what this speaker is explaining", "intent": "voice_summary"},
  {"text": "Quick overview of this voice memo", "intent": "voice_summary"},
  {"text": "What’s this speaker talking about?", "intent": "voice_summary"},
  {"text": "Could you wrap this audio up in a few words?", "intent": "voice_summary"},
  {"text": "Break this down and tell me the main parts", "intent": "voice_summary"}
]

# %%
data5 = [
  {"text": "Give a quick explanation of this audio file", "intent": "voice_summary"},
  {"text": "Summarize this voice clip in one line", "intent": "voice_summary"},
  {"text": "I need a short summary of the recording", "intent": "voice_summary"},
  {"text": "Break down the content of this audio", "intent": "voice_summary"},
  {"text": "What's the speaker talking about in this file?", "intent": "voice_summary"},
  {"text": "Give me the main highlights of this audio", "intent": "voice_summary"},
  {"text": "Can you summarize what was said in this recording?", "intent": "voice_summary"},
  {"text": "Tell me what this audio is explaining", "intent": "voice_summary"},
  {"text": "I'd like a summary of the voice message", "intent": "voice_summary"},
  {"text": "Provide a quick recap of this audio note", "intent": "voice_summary"},
  {"text": "Give an overview of the discussion in this audio", "intent": "voice_summary"},
  {"text": "Summarize the topic covered in this voice clip", "intent": "voice_summary"},
  {"text": "Give me a brief of what’s in this audio", "intent": "voice_summary"},
  {"text": "What’s being said in this audio message?", "intent": "voice_summary"},
  {"text": "Give me a voice summary from this file", "intent": "voice_summary"},
  {"text": "What’s this voice file all about?", "intent": "voice_summary"},
  {"text": "Summarize the main ideas from the audio clip", "intent": "voice_summary"},
  {"text": "Explain what this voice note is talking about", "intent": "voice_summary"},
  {"text": "What's the subject of this sound file?", "intent": "voice_summary"},
  {"text": "I want a summary of this audio", "intent": "voice_summary"},
  {"text": "What’s the voice file trying to convey?", "intent": "voice_summary"},
  {"text": "Summarize what was discussed in this voice message", "intent": "voice_summary"},
  {"text": "Extract a summary from this audio clip", "intent": "voice_summary"},
  {"text": "Tell me what the person is saying in this voice note", "intent": "voice_summary"},
  {"text": "Get me the summary of this podcast audio", "intent": "voice_summary"},
  {"text": "Can you provide a concise summary of this audio?", "intent": "voice_summary"},
  {"text": "Summarize this speech recording", "intent": "voice_summary"},
  {"text": "Tell me the essence of this voice clip", "intent": "voice_summary"},
  {"text": "What’s the short version of this recording?", "intent": "voice_summary"},
  {"text": "Give a recap of this audio content", "intent": "voice_summary"},
  {"text": "What is this person talking about?", "intent": "voice_summary"},
  {"text": "What’s the main idea of this voice message?", "intent": "voice_summary"},
  {"text": "Summarize the voice file in plain terms", "intent": "voice_summary"},
  {"text": "Provide a brief explanation of this audio", "intent": "voice_summary"},
  {"text": "I just need the key points from this voice note", "intent": "voice_summary"},
  {"text": "Explain this audio in short", "intent": "voice_summary"},
  {"text": "What's covered in this recording?", "intent": "voice_summary"},
  {"text": "Give me a short interpretation of this voice memo", "intent": "voice_summary"},
  {"text": "What’s the central message of this audio?", "intent": "voice_summary"},
  {"text": "What’s the overview of this speech clip?", "intent": "voice_summary"},
  {"text": "Can you sum up this sound clip?", "intent": "voice_summary"},
  {"text": "What's the content of this voice file?", "intent": "voice_summary"},
  {"text": "Tell me the main subject of the audio", "intent": "voice_summary"},
  {"text": "Get a voice summary from this uploaded audio", "intent": "voice_summary"},
  {"text": "What’s said in the uploaded voice clip?", "intent": "voice_summary"},
  {"text": "Give a concise explanation of this spoken content", "intent": "voice_summary"},
  {"text": "What information is shared in this voice recording?", "intent": "voice_summary"},
  {"text": "Summarize this audio content quickly", "intent": "voice_summary"},
  {"text": "What's the conclusion of this voice note?", "intent": "voice_summary"},
  {"text": "Can I get a quick summary of what’s said here?", "intent": "voice_summary"}
]

# %%
data6 = [
  {"text": "What’s being conveyed in this audio file?", "intent": "voice_summary"},
  {"text": "Can you tell me the main idea in this voice message?", "intent": "voice_summary"},
  {"text": "I'd like a short summary of this voice clip", "intent": "voice_summary"},
  {"text": "Please interpret the audio and summarize it", "intent": "voice_summary"},
  {"text": "Can you break down this speech into key points?", "intent": "voice_summary"},
  {"text": "What’s this voice message saying in brief?", "intent": "voice_summary"},
  {"text": "Please extract the essence of the audio", "intent": "voice_summary"},
  {"text": "Give me the outline of this voice recording", "intent": "voice_summary"},
  {"text": "Help me understand what this person is talking about", "intent": "voice_summary"},
  {"text": "What's the general topic in this audio clip?", "intent": "voice_summary"},
  {"text": "Summarize what’s discussed in the recording", "intent": "voice_summary"},
  {"text": "Tell me what’s important in this sound clip", "intent": "voice_summary"},
  {"text": "Can you summarize this voice for me?", "intent": "voice_summary"},
  {"text": "Let me know what this audio is about", "intent": "voice_summary"},
  {"text": "Give a short explanation of the voice clip", "intent": "voice_summary"},
  {"text": "Could you summarize the ideas expressed in this clip?", "intent": "voice_summary"},
  {"text": "Break this recording into key ideas", "intent": "voice_summary"},
  {"text": "Tell me what’s happening in this audio", "intent": "voice_summary"},
  {"text": "I want the short version of this audio’s content", "intent": "voice_summary"},
  {"text": "Could you quickly tell me what this audio says?", "intent": "voice_summary"},
  {"text": "Please give the key points of this voice file", "intent": "voice_summary"},
  {"text": "I need a concise summary of this voice memo", "intent": "voice_summary"},
  {"text": "Tell me the summary of this conversation", "intent": "voice_summary"},
  {"text": "Highlight the important content from this audio", "intent": "voice_summary"},
  {"text": "Just a quick idea of what this voice recording is", "intent": "voice_summary"},
  {"text": "Can you tell me the summary of this voice?", "intent": "voice_summary"},
  {"text": "Summarize this voice memo in simple terms", "intent": "voice_summary"},
  {"text": "What is this person saying overall?", "intent": "voice_summary"},
  {"text": "Please explain what’s going on in this clip", "intent": "voice_summary"},
  {"text": "Get me the crux of this voice note", "intent": "voice_summary"}
]

# %%
data6 += [
  {"text": "Can you summarize the voice note for me?", "intent": "voice_summary"},
  {"text": "Give me a brief on what’s being said in this voice message", "intent": "voice_summary"},
  {"text": "Please shorten this audio into a summary", "intent": "voice_summary"},
  {"text": "I'd like to know what’s being talked about in the voice clip", "intent": "voice_summary"},
  {"text": "Extract the main message from this recording", "intent": "voice_summary"},
  {"text": "Provide a short description of this audio", "intent": "voice_summary"},
  {"text": "Summarize what the person is saying", "intent": "voice_summary"},
  {"text": "Just the important parts from this audio, please", "intent": "voice_summary"},
  {"text": "What are the key points from this voice?", "intent": "voice_summary"},
  {"text": "Turn this voice message into a short summary", "intent": "voice_summary"},
  {"text": "Help me get a quick understanding of this audio", "intent": "voice_summary"},
  {"text": "What’s the main content in this audio?", "intent": "voice_summary"},
  {"text": "Condense this voice message into key ideas", "intent": "voice_summary"},
  {"text": "Summarize the audio content clearly", "intent": "voice_summary"},
  {"text": "Give a summary of what’s spoken in the voice", "intent": "voice_summary"},
  {"text": "Provide a summary of this speech", "intent": "voice_summary"},
  {"text": "What does the speaker say in summary?", "intent": "voice_summary"},
  {"text": "Give a concise breakdown of the recording", "intent": "voice_summary"},
  {"text": "Turn this voice into a short note", "intent": "voice_summary"},
  {"text": "Tell me briefly what this audio is about", "intent": "voice_summary"},
  {"text": "What are they discussing in this voice message?", "intent": "voice_summary"},
  {"text": "Help me understand the core idea of the voice file", "intent": "voice_summary"},
  {"text": "Summarize the discussion in this recording", "intent": "voice_summary"},
  {"text": "Could you list the main points from the voice clip?", "intent": "voice_summary"},
  {"text": "I need a quick summary of this audio note", "intent": "voice_summary"},
  {"text": "What are the highlights of this voice?", "intent": "voice_summary"},
  {"text": "Tell me the gist of this voice message", "intent": "voice_summary"},
  {"text": "Briefly explain the content of this audio", "intent": "voice_summary"},
  {"text": "Help me figure out what’s being said here", "intent": "voice_summary"},
  {"text": "Can you put this audio in a nutshell?", "intent": "voice_summary"}
]

# %%
data6 += [
  {"text": "What’s the takeaway from this audio?", "intent": "voice_summary"},
  {"text": "Can you tell me the essence of this voice clip?", "intent": "voice_summary"},
  {"text": "Summarize what the speaker is talking about", "intent": "voice_summary"},
  {"text": "Help me catch the main idea from this recording", "intent": "voice_summary"},
  {"text": "Give me the highlights of this voice memo", "intent": "voice_summary"},
  {"text": "Extract the core message of this audio", "intent": "voice_summary"},
  {"text": "What does the voice clip convey overall?", "intent": "voice_summary"},
  {"text": "Tell me what this person is trying to say", "intent": "voice_summary"},
  {"text": "I want a summary of what was said", "intent": "voice_summary"},
  {"text": "What’s the audio file about?", "intent": "voice_summary"},
  {"text": "Summarize the topic discussed in this audio", "intent": "voice_summary"},
  {"text": "Give me a rundown of this voice message", "intent": "voice_summary"},
  {"text": "What’s the speaker trying to communicate?", "intent": "voice_summary"},
  {"text": "Shorten this audio to its key message", "intent": "voice_summary"},
  {"text": "What is the speaker saying in short?", "intent": "voice_summary"},
  {"text": "Break this audio down to its key insights", "intent": "voice_summary"},
  {"text": "Tell me what’s being discussed", "intent": "voice_summary"},
  {"text": "Can you simplify this voice message?", "intent": "voice_summary"},
  {"text": "Give the audio's meaning in brief", "intent": "voice_summary"},
  {"text": "Tell me the key discussion from this voice", "intent": "voice_summary"},
  {"text": "Capture the summary of this audio clip", "intent": "voice_summary"},
  {"text": "Can you share a short overview of this voice recording?", "intent": "voice_summary"},
  {"text": "Provide a summary of what’s said here", "intent": "voice_summary"},
  {"text": "What’s the brief idea of this voice note?", "intent": "voice_summary"},
  {"text": "Summarize this for me in one line", "intent": "voice_summary"},
  {"text": "Explain briefly what this recording says", "intent": "voice_summary"},
  {"text": "I just want to know what they are talking about", "intent": "voice_summary"},
  {"text": "What is discussed in this voice clip?", "intent": "voice_summary"},
  {"text": "Can you give the overview of this audio?", "intent": "voice_summary"},
  {"text": "Break down this voice memo in short", "intent": "voice_summary"},
  {"text": "I need the central idea from this audio", "intent": "voice_summary"},
  {"text": "What’s the person talking about in general?", "intent": "voice_summary"},
  {"text": "Summarize this speech message", "intent": "voice_summary"},
  {"text": "Convert this voice to key takeaways", "intent": "voice_summary"},
  {"text": "What are the key elements of this voice?", "intent": "voice_summary"},
  {"text": "What’s the content of this voice note?", "intent": "voice_summary"},
  {"text": "Brief me on this voice clip", "intent": "voice_summary"},
  {"text": "List the primary message of this audio", "intent": "voice_summary"},
  {"text": "Can you pull out the main idea?", "intent": "voice_summary"},
  {"text": "Give me the short version of this recording", "intent": "voice_summary"},
  {"text": "What are they trying to explain?", "intent": "voice_summary"},
  {"text": "Can you summarize the subject of this audio?", "intent": "voice_summary"},
  {"text": "Let me know the conclusion of this audio", "intent": "voice_summary"},
  {"text": "Extract the essential points", "intent": "voice_summary"},
  {"text": "Give a to-the-point summary", "intent": "voice_summary"},
  {"text": "Summarize the important information", "intent": "voice_summary"},
  {"text": "What does this audio mainly talk about?", "intent": "voice_summary"},
  {"text": "Help me quickly understand this voice note", "intent": "voice_summary"},
  {"text": "Tell me the important topics mentioned", "intent": "voice_summary"},
  {"text": "I need a small note on this voice message", "intent": "voice_summary"},
  {"text": "Capture the summary in 1-2 lines", "intent": "voice_summary"},
  {"text": "Point out the major themes of the audio", "intent": "voice_summary"},
  {"text": "What are the speaker’s key arguments?", "intent": "voice_summary"},
  {"text": "Can you make this audio more digestible?", "intent": "voice_summary"},
  {"text": "Give me the quick points", "intent": "voice_summary"},
  {"text": "What’s the voice all about?", "intent": "voice_summary"},
  {"text": "Provide quick notes from the voice memo", "intent": "voice_summary"},
  {"text": "Summarize this speech recording", "intent": "voice_summary"},
  {"text": "Give a brief summary in plain words", "intent": "voice_summary"},
  {"text": "Share what’s being said without the extra detail", "intent": "voice_summary"},
  {"text": "Highlight the summary points", "intent": "voice_summary"},
  {"text": "Make this voice content easy to understand", "intent": "voice_summary"},
  {"text": "Can you give me a 2-line summary?", "intent": "voice_summary"},
  {"text": "Condense this audio into essentials", "intent": "voice_summary"},
  {"text": "Can you give the conclusion of this voice file?", "intent": "voice_summary"},
  {"text": "Just want the gist of this clip", "intent": "voice_summary"},
  {"text": "Outline the main discussion here", "intent": "voice_summary"},
  {"text": "I need to know the context of this audio", "intent": "voice_summary"},
  {"text": "Pull out the main statements", "intent": "voice_summary"},
  {"text": "What’s the audio’s intent?", "intent": "voice_summary"},
  {"text": "Extract a few key lines that summarize this", "intent": "voice_summary"},
  {"text": "What’s the point being made here?", "intent": "voice_summary"},
  {"text": "Tell me what to understand from this voice", "intent": "voice_summary"},
  {"text": "I need the summarized version of this", "intent": "voice_summary"},
  {"text": "Help me grasp the message quickly", "intent": "voice_summary"},
  {"text": "Boil this down to the basics", "intent": "voice_summary"},
  {"text": "Give a brief message summary", "intent": "voice_summary"},
  {"text": "Condense this message for clarity", "intent": "voice_summary"},
  {"text": "Share a small explanation of what’s said", "intent": "voice_summary"},
  {"text": "Can you explain this audio in a few words?", "intent": "voice_summary"},
  {"text": "Interpret the message in summary form", "intent": "voice_summary"},
  {"text": "Write a few lines summarizing this voice", "intent": "voice_summary"},
  {"text": "Give a compact version of the discussion", "intent": "voice_summary"},
  {"text": "Tell me what to know from this audio", "intent": "voice_summary"},
  {"text": "What’s the final takeaway from the audio?", "intent": "voice_summary"},
  {"text": "I need a crisp version of this audio", "intent": "voice_summary"},
  {"text": "Give the short form of what was said", "intent": "voice_summary"},
  {"text": "Can you help summarize this in points?", "intent": "voice_summary"},
  {"text": "What should I understand from this clip?", "intent": "voice_summary"},
  {"text": "Summarize this in a few bullet points", "intent": "voice_summary"},
  {"text": "Give a short extract of the voice file", "intent": "voice_summary"},
  {"text": "What’s the meaning of this recording?", "intent": "voice_summary"},
  {"text": "Summarize this conversation for me", "intent": "voice_summary"},
  {"text": "Help me find the main focus of the audio", "intent": "voice_summary"},
  {"text": "Tell me what this talk is centered on", "intent": "voice_summary"},
  {"text": "Provide a light summary of the content", "intent": "voice_summary"},
  {"text": "Write a few words on what the audio is about", "intent": "voice_summary"},
  {"text": "Can you share what’s said in brief?", "intent": "voice_summary"},
  {"text": "What’s the key takeaway from this?", "intent": "voice_summary"},
  {"text": "Tell me what was spoken about", "intent": "voice_summary"},
  {"text": "Extract and share the summary", "intent": "voice_summary"}
]

# %%
data6+= [
  {"text": "Summarize this audio in simple terms", "intent": "voice_summary"},
  {"text": "What is this audio generally saying?", "intent": "voice_summary"},
  {"text": "Give me a summary explanation of the voice message", "intent": "voice_summary"},
  {"text": "Explain briefly what’s discussed in this audio clip", "intent": "voice_summary"},
  {"text": "Tell me the essence of what I’m hearing", "intent": "voice_summary"},
  {"text": "Make this voice message easy to understand", "intent": "voice_summary"},
  {"text": "Can you summarize the voice recording?", "intent": "voice_summary"},
  {"text": "Condense the message in this voice clip", "intent": "voice_summary"},
  {"text": "Quick summary of this conversation, please", "intent": "voice_summary"},
  {"text": "Wrap up the voice clip content for me", "intent": "voice_summary"},
  {"text": "Break down this voice message into a short description", "intent": "voice_summary"},
  {"text": "Need a summary note of this voice", "intent": "voice_summary"},
  {"text": "Write down the main message from this audio", "intent": "voice_summary"},
  {"text": "Can you tell me what this speaker is getting at?", "intent": "voice_summary"},
  {"text": "What’s the short version of this message?", "intent": "voice_summary"},
  {"text": "Capture the important message from this audio", "intent": "voice_summary"},
  {"text": "Provide a small recap of the audio", "intent": "voice_summary"},
  {"text": "Summarize the vocal message here", "intent": "voice_summary"},
  {"text": "Tell me what the speaker is conveying", "intent": "voice_summary"},
  {"text": "I want a quick summary of the content", "intent": "voice_summary"},
  {"text": "What did the person talk about?", "intent": "voice_summary"},
  {"text": "Boil this voice note down to a few points", "intent": "voice_summary"},
  {"text": "Distill this voice content into main ideas", "intent": "voice_summary"},
  {"text": "What are the major insights from this voice recording?", "intent": "voice_summary"},
  {"text": "Help me understand what the audio says", "intent": "voice_summary"},
  {"text": "Short explanation of this audio, please", "intent": "voice_summary"},
  {"text": "Put this audio into a few sentences", "intent": "voice_summary"},
  {"text": "What’s this speaker explaining?", "intent": "voice_summary"},
  {"text": "Tell me briefly what this person said", "intent": "voice_summary"},
  {"text": "I need a TL;DR for this voice clip", "intent": "voice_summary"},
  {"text": "Give a quick brief on the voice message", "intent": "voice_summary"},
  {"text": "Compress this audio into summary form", "intent": "voice_summary"},
  {"text": "Break down what was said here", "intent": "voice_summary"},
  {"text": "Convert this long voice to a few sentences", "intent": "voice_summary"},
  {"text": "Tell me the voice content concisely", "intent": "voice_summary"},
  {"text": "Summarize the talk in this recording", "intent": "voice_summary"},
  {"text": "What is the person trying to tell us?", "intent": "voice_summary"},
  {"text": "Outline what was spoken", "intent": "voice_summary"},
  {"text": "Give a short recap of the speaker’s points", "intent": "voice_summary"},
  {"text": "Please summarize this audio clip fast", "intent": "voice_summary"},
  {"text": "I want a fast summary of this voice message", "intent": "voice_summary"},
  {"text": "Turn this speech into summary format", "intent": "voice_summary"},
  {"text": "Make this long audio brief", "intent": "voice_summary"},
  {"text": "Give me the audio's crux", "intent": "voice_summary"},
  {"text": "Highlight the speaker’s message", "intent": "voice_summary"},
  {"text": "Pick out the top lines from the audio", "intent": "voice_summary"},
  {"text": "Share the takeaway from this voice clip", "intent": "voice_summary"},
  {"text": "I need a one-liner from this voice note", "intent": "voice_summary"},
  {"text": "What’s the important idea conveyed?", "intent": "voice_summary"},
  {"text": "Briefly explain what’s in this voice memo", "intent": "voice_summary"},
  {"text": "Short summary of the audio message", "intent": "voice_summary"},
  {"text": "What's this audio content about in short?", "intent": "voice_summary"},
  {"text": "Share the short conclusion of the audio", "intent": "voice_summary"},
  {"text": "List the speaker’s points in short", "intent": "voice_summary"},
  {"text": "Can I get a summary breakdown?", "intent": "voice_summary"},
  {"text": "What’s the overall message of the voice?", "intent": "voice_summary"},
  {"text": "Help summarize the topic of discussion", "intent": "voice_summary"},
  {"text": "Voice summary needed", "intent": "voice_summary"},
  {"text": "Audio gist please", "intent": "voice_summary"},
  {"text": "Summarize recording", "intent": "voice_summary"},
  {"text": "Key takeaway from this message?", "intent": "voice_summary"},
  {"text": "What is he/she discussing here?", "intent": "voice_summary"},
  {"text": "Overview of the audio", "intent": "voice_summary"},
  {"text": "Extract voice highlights", "intent": "voice_summary"},
  {"text": "Main focus of the audio", "intent": "voice_summary"},
  {"text": "Summary of audio speech", "intent": "voice_summary"},
  {"text": "Tell me the brief of this voice", "intent": "voice_summary"},
  {"text": "What did they mean in this clip?", "intent": "voice_summary"},
  {"text": "Interpret this audio message shortly", "intent": "voice_summary"},
  {"text": "Make a short paragraph from this audio", "intent": "voice_summary"},
  {"text": "List important discussion points", "intent": "voice_summary"},
  {"text": "Make this voice note understandable in short", "intent": "voice_summary"},
  {"text": "What’s being expressed in the voice?", "intent": "voice_summary"},
  {"text": "Translate this audio into a summary", "intent": "voice_summary"},
  {"text": "Quick interpretation of this clip", "intent": "voice_summary"},
  {"text": "Give short key notes from this audio", "intent": "voice_summary"},
  {"text": "Voice to summary conversion please", "intent": "voice_summary"},
  {"text": "Speaker's message in one line?", "intent": "voice_summary"},
  {"text": "Audio summary output", "intent": "voice_summary"},
  {"text": "Voice content summarized", "intent": "voice_summary"},
  {"text": "Tell me the voice message meaning", "intent": "voice_summary"},
  {"text": "Extract speaker’s motive", "intent": "voice_summary"},
  {"text": "What’s conveyed in the audio clip?", "intent": "voice_summary"},
  {"text": "Simplify this audio message", "intent": "voice_summary"},
  {"text": "Tell me the central idea", "intent": "voice_summary"},
  {"text": "What’s being explained?", "intent": "voice_summary"},
  {"text": "Create a mini-summary of the voice", "intent": "voice_summary"},
  {"text": "Write a small review of this audio", "intent": "voice_summary"},
  {"text": "What’s the message content?", "intent": "voice_summary"},
  {"text": "Voice to text summary required", "intent": "voice_summary"},
  {"text": "Main points in brief?", "intent": "voice_summary"},
  {"text": "Audio explained briefly", "intent": "voice_summary"},
  {"text": "Short outline of this voice", "intent": "voice_summary"},
  {"text": "Convert voice file to summary", "intent": "voice_summary"},
  {"text": "Speaker’s words summarized", "intent": "voice_summary"},
  {"text": "What’s the short story behind this voice?", "intent": "voice_summary"},
  {"text": "Explain what’s being talked about", "intent": "voice_summary"},
  {"text": "Give concise interpretation of the voice", "intent": "voice_summary"},
  {"text": "Narrate this audio in a line", "intent": "voice_summary"},
]

# %%
data6 += [
  {"text": "What is the overall message of this voice?", "intent": "voice_summary"},
  {"text": "Give me a simple explanation of the audio", "intent": "voice_summary"},
  {"text": "Can you tell me what’s being talked about?", "intent": "voice_summary"},
  {"text": "Please condense the content of this voice note", "intent": "voice_summary"},
  {"text": "Summarize what’s being conveyed here", "intent": "voice_summary"},
  {"text": "Give me a summary without the fluff", "intent": "voice_summary"},
  {"text": "I just want the summary of this voice clip", "intent": "voice_summary"},
  {"text": "Help me understand what the speaker is saying", "intent": "voice_summary"},
  {"text": "Can you tell me the topic of this audio?", "intent": "voice_summary"},
  {"text": "Summarize this voice message in 2 lines", "intent": "voice_summary"},
  {"text": "Extract a concise summary from this voice", "intent": "voice_summary"},
  {"text": "Tell me what this audio is mainly about", "intent": "voice_summary"},
  {"text": "What are the main takeaways from this recording?", "intent": "voice_summary"},
  {"text": "Briefly explain the contents of this audio", "intent": "voice_summary"},
  {"text": "Can you outline the core ideas in this clip?", "intent": "voice_summary"},
  {"text": "Give me an overview of what’s being said", "intent": "voice_summary"},
  {"text": "Summarize the speech in simple terms", "intent": "voice_summary"},
  {"text": "What’s the most important point in this audio?", "intent": "voice_summary"},
  {"text": "List down what the speaker is highlighting", "intent": "voice_summary"},
  {"text": "Can I get a summary of this audio message?", "intent": "voice_summary"},
  {"text": "Explain what this voice note is talking about", "intent": "voice_summary"},
  {"text": "What is the essential summary here?", "intent": "voice_summary"},
  {"text": "Tell me the focus of this conversation", "intent": "voice_summary"},
  {"text": "Quickly summarize what’s being discussed", "intent": "voice_summary"},
  {"text": "Give a snapshot of this voice recording", "intent": "voice_summary"},
  {"text": "Can you provide a gist of the audio?", "intent": "voice_summary"},
  {"text": "I need the voice note’s core meaning", "intent": "voice_summary"},
  {"text": "What’s the discussion mainly covering?", "intent": "voice_summary"},
  {"text": "Share the summary of this voice in a few lines", "intent": "voice_summary"},
  {"text": "Help me extract the essence of this speech", "intent": "voice_summary"},
  {"text": "Tell me what this voice is essentially saying", "intent": "voice_summary"},
  {"text": "Can you extract the conclusion of this clip?", "intent": "voice_summary"},
  {"text": "Summarize what this person is trying to explain", "intent": "voice_summary"},
  {"text": "What is the highlight of the audio?", "intent": "voice_summary"},
  {"text": "Break it down and give the main idea", "intent": "voice_summary"},
  {"text": "Can you quickly tell me what this is about?", "intent": "voice_summary"},
  {"text": "Give the key summary of what’s recorded", "intent": "voice_summary"},
  {"text": "Help me with a short description of the audio", "intent": "voice_summary"},
  {"text": "What’s the basic idea conveyed?", "intent": "voice_summary"},
  {"text": "Tell me what message this clip conveys", "intent": "voice_summary"},
  {"text": "What’s the message in a nutshell?", "intent": "voice_summary"},
  {"text": "Can you help me understand this in brief?", "intent": "voice_summary"},
  {"text": "Highlight the important points discussed", "intent": "voice_summary"},
  {"text": "Share what this voice clip mainly covers", "intent": "voice_summary"},
  {"text": "Give me a very short recap of this audio", "intent": "voice_summary"},
  {"text": "Summarize the entire voice message", "intent": "voice_summary"},
  {"text": "What’s the conversation mainly about?", "intent": "voice_summary"},
  {"text": "Extract and outline the key points", "intent": "voice_summary"},
  {"text": "What do I need to understand from this?", "intent": "voice_summary"},
  {"text": "Give a plain English summary of this", "intent": "voice_summary"},
  {"text": "What’s the person trying to highlight here?", "intent": "voice_summary"},
  {"text": "Extract key points in bullet form", "intent": "voice_summary"},
  {"text": "Give a summary that captures the voice’s intent", "intent": "voice_summary"},
  {"text": "Tell me the essence without much detail", "intent": "voice_summary"},
  {"text": "I want just the main idea of this message", "intent": "voice_summary"},
  {"text": "Help me extract key facts from the audio", "intent": "voice_summary"},
  {"text": "Share the key takeaway in one sentence", "intent": "voice_summary"},
  {"text": "Can you distill the message of this recording?", "intent": "voice_summary"},
  {"text": "What’s the speaker’s core message?", "intent": "voice_summary"},
  {"text": "Give me the meat of the message", "intent": "voice_summary"},
  {"text": "Summarize what the person is trying to get across", "intent": "voice_summary"},
  {"text": "Explain this voice in the simplest way", "intent": "voice_summary"},
  {"text": "What should I take away from this recording?", "intent": "voice_summary"},
  {"text": "What are the primary take-home points?", "intent": "voice_summary"},
  {"text": "Can you summarize the recording's contents?", "intent": "voice_summary"},
  {"text": "Just give me the core discussion", "intent": "voice_summary"},
  {"text": "What idea is being shared in this voice?", "intent": "voice_summary"},
  {"text": "I need a brief on this clip", "intent": "voice_summary"},
  {"text": "What’s the underlying message of this audio?", "intent": "voice_summary"},
  {"text": "Can you break this voice down simply?", "intent": "voice_summary"},
  {"text": "Give the general idea in a short paragraph", "intent": "voice_summary"},
  {"text": "Summarize this voice with key highlights", "intent": "voice_summary"},
  {"text": "What should I learn from this voice?", "intent": "voice_summary"},
  {"text": "What is the audio’s main talking point?", "intent": "voice_summary"},
  {"text": "Can you help decode this voice into summary?", "intent": "voice_summary"},
  {"text": "I need to know what the speaker meant", "intent": "voice_summary"},
  {"text": "Boil the audio down to a few lines", "intent": "voice_summary"},
  {"text": "Summarize this like a news headline", "intent": "voice_summary"},
  {"text": "Give the short and simple message", "intent": "voice_summary"},
  {"text": "Tell me the takeaway in plain terms", "intent": "voice_summary"},
  {"text": "Highlight only the essential parts", "intent": "voice_summary"},
  {"text": "What is the speaker’s message in short?", "intent": "voice_summary"},
  {"text": "Summarize this without the technicalities", "intent": "voice_summary"},
  {"text": "Help me figure out the important message", "intent": "voice_summary"},
  {"text": "What does this recording aim to express?", "intent": "voice_summary"},
  {"text": "Just want to know the big picture", "intent": "voice_summary"},
  {"text": "Sum this voice up in a few key phrases", "intent": "voice_summary"},
  {"text": "What is the main intent of this voice note?", "intent": "voice_summary"},
  {"text": "What’s the discussion summary here?", "intent": "voice_summary"},
  {"text": "Provide a simplified overview of this audio", "intent": "voice_summary"},
  {"text": "What does the person want to communicate?", "intent": "voice_summary"},
  {"text": "Can you recap what’s been said?", "intent": "voice_summary"},
  {"text": "Just share what matters from this message", "intent": "voice_summary"},
  {"text": "Tell me what this message boils down to", "intent": "voice_summary"},
  {"text": "What’s the summary explanation?", "intent": "voice_summary"},
  {"text": "Give me a quick note about this clip", "intent": "voice_summary"},
  {"text": "Help extract what the speaker really means", "intent": "voice_summary"},
  {"text": "Give the heart of the discussion", "intent": "voice_summary"}
]

# %%
data6 += [
  {"text": "Summarize the audio for quick reading", "intent": "voice_summary"},
  {"text": "Briefly tell me what the speaker is saying", "intent": "voice_summary"},
  {"text": "Need a summary of this audio speech", "intent": "voice_summary"},
  {"text": "Quickly summarize the conversation in this voice message", "intent": "voice_summary"},
  {"text": "Can you summarize the points discussed in this voice?", "intent": "voice_summary"},
  {"text": "I'd like a short description of the voice content", "intent": "voice_summary"},
  {"text": "Voice is too long, just give me the summary", "intent": "voice_summary"},
  {"text": "Capture the key parts of this voice message", "intent": "voice_summary"},
  {"text": "Short version of what was said in the voice", "intent": "voice_summary"},
  {"text": "Provide a voice note summary", "intent": "voice_summary"},
  {"text": "Summarize this message from the speaker", "intent": "voice_summary"},
  {"text": "Give me a quick explanation of what’s in this voice", "intent": "voice_summary"},
  {"text": "I want to know what this voice clip is about", "intent": "voice_summary"},
  {"text": "Short summary of the spoken message", "intent": "voice_summary"},
  {"text": "Reduce this voice content to 2 lines", "intent": "voice_summary"},
  {"text": "What are they mainly saying in this clip?", "intent": "voice_summary"},
  {"text": "Tell me the idea in this voice file", "intent": "voice_summary"},
  {"text": "What's the summary from this voice audio?", "intent": "voice_summary"},
  {"text": "Give me a high-level overview of this voice", "intent": "voice_summary"},
  {"text": "What's the voice about in summary form?", "intent": "voice_summary"},
  {"text": "What’s the short gist of this voice?", "intent": "voice_summary"},
  {"text": "Summarize the voice info", "intent": "voice_summary"},
  {"text": "Give me the voice message highlights", "intent": "voice_summary"},
  {"text": "Short overview of this voice chat", "intent": "voice_summary"},
  {"text": "Key points from this voice message please", "intent": "voice_summary"},
  {"text": "Make a digest from the voice clip", "intent": "voice_summary"},
  {"text": "Can you give me a capsule version of this?", "intent": "voice_summary"},
  {"text": "Voice summary in bullet points?", "intent": "voice_summary"},
  {"text": "Summarize the voice into 3 key points", "intent": "voice_summary"},
  {"text": "What did the speaker convey in brief?", "intent": "voice_summary"},
  {"text": "Help me understand this audio quickly", "intent": "voice_summary"},
  {"text": "Extract the core message from this voice", "intent": "voice_summary"},
  {"text": "Turn this voice note into a brief summary", "intent": "voice_summary"},
  {"text": "I need a summarized version of this voice", "intent": "voice_summary"},
  {"text": "Explain what this person is saying in brief", "intent": "voice_summary"},
  {"text": "Voice summarization request", "intent": "voice_summary"},
  {"text": "Turn long audio into a summary", "intent": "voice_summary"},
  {"text": "Give me a clear and concise summary of this", "intent": "voice_summary"},
  {"text": "Condense the speaker’s words", "intent": "voice_summary"},
  {"text": "What's the voice summary in 1-2 lines?", "intent": "voice_summary"},
  {"text": "Voice recording — what’s it about?", "intent": "voice_summary"},
  {"text": "Shortly describe the contents of the voice note", "intent": "voice_summary"},
  {"text": "Highlight the key points in this voice", "intent": "voice_summary"},
  {"text": "What’s the short message in the clip?", "intent": "voice_summary"},
  {"text": "Get me a compressed version of the audio message", "intent": "voice_summary"},
  {"text": "Speaker summary needed", "intent": "voice_summary"},
  {"text": "Tell me what the clip is communicating", "intent": "voice_summary"},
  {"text": "Summarize this voice log", "intent": "voice_summary"},
  {"text": "Outline the audio into short form", "intent": "voice_summary"},
  {"text": "Reduce audio conversation to main points", "intent": "voice_summary"},
  {"text": "Voice content in 2-3 lines summary", "intent": "voice_summary"},
  {"text": "Speaker's intention in short", "intent": "voice_summary"},
  {"text": "Quick overview of the voice talk", "intent": "voice_summary"},
  {"text": "Audio message summary for notes", "intent": "voice_summary"},
  {"text": "Need executive summary of this voice", "intent": "voice_summary"},
  {"text": "Voice explanation summarized", "intent": "voice_summary"},
  {"text": "Voice summary in short form", "intent": "voice_summary"},
  {"text": "Can you brief the voice note?", "intent": "voice_summary"},
  {"text": "Abridged form of the voice message", "intent": "voice_summary"},
  {"text": "Summarized explanation of the voice", "intent": "voice_summary"},
  {"text": "Short form of the voice content", "intent": "voice_summary"},
  {"text": "Distilled version of this voice talk", "intent": "voice_summary"},
  {"text": "Wrap up this voice message in a short note", "intent": "voice_summary"},
  {"text": "Give me a capsule summary of the voice", "intent": "voice_summary"},
  {"text": "Short narration of the voice", "intent": "voice_summary"},
  {"text": "Compressed voice message info", "intent": "voice_summary"},
  {"text": "In a few words, what’s in this voice file?", "intent": "voice_summary"},
  {"text": "Audio to bullet points summary", "intent": "voice_summary"},
  {"text": "Simplified version of the speaker's message", "intent": "voice_summary"},
  {"text": "Quick recap of the voice", "intent": "voice_summary"},
  {"text": "Concise voice information summary", "intent": "voice_summary"},
  {"text": "What's the key takeaway from this voice?", "intent": "voice_summary"},
  {"text": "Summarize the voice discussion", "intent": "voice_summary"},
  {"text": "Can you compress this speaker’s ideas?", "intent": "voice_summary"},
  {"text": "Main message from this voice audio", "intent": "voice_summary"},
  {"text": "Squeeze this voice into summary", "intent": "voice_summary"},
  {"text": "Short breakdown of the audio", "intent": "voice_summary"},
  {"text": "What's the summary paragraph for this voice?", "intent": "voice_summary"},
  {"text": "What’s the key message inside this clip?", "intent": "voice_summary"},
  {"text": "Voice message summarized into one line", "intent": "voice_summary"},
  {"text": "Rephrase and summarize the voice", "intent": "voice_summary"},
  {"text": "Speaker’s speech into summary", "intent": "voice_summary"},
  {"text": "Shorten this voice message to its essence", "intent": "voice_summary"},
  {"text": "Convert voice speech into small summary", "intent": "voice_summary"},
  {"text": "Pull out the main summary from this voice", "intent": "voice_summary"},
  {"text": "Voice topic summarized", "intent": "voice_summary"},
  {"text": "What’s being conveyed overall?", "intent": "voice_summary"},
  {"text": "Summarize speech into 2 lines", "intent": "voice_summary"},
  {"text": "Condensed speaker explanation", "intent": "voice_summary"},
  {"text": "Voice memo brief", "intent": "voice_summary"},
  {"text": "Short message outline from the speaker", "intent": "voice_summary"},
  {"text": "What are the few key points in this voice?", "intent": "voice_summary"},
  {"text": "Make a quick summary statement", "intent": "voice_summary"},
  {"text": "Speaker message extraction", "intent": "voice_summary"},
  {"text": "Voice clip idea summary", "intent": "voice_summary"},
  {"text": "Give me a short summary idea from this voice", "intent": "voice_summary"},
]

# %%
data6 += [
    {"text": "Give me the final thoughts of this voice note.", "intent": "voice_summary"},
    {"text": "What was the crux of this recording?", "intent": "voice_summary"},
    {"text": "Give the summary in layman’s terms.", "intent": "voice_summary"},
    {"text": "Extract the summary message from the voice note.", "intent": "voice_summary"},
    {"text": "What’s the message this audio is delivering?", "intent": "voice_summary"},
    {"text": "Can you tell me the gist in one line?", "intent": "voice_summary"},
    {"text": "What’s the essence of the speaker’s message?", "intent": "voice_summary"},
    {"text": "Can you decode and summarize the voice?", "intent": "voice_summary"},
    {"text": "Write a summary sentence for this audio.", "intent": "voice_summary"},
    {"text": "Can you explain this voice briefly?", "intent": "voice_summary"},
    {"text": "Break down this message into a short summary.", "intent": "voice_summary"},
    {"text": "Highlight what matters in this recording.", "intent": "voice_summary"},
    {"text": "Help me get the idea of this voice file.", "intent": "voice_summary"},
    {"text": "Give me a short recap of this voice clip.", "intent": "voice_summary"},
    {"text": "What’s the voice note trying to tell us?", "intent": "voice_summary"},
    {"text": "Can you extract and summarize the voice idea?", "intent": "voice_summary"},
    {"text": "Can you tell me what’s conveyed here?", "intent": "voice_summary"},
    {"text": "Describe the message briefly.", "intent": "voice_summary"},
    {"text": "Provide the core of what’s being discussed.", "intent": "voice_summary"},
    {"text": "Give me the distilled message.", "intent": "voice_summary"},
    {"text": "Share a summary snippet of the audio.", "intent": "voice_summary"},
    {"text": "Give me a quick overview of what’s being said.", "intent": "voice_summary"},
    {"text": "Can you give me a brief about this voice note?", "intent": "voice_summary"},
    {"text": "Tell me what this audio is mainly expressing.", "intent": "voice_summary"},
    {"text": "Give the briefest form of this message.", "intent": "voice_summary"},
    {"text": "Pick out the important info and summarize.", "intent": "voice_summary"},
    {"text": "Summarize this voice chat.", "intent": "voice_summary"},
    {"text": "What does this voice message boil down to?", "intent": "voice_summary"},
    {"text": "Extract the top points from this voice.", "intent": "voice_summary"},
    {"text": "What was the speaker mainly emphasizing?", "intent": "voice_summary"},
    {"text": "What conclusion can we draw from the audio?", "intent": "voice_summary"},
    {"text": "Tell me what to note from this voice clip.", "intent": "voice_summary"},
    {"text": "Give the key facts from this voice file.", "intent": "voice_summary"},
    {"text": "What’s the concise idea of this audio clip?", "intent": "voice_summary"},
    {"text": "Can you summarize this voice log?", "intent": "voice_summary"},
    {"text": "What theme is the speaker touching on?", "intent": "voice_summary"},
    {"text": "Share the compact interpretation.", "intent": "voice_summary"},
    {"text": "Can you provide a summary insight?", "intent": "voice_summary"},
    {"text": "List the summary in easy words.", "intent": "voice_summary"},
    {"text": "Can you distill this audio to essentials?", "intent": "voice_summary"},
    {"text": "Help simplify the voice message.", "intent": "voice_summary"},
    {"text": "Can you tell the outcome of the discussion?", "intent": "voice_summary"},
    {"text": "Write a one-line summary of the audio.", "intent": "voice_summary"},
    {"text": "I just want the summary line.", "intent": "voice_summary"},
    {"text": "Outline the content in a few words.", "intent": "voice_summary"},
    {"text": "Give the core message of this voice clip.", "intent": "voice_summary"},
    {"text": "Provide key notes from this recording.", "intent": "voice_summary"},
    {"text": "Tell me what to take away from the message.", "intent": "voice_summary"},
    {"text": "Give me the final idea from the audio.", "intent": "voice_summary"},
    {"text": "Tell me the condensed message here.", "intent": "voice_summary"},
    {"text": "Help me get the speaker's point across quickly.", "intent": "voice_summary"},
    {"text": "Give a summarized version of this recording.", "intent": "voice_summary"},
    {"text": "Can you shorten this to just the essentials?", "intent": "voice_summary"},
    {"text": "What was the talk mostly about?", "intent": "voice_summary"},
    {"text": "Distill the content into a short takeaway.", "intent": "voice_summary"},
    {"text": "Highlight only the important words.", "intent": "voice_summary"},
    {"text": "Briefly explain the voice message.", "intent": "voice_summary"},
    {"text": "Extract just the insights from the voice.", "intent": "voice_summary"},
    {"text": "What’s the key message from the talk?", "intent": "voice_summary"},
    {"text": "Give me a quick breakdown of the voice.", "intent": "voice_summary"},
    {"text": "Explain the meaning behind this recording.", "intent": "voice_summary"},
    {"text": "Summarize this without any fluff.", "intent": "voice_summary"},
    {"text": "Tell me what matters most in this audio.", "intent": "voice_summary"},
    {"text": "Condense this voice file to the main point.", "intent": "voice_summary"},
    {"text": "What’s the key line from this clip?", "intent": "voice_summary"},
    {"text": "Tell me what the speaker is focusing on.", "intent": "voice_summary"},
    {"text": "I want just the key sentences from this voice note.", "intent": "voice_summary"},
    {"text": "Give a focused summary of this voice clip.", "intent": "voice_summary"},
    {"text": "Write a mini summary of this voice.", "intent": "voice_summary"},
    {"text": "What takeaway does this audio give?", "intent": "voice_summary"},
    {"text": "Give the essence in two lines.", "intent": "voice_summary"},
    {"text": "What should I remember from this voice?", "intent": "voice_summary"},
    {"text": "Just sum it up quickly.", "intent": "voice_summary"},
    {"text": "Provide the final idea in this audio.", "intent": "voice_summary"},
    {"text": "Break it down to a short explanation.", "intent": "voice_summary"},
    {"text": "What’s being conveyed in short?", "intent": "voice_summary"},
    {"text": "Give the punchline of the voice.", "intent": "voice_summary"},
    {"text": "Summarize the purpose of this recording.", "intent": "voice_summary"},
    {"text": "Point out the key highlights.", "intent": "voice_summary"},
    {"text": "Can you summarize the message intent?", "intent": "voice_summary"},
    {"text": "Write what this message tries to tell us.", "intent": "voice_summary"},
    {"text": "What’s the summarized point here?", "intent": "voice_summary"},
    {"text": "Give me just the core theme.", "intent": "voice_summary"},
    {"text": "What is this speaker emphasizing?", "intent": "voice_summary"},
    {"text": "Explain what the speaker is aiming to say.", "intent": "voice_summary"},
    {"text": "Give a tiny summary of this clip.", "intent": "voice_summary"},
    {"text": "Just the conclusion will do.", "intent": "voice_summary"},
    {"text": "Can you get me the idea fast?", "intent": "voice_summary"},
    {"text": "Tell me the speaker’s message in summary.", "intent": "voice_summary"},
    {"text": "Just summarize the voice very shortly.", "intent": "voice_summary"},
    {"text": "Highlight the intent of this message.", "intent": "voice_summary"},
    {"text": "Distill the recording into key ideas.", "intent": "voice_summary"},
    {"text": "Break this talk down into one thought.", "intent": "voice_summary"},
    {"text": "Tell me what this recording revolves around.", "intent": "voice_summary"},
    {"text": "Sum up the voice in a nutshell.", "intent": "voice_summary"},
    {"text": "Can you express the clip’s idea in a line?", "intent": "voice_summary"},
    {"text": "Extract only the relevant message.", "intent": "voice_summary"},
    {"text": "Summarize what was explained.", "intent": "voice_summary"},
    {"text": "Give a one-liner explaining this voice.", "intent": "voice_summary"},
    {"text": "Tell me what to understand here quickly.", "intent": "voice_summary"}
]

# %%
# Extending the dataset with 100 more variations for the "voice_summary" intent

data6 += [
    {"text": "Can you put this voice message into a nutshell?", "intent": "voice_summary"},
    {"text": "Give me a TL;DR of the audio.", "intent": "voice_summary"},
    {"text": "Summarize this voice like a news headline.", "intent": "voice_summary"},
    {"text": "What's the most important line from this voice?", "intent": "voice_summary"},
    {"text": "Voice note summary please.", "intent": "voice_summary"},
    {"text": "I need a quick idea of this voice message.", "intent": "voice_summary"},
    {"text": "Can you turn this into a single line insight?", "intent": "voice_summary"},
    {"text": "What would be the abstract of this audio?", "intent": "voice_summary"},
    {"text": "Give me the speaker's point in a sentence.", "intent": "voice_summary"},
    {"text": "What does this message really mean?", "intent": "voice_summary"},
    {"text": "Tell me what the speaker is implying.", "intent": "voice_summary"},
    {"text": "Pull out the core from this audio file.", "intent": "voice_summary"},
    {"text": "Quickly interpret the message for me.", "intent": "voice_summary"},
    {"text": "Extract the heart of this voice message.", "intent": "voice_summary"},
    {"text": "I want to know what this is all about.", "intent": "voice_summary"},
    {"text": "Give a condensed interpretation.", "intent": "voice_summary"},
    {"text": "In just one or two sentences, what is this?", "intent": "voice_summary"},
    {"text": "What's the conclusion from this audio?", "intent": "voice_summary"},
    {"text": "Tell me the wrap-up of this voice note.", "intent": "voice_summary"},
    {"text": "Simplify the message into a quick point.", "intent": "voice_summary"},
    {"text": "Need a bite-sized summary of the clip.", "intent": "voice_summary"},
    {"text": "Give me the takeaway of this voice note.", "intent": "voice_summary"},
    {"text": "What can I learn from this voice message?", "intent": "voice_summary"},
    {"text": "Translate this voice to a single thought.", "intent": "voice_summary"},
    {"text": "Give me the voice summary like a caption.", "intent": "voice_summary"},
    {"text": "Tell me the gist of the audio in 5 words.", "intent": "voice_summary"},
    {"text": "Help me capture the voice message essence.", "intent": "voice_summary"},
    {"text": "Can you shorten this voice logically?", "intent": "voice_summary"},
    {"text": "Summarize this for my notes.", "intent": "voice_summary"},
    {"text": "Turn this long message into a short quote.", "intent": "voice_summary"},
    {"text": "What's the bullet point version of this voice?", "intent": "voice_summary"},
    {"text": "Convert the voice note to a tweet-length summary.", "intent": "voice_summary"},
    {"text": "What would be the heading of this message?", "intent": "voice_summary"},
    {"text": "Turn this clip into a title-like summary.", "intent": "voice_summary"},
    {"text": "Give me the big idea in short form.", "intent": "voice_summary"},
    {"text": "How would you summarize this audio fast?", "intent": "voice_summary"},
    {"text": "Extract the one-liner from this audio.", "intent": "voice_summary"},
    {"text": "Tell me what stands out from this voice.", "intent": "voice_summary"},
    {"text": "What is the headline idea of the voice?", "intent": "voice_summary"},
    {"text": "Make this voice brief for my memory.", "intent": "voice_summary"},
    {"text": "Just the main insight please.", "intent": "voice_summary"},
    {"text": "Wrap up the message in one statement.", "intent": "voice_summary"},
    {"text": "Put the audio into a key sentence.", "intent": "voice_summary"},
    {"text": "Compress this audio into a phrase.", "intent": "voice_summary"},
    {"text": "What should I grasp from this voice?", "intent": "voice_summary"},
    {"text": "Tell me the speaker’s main agenda.", "intent": "voice_summary"},
    {"text": "Compress the core of the voice.", "intent": "voice_summary"},
    {"text": "What’s the loudest message in this clip?", "intent": "voice_summary"},
    {"text": "Express this voice content in short.", "intent": "voice_summary"},
    {"text": "Give me an overview sentence.", "intent": "voice_summary"},
    {"text": "Voice message - I just need the summary.", "intent": "voice_summary"},
    {"text": "Sum it up to the punchline.", "intent": "voice_summary"},
    {"text": "What’s the summary of the discussion?", "intent": "voice_summary"},
    {"text": "Summarize the opinion from the audio.", "intent": "voice_summary"},
    {"text": "Voice file: need a recap.", "intent": "voice_summary"},
    {"text": "Short recap for the audio please.", "intent": "voice_summary"},
    {"text": "What would the summary report say?", "intent": "voice_summary"},
    {"text": "Turn this into a short summary block.", "intent": "voice_summary"},
    {"text": "How can I note this message briefly?", "intent": "voice_summary"},
    {"text": "One-line conclusion for the audio?", "intent": "voice_summary"},
    {"text": "Single-line feedback from this voice note?", "intent": "voice_summary"},
    {"text": "Distill the speech into a key idea.", "intent": "voice_summary"},
    {"text": "Tell me the outcome in brief.", "intent": "voice_summary"},
    {"text": "What’s the short interpretation?", "intent": "voice_summary"},
    {"text": "Explain this message in a short bullet.", "intent": "voice_summary"},
    {"text": "Extract key takeaway in one sentence.", "intent": "voice_summary"},
    {"text": "Summarize the important aspects.", "intent": "voice_summary"},
    {"text": "Share the one thing this voice teaches.", "intent": "voice_summary"},
    {"text": "Highlight the meaningful part of the voice.", "intent": "voice_summary"},
    {"text": "Give me a voice summary I can remember.", "intent": "voice_summary"},
    {"text": "Help me get the quick point.", "intent": "voice_summary"},
    {"text": "Summarize the context of the clip.", "intent": "voice_summary"},
    {"text": "Give a mini breakdown of this voice.", "intent": "voice_summary"},
    {"text": "Single-sentence version of the message?", "intent": "voice_summary"},
    {"text": "Compact summary of the voice content?", "intent": "voice_summary"},
    {"text": "Tell me the voice note's essence.", "intent": "voice_summary"},
    {"text": "Give a very short recap please.", "intent": "voice_summary"},
    {"text": "Turn this clip into a headline.", "intent": "voice_summary"},
    {"text": "Summarize the clip as if for a friend.", "intent": "voice_summary"},
    {"text": "Write the moral of the audio.", "intent": "voice_summary"},
    {"text": "Conclude this voice with a summary.", "intent": "voice_summary"},
    {"text": "Give the most relevant insight from the audio.", "intent": "voice_summary"},
    {"text": "Write the audio’s key lesson.", "intent": "voice_summary"},
    {"text": "What key takeaway does the speaker leave us with?", "intent": "voice_summary"},
    {"text": "Give a one-sentence output from the voice.", "intent": "voice_summary"},
    {"text": "What’s the essence in one line?", "intent": "voice_summary"},
    {"text": "Break it down into a summary tweet.", "intent": "voice_summary"},
    {"text": "One-sentence wrap-up of this message?", "intent": "voice_summary"},
    {"text": "Voice summary like a WhatsApp status.", "intent": "voice_summary"},
    {"text": "What’s the bite-sized thought here?", "intent": "voice_summary"},
    {"text": "Make this recording short and snappy.", "intent": "voice_summary"},
    {"text": "How would you summarize this message to a kid?", "intent": "voice_summary"},
    {"text": "Can you write a key point from the audio?", "intent": "voice_summary"},
    {"text": "Summarize in layman language.", "intent": "voice_summary"},
    {"text": "Give a common-sense summary of the clip.", "intent": "voice_summary"},
]

# %%
data6 += [
  {"text": "Can I get a quick voice message overview?", "intent": "voice_summary"},
  {"text": "Briefly what does this voice message say?", "intent": "voice_summary"},
  {"text": "Extract summary from this voice memo", "intent": "voice_summary"},
  {"text": "Tell me the summary of what they said", "intent": "voice_summary"},
  {"text": "Summarize what’s being discussed in the voice note", "intent": "voice_summary"},
  {"text": "Summarize this voice file please", "intent": "voice_summary"},
  {"text": "What’s the short info from this voice note?", "intent": "voice_summary"},
  {"text": "Give me a summary idea from this audio", "intent": "voice_summary"},
  {"text": "Voice message in summary form", "intent": "voice_summary"},
  {"text": "Tell me the short version of this voice note", "intent": "voice_summary"},
  {"text": "Highlight what the speaker said", "intent": "voice_summary"},
  {"text": "Wrap up this voice recording", "intent": "voice_summary"},
  {"text": "Voice message essence please", "intent": "voice_summary"},
  {"text": "Speaker's point in short?", "intent": "voice_summary"},
  {"text": "Can I get a 1-line summary of this voice?", "intent": "voice_summary"},
  {"text": "Break down this voice note to core ideas", "intent": "voice_summary"},
  {"text": "Voice message summary required", "intent": "voice_summary"},
  {"text": "What’s the core idea of this voice clip?", "intent": "voice_summary"},
  {"text": "Give me a 2-3 line gist of the voice", "intent": "voice_summary"},
  {"text": "Summarize what’s spoken here", "intent": "voice_summary"},
  {"text": "Voice note main idea?", "intent": "voice_summary"},
  {"text": "Condensed form of the voice message", "intent": "voice_summary"},
  {"text": "Shorten the voice message to a readable format", "intent": "voice_summary"},
  {"text": "Extract highlights from this voice", "intent": "voice_summary"},
  {"text": "Quick idea of what this voice contains", "intent": "voice_summary"},
  {"text": "Capture key takeaways from this voice", "intent": "voice_summary"},
  {"text": "Can I get the TLDR of this audio?", "intent": "voice_summary"},
  {"text": "Bullet point summary from this voice", "intent": "voice_summary"},
  {"text": "What’s the speaker’s main message?", "intent": "voice_summary"},
  {"text": "Create a short digest from the voice note", "intent": "voice_summary"},
  {"text": "List the core content of this voice", "intent": "voice_summary"},
  {"text": "Help me get the important parts from this audio", "intent": "voice_summary"},
  {"text": "Provide a short review of the voice message", "intent": "voice_summary"},
  {"text": "I need a brief of the audio file", "intent": "voice_summary"},
  {"text": "What is this voice message about briefly?", "intent": "voice_summary"},
  {"text": "Summarize the recording for me", "intent": "voice_summary"},
  {"text": "Short version of speaker’s message please", "intent": "voice_summary"},
  {"text": "Summarize the message recorded", "intent": "voice_summary"},
  {"text": "Voice summary required", "intent": "voice_summary"},
  {"text": "Can you shorten this voice file to a few words?", "intent": "voice_summary"},
  {"text": "Convert voice file to short note", "intent": "voice_summary"},
  {"text": "What’s said in the voice file in brief?", "intent": "voice_summary"},
  {"text": "I want a brief summary of the voice chat", "intent": "voice_summary"},
  {"text": "Voice message gist in a few lines", "intent": "voice_summary"},
  {"text": "What’s this audio clip about?", "intent": "voice_summary"},
  {"text": "Give a wrap-up of this voice message", "intent": "voice_summary"},
  {"text": "Summarize the voice log", "intent": "voice_summary"},
  {"text": "What’s the essential message here?", "intent": "voice_summary"},
  {"text": "Voice memo short description", "intent": "voice_summary"},
  {"text": "Outline what this speaker said", "intent": "voice_summary"},
  {"text": "Make this voice message readable as a summary", "intent": "voice_summary"},
  {"text": "Explain the voice note in short", "intent": "voice_summary"},
  {"text": "Compress this voice message info", "intent": "voice_summary"},
  {"text": "Distill the content of the voice clip", "intent": "voice_summary"},
  {"text": "Voice summary in under 50 words", "intent": "voice_summary"},
  {"text": "Tell me the essence of the recording", "intent": "voice_summary"},
  {"text": "Main idea spoken in voice clip", "intent": "voice_summary"},
  {"text": "Recap of the voice message", "intent": "voice_summary"},
  {"text": "Shortened version of speaker’s words", "intent": "voice_summary"},
  {"text": "Speaker’s summary needed", "intent": "voice_summary"},
  {"text": "What’s in this voice clip in short?", "intent": "voice_summary"},
  {"text": "Summarize the communication in this audio", "intent": "voice_summary"},
  {"text": "Voice overview required", "intent": "voice_summary"},
  {"text": "Give me a breakdown of the voice", "intent": "voice_summary"},
  {"text": "Can you draft a short summary of this voice?", "intent": "voice_summary"},
  {"text": "Speaker’s message condensed", "intent": "voice_summary"},
  {"text": "Short report from this voice note", "intent": "voice_summary"},
  {"text": "Voice idea in simple terms", "intent": "voice_summary"},
  {"text": "Gist of the audio file", "intent": "voice_summary"},
  {"text": "Voice content recap", "intent": "voice_summary"},
  {"text": "Short version of what’s recorded here", "intent": "voice_summary"},
  {"text": "Give me the key info from this voice", "intent": "voice_summary"},
  {"text": "Voice transcript summary", "intent": "voice_summary"},
  {"text": "Abstract of voice message", "intent": "voice_summary"},
  {"text": "Voice note takeaway", "intent": "voice_summary"},
  {"text": "Summarize what's being talked about in the voice", "intent": "voice_summary"},
  {"text": "Short form of the voice dialogue", "intent": "voice_summary"},
  {"text": "Wrap up the points discussed in the voice", "intent": "voice_summary"},
  {"text": "Give me a 3-point summary", "intent": "voice_summary"},
  {"text": "Summarize message into readable lines", "intent": "voice_summary"},
  {"text": "Need a precise version of voice content", "intent": "voice_summary"},
  {"text": "Short content of voice file", "intent": "voice_summary"},
  {"text": "Condensed speaker voice", "intent": "voice_summary"},
  {"text": "Extract voice summary automatically", "intent": "voice_summary"},
  {"text": "Voice speech in short", "intent": "voice_summary"},
  {"text": "Recap the voice", "intent": "voice_summary"},
  {"text": "Make the audio message short and crisp", "intent": "voice_summary"},
  {"text": "Audio clip gist", "intent": "voice_summary"},
  {"text": "Shorten this voice chat", "intent": "voice_summary"},
  {"text": "What was said in this voice, briefly?", "intent": "voice_summary"},
  {"text": "Extract a concise explanation from the voice", "intent": "voice_summary"},
  {"text": "Voice file — give me the quick summary", "intent": "voice_summary"},
  {"text": "Compress and summarize audio", "intent": "voice_summary"},
  {"text": "Speaker’s key insights in short form", "intent": "voice_summary"},
]

# %% [markdown]
# ## Combining Data

# %%
import pandas as pd
try:
    data = data1 + data2 + data3 + data4 + data5 + data6 
    df = pd.DataFrame(data)
    df.to_csv('voice_summary_data.csv')
    print("CSV file saved successfully.")
except Exception as e:
    print(f"exception occured {e}")
# Out:
# CSV file saved successfully.
